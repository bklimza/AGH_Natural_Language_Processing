# %% [markdown]
# # Natural Language Processing - lab 4 (Multiword expressions identification and extraction)
#
# Bartosz Klimza

# %% [markdown]
# # Necessary imports

# %%
import pl_core_news_sm
import spacy
from spacy.tokenizer import Tokenizer
from nltk.util import ngrams
import os
import math

# %%
# !python -m spacy download pl_core_news_sm
# Out:
# Collecting pl_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pl_core_news_sm-2.3.0/pl_core_news_sm-2.3.0.tar.gz (48.7 MB)
#      |████████████████████████████████| 48.7 MB 850 kB/s eta 0:00:01
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from pl_core_news_sm==2.3.0) (2.3.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (1.20.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (2.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (4.59.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (1.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (0.7.4)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (7.4.5)
# Requirement already satisfied: setuptools in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (52.0.0.post20210125)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bartoszklimza/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pl_core_news_sm==2.3.0) (2021.10.8)
# ✔ Download and installation successful
# You can now load the model via spacy.load('pl_core_news_sm')

# %% [markdown]
# # 1. Use SpaCy tokenizer API to tokenize the text from the law corpus:

# %%
nlp = pl_core_news_sm.load()

# Create a blank Tokenizer with just the Polish vocab
tokenizer = Tokenizer(nlp.vocab)

# %% [markdown]
# # 2. Compute bigram counts of downcased tokens. Given the sentence: "The quick brown fox jumps over the lazy dog.", the bigram counts are as follows:
#
# * "the quick":1
# * "quick brown":1
# * "brown fox":1
# * ...
# * "dog.":1

# %%
data_dir = "./ustawy/"

bigrams_dict = dict()
for file in os.listdir(data_dir):
    bills = open(f"./{data_dir}{file}", "r").read()
    bills = bills.split()
    bills = " ".join(bills)
    bills = bills.lower()
    tokens = tokenizer(bills)
    bigrams = ngrams(tokens, 2)
    bigrams_list = []
    for b in bigrams:
        if str(b[0])[-1] in [".", ":", ";", "(", ")", "[", "]", ","]:
            bigrams_list.append(str(b[0])[:-1]+str(b[0])[-1])
        elif str(b[1])[-1] in [".", ":", ";", "(", ")", "[", "]", ","]:
            bigrams_list.append(str(b[1])[:-1]+str(b[1])[-1])
        else:
            bigrams_list.append(str(b[0]) + " " + str(b[1]))
    for i in bigrams_list:
        if i in bigrams_dict.keys():
            bigrams_dict[i] += 1
        else:
            bigrams_dict[i] = 1

bigrams_dictionary = {k: v for k, v in sorted(bigrams_dict.items(), key=lambda item: item[1], reverse=True)}
bigrams_dictionary
# Out:
# {'art.': 126873,
#  'ust.': 103543,
#  'r.': 62958,
#  'poz.': 45369,
#  'mowa w': 28450,
#  '2.': 21587,
#  '1.': 21312,
#  'brzmienie:': 20974,
#  '1,': 15672,
#  '2)': 14309,
#  'których mowa': 13847,
#  'o których': 13839,
#  '3.': 13730,
#  '1)': 13695,
#  'brzmieniu:': 13216,
#  'z dnia': 9513,
#  'którym mowa': 9165,
#  'o którym': 9155,
#  '2,': 9042,
#  '3)': 9006,
#  '(dz.u.': 8930,
#  'do spraw': 8680,
#  'i nr': 8435,
#  'dodaje się': 8190,
#  '4.': 8156,
#  'rozporządzenia,': 8047,
#  'w drodze': 7092,
#  'na podstawie': 6610,
#  'b)': 6356,
#  'a)': 6255,
#  'stosuje się': 6030,
#  '4)': 5792,
#  'określi,': 5615,
#  '1 pkt': 5591,
#  'o której': 5512,
#  'której mowa': 5502,
#  '3,': 5439,
#  '5.': 5246,
#  'w przypadku': 5096,
#  'od dnia': 5084,
#  'w zakresie': 5071,
#  'właściwy do': 4835,
#  'zastępuje się': 4776,
#  '"art.': 4709,
#  '| |': 4687,
#  'w ustawie': 4605,
#  'minister właściwy': 4282,
#  'oraz z': 4256,
#  'ustawy,': 4183,
#  'w życie': 4123,
#  '5)': 4030,
#  'określonych w': 4025,
#  'w tym': 3893,
#  'w terminie': 3838,
#  '(dz.': 3823,
#  'lit.': 3783,
#  '4,': 3756,
#  '106,': 3755,
#  'w pkt': 3746,
#  'a także': 3674,
#  'ustawie z': 3660,
#  '1 i': 3618,
#  'zmiany:': 3608,
#  '6.': 3203,
#  'w §': 3155,
#  'pracy,': 3114,
#  'ustawy z': 3056,
#  'w razie': 3028,
#  'się wyrazami': 2941,
#  'c)': 2886,
#  '6)': 2839,
#  'pkt 1': 2702,
#  'państwa,': 2694,
#  'może być': 2636,
#  'w celu': 2614,
#  'zgodnie z': 2542,
#  'skreśla się': 2499,
#  '5,': 2474,
#  'dni od': 2473,
#  'w szczególności': 2445,
#  '§ 1': 2419,
#  'u.': 2377,
#  'wejścia w': 2372,
#  'na wniosek': 2367,
#  'się w': 2332,
#  'z zastrzeżeniem': 2318,
#  'z tytułu': 2304,
#  'co najmniej': 2280,
#  '7.': 2180,
#  'się wyrazy': 2173,
#  'do dnia': 2162,
#  'w sprawach': 2148,
#  'a w': 2141,
#  'późn.': 2128,
#  'określone w': 2124,
#  'ustawy.': 2119,
#  '7)': 2093,
#  '2 pkt': 2091,
#  'rzeczypospolitej polskiej': 2067,
#  'się do': 2049,
#  'pkt 2': 2032,
#  'decyzji,': 2019,
#  '2 i': 1998,
#  'się,': 1972,
#  'nie może': 1959,
#  'środowiska,': 1930,
#  '6,': 1922,
#  'szczególności:': 1908,
#  'się odpowiednio': 1891,
#  'się następujące': 1855,
#  'wprowadza się': 1847,
#  'w sprawie': 1821,
#  'mogą być': 1820,
#  'odpowiednio.': 1808,
#  'w którym': 1800,
#  'się pkt': 1792,
#  '- w': 1791,
#  'z dniem': 1781,
#  'w rozumieniu': 1777,
#  'polskiej,': 1758,
#  'r.,': 1756,
#  'osób,': 1747,
#  'porozumieniu z': 1729,
#  '8.': 1714,
#  '121,': 1706,
#  'dz.': 1683,
#  'w porozumieniu': 1679,
#  'w wysokości': 1647,
#  'z 1997': 1639,
#  'osoby,': 1628,
#  'przypadku,': 1625,
#  'w przepisach': 1625,
#  'po upływie': 1615,
#  'właściwego do': 1599,
#  '1 otrzymuje': 1568,
#  '8)': 1557,
#  'lub w': 1551,
#  'się na': 1530,
#  'na zasadach': 1515,
#  'z 2000': 1506,
#  'dz.u.': 1503,
#  'z 1998': 1497,
#  '2 otrzymuje': 1476,
#  'z ministrem': 1469,
#  'wchodzi w': 1464,
#  'w związku': 1463,
#  'na terytorium': 1462,
#  'ministra właściwego': 1460,
#  '43,': 1457,
#  'przed dniem': 1451,
#  'd)': 1445,
#  'jest obowiązany': 1445,
#  'ustawy o': 1440,
#  'z wyjątkiem': 1415,
#  'nie stosuje': 1412,
#  'wraz z': 1411,
#  'względu na': 1402,
#  '7,': 1387,
#  'oraz w': 1378,
#  'w okresie': 1361,
#  'i w': 1356,
#  '12,': 1355,
#  'właściwym do': 1351,
#  '34,': 1350,
#  'w stosunku': 1349,
#  'publicznych,': 1342,
#  'z 1996': 1325,
#  '162,': 1309,
#  'o zmianie': 1297,
#  'związku z': 1292,
#  'tys.': 1290,
#  'chyba że': 1285,
#  'miesięcy od': 1283,
#  'czynności,': 1276,
#  '§ 2': 1275,
#  'pkt 3': 1274,
#  'w trybie': 1263,
#  'pracy.': 1249,
#  'prawo do': 1236,
#  'informacji,': 1228,
#  'terytorium rzeczypospolitej': 1219,
#  '141,': 1217,
#  '9)': 1216,
#  'do obrotu': 1210,
#  '9.': 1205,
#  'przez to': 1193,
#  'związanych z': 1189,
#  'ustawa z': 1187,
#  'ustawa wchodzi': 1184,
#  '1 stycznia': 1181,
#  'ze względu': 1180,
#  'stosunku do': 1177,
#  'przepisów o': 1173,
#  'z 1999': 1172,
#  'ministrem właściwym': 1164,
#  'w sposób': 1163,
#  'rozporządzenia:': 1160,
#  '28,': 1156,
#  '3 i': 1154,
#  'z uwzględnieniem': 1147,
#  'określonym w': 1147,
#  'i tryb': 1136,
#  '14 dni': 1126,
#  'lat,': 1122,
#  'w formie': 1117,
#  '§2.': 1117,
#  '60,': 1112,
#  '3 otrzymuje': 1102,
#  'na rzecz': 1096,
#  'może,': 1094,
#  'dnia 31': 1070,
#  'roku,': 1070,
#  'w ramach': 1065,
#  '10.': 1056,
#  'wymienionych w': 1049,
#  'ogłoszenia.': 1048,
#  '104,': 1045,
#  'w ciągu': 1043,
#  '88,': 1040,
#  '"2.': 1040,
#  'zasadach określonych': 1040,
#  'się z': 1038,
#  'państwa.': 1028,
#  '1 w': 1014,
#  '137,': 1014,
#  'ministrów,': 1010,
#  'spraw wewnętrznych': 1008,
#  'w postępowaniu': 1005,
#  'spraw finansów': 1004,
#  'dniem 1': 998,
#  'z 1994': 995,
#  'zdrowia,': 994,
#  '123,': 993,
#  'z 1995': 992,
#  'z 2001': 991,
#  '10)': 985,
#  'rozumie się': 982,
#  'pozbawienia wolności': 979,
#  'podlega karze': 970,
#  '11,': 967,
#  'kontroli,': 967,
#  'do czasu': 965,
#  'dnia wejścia': 965,
#  'w dniu': 964,
#  '§1.': 960,
#  'określa,': 954,
#  '113,': 954,
#  'zostały ogłoszone': 952,
#  'ogłoszone w': 950,
#  'policji,': 944,
#  'się przez': 943,
#  'inaczej.': 942,
#  'ustawy zostały': 940,
#  'oraz o': 937,
#  '31 grudnia': 936,
#  'po wyrazach': 934,
#  'wniosek o': 934,
#  '8,': 933,
#  'związane z': 929,
#  'w wyniku': 927,
#  'w których': 922,
#  'i innych': 922,
#  'wniosku,': 920,
#  'umowy,': 919,
#  'dniem wejścia': 919,
#  'określonego w': 915,
#  '96,': 911,
#  'w odniesieniu': 909,
#  'nie jest': 905,
#  '54,': 903,
#  '117,': 897,
#  '9,': 896,
#  'odniesieniu do': 894,
#  'i dodaje': 893,
#  '"3.': 893,
#  'pkt 4': 885,
#  'wymienionej ustawy': 885,
#  'terytorialnego,': 877,
#  'na czas': 874,
#  'ustawą,': 872,
#  '3 w': 871,
#  '„art.': 870,
#  'narodowej,': 864,
#  '90,': 861,
#  'danych,': 860,
#  'się przepisy': 857,
#  'wniosku o': 851,
#  'zmianie ustawy': 850,
#  'zwierząt,': 850,
#  'ustawie,': 849,
#  'i 2': 841,
#  '133,': 841,
#  'życie z': 836,
#  'podstawie przepisów': 836,
#  '"1.': 832,
#  '3 pkt': 830,
#  'prawa do': 829,
#  'życie niniejszej': 829,
#  'województwa,': 829,
#  'działalności,': 827,
#  'przypadkach,': 824,
#  'odpadów,': 824,
#  '107,': 822,
#  '110,': 821,
#  'życie po': 818,
#  '122,': 817,
#  'w czasie': 815,
#  'samorządu terytorialnego': 806,
#  'nie później': 802,
#  'spółki,': 801,
#  '- prawo': 800,
#  '98,': 798,
#  'z zakresu': 797,
#  '11)': 795,
#  'części,': 790,
#  'przypadku gdy': 787,
#  'wynikających z': 787,
#  'w skład': 787,
#  ',': 781,
#  'zadań,': 781,
#  'się o': 776,
#  'odpowiednio przepisy': 771,
#  'e)': 770,
#  '27,': 770,
#  'z tym': 769,
#  'zasięgnięciu opinii': 763,
#  'prawnych,': 763,
#  'szczegółowe zasady': 761,
#  'do:': 761,
#  'po zasięgnięciu': 761,
#  '10,': 759,
#  'do wykonywania': 759,
#  '41,': 758,
#  '45,': 756,
#  'sprawach,': 752,
#  'się:': 750,
#  'w roku': 748,
#  'ochrony środowiska': 748,
#  '75,': 744,
#  'gospodarczej,': 744,
#  'skarbu państwa': 743,
#  'finansów publicznych': 743,
#  'prawnej,': 740,
#  'do rejestru': 739,
#  'odpowiednio do': 734,
#  '22,': 734,
#  'spraw gospodarki': 730,
#  'umowy o': 725,
#  '86,': 725,
#  'i ich': 724,
#  '11.': 723,
#  '4 otrzymuje': 722,
#  '2 w': 721,
#  'z wyłączeniem': 719,
#  '120,': 718,
#  '19,': 717,
#  'wewnętrznych,': 716,
#  '48,': 715,
#  'się wyrazem': 713,
#  'dnia 29': 711,
#  'zezwolenia,': 711,
#  'urzędu,': 711,
#  'wniosek,': 707,
#  'z przepisami': 705,
#  'ustala się': 704,
#  'przez ministra': 701,
#  'kraju,': 700,
#  '12.': 700,
#  'zezwolenia na': 700,
#  'rady ministrów': 698,
#  '24,': 697,
#  'publicznej,': 696,
#  'osoba,': 695,
#  'przepisów,': 693,
#  'przez okres': 692,
#  'na obszarze': 690,
#  'wymienione w': 689,
#  'co do': 688,
#  '74,': 688,
#  'później niż': 687,
#  '70,': 685,
#  'terminie do': 684,
#  'zakresie,': 684,
#  '95,': 684,
#  'europejskiej,': 684,
#  'granicznej,': 684,
#  'o ochronie': 682,
#  'pkt 5': 681,
#  'działalności gospodarczej': 681,
#  '49,': 681,
#  'rada ministrów': 679,
#  '89,': 678,
#  'jednak niż': 677,
#  'w brzmieniu': 677,
#  'określony w': 676,
#  'jeżeli w': 675,
#  '12)': 673,
#  'na okres': 672,
#  'informacji o': 671,
#  '4 i': 671,
#  '21,': 670,
#  'dnia 30': 668,
#  '80,': 668,
#  'nieruchomości,': 667,
#  '111,': 665,
#  'zarządzenia,': 663,
#  'postępowania,': 663,
#  'wojskowej,': 660,
#  'są:': 660,
#  'po pkt': 660,
#  '§3.': 660,
#  'rozumieniu przepisów': 659,
#  'uchyla się': 655,
#  'i 3': 652,
#  '30 dni': 651,
#  'kodeksu postępowania': 649,
#  'życie ustawy': 649,
#  '25,': 647,
#  'w części': 647,
#  '1 wyrazy': 647,
#  'o wydanie': 647,
#  'unii europejskiej': 646,
#  '160,': 646,
#  'obrotu,': 644,
#  '§ 3': 644,
#  'kropkę zastępuje': 643,
#  'miesięcy,': 642,
#  'sprawiedliwości,': 637,
#  'pracy w': 637,
#  'gminy,': 637,
#  'polskiej.': 636,
#  'w wypadku': 636,
#  'do lat': 636,
#  'się.': 635,
#  'ustawę z': 635,
#  'budżetu państwa': 631,
#  'ze środków': 631,
#  'jeżeli nie': 626,
#  '72,': 626,
#  'przepisów ustawy': 624,
#  'terminie,': 623,
#  'w tych': 622,
#  '91,': 621,
#  '2 wyrazy': 620,
#  'przez niego': 620,
#  '4 w': 619,
#  'opieki zdrowotnej': 617,
#  'z 1991': 616,
#  'prawa,': 616,
#  'karnego,': 614,
#  '2 dodaje': 611,
#  'zł.': 610,
#  'administracji rządowej': 608,
#  '1:': 608,
#  'mając na': 607,
#  'dnia 1': 607,
#  'o ile': 606,
#  'określić,': 605,
#  'na terenie': 604,
#  'postępowania w': 604,
#  'służby,': 603,
#  'z 2003': 601,
#  'określonej w': 598,
#  'więcej niż': 598,
#  'z 2004': 598,
#  'dokumentów,': 596,
#  '94,': 595,
#  '73,': 595,
#  '20,': 595,
#  'lub jego': 595,
#  '13.': 594,
#  '- rozumie': 594,
#  'społecznej,': 593,
#  'towarów,': 593,
#  'obrony narodowej': 591,
#  'lat.': 590,
#  'spraw zdrowia': 590,
#  '83,': 588,
#  'środowiska.': 588,
#  '26,': 586,
#  '1 dodaje': 585,
#  '100,': 584,
#  'nie mogą': 583,
#  'okoliczności,': 583,
#  'przepisach o': 582,
#  '6 miesięcy': 582,
#  'gospodarki,': 580,
#  '13)': 577,
#  'uważa się': 575,
#  'prezes rady': 575,
#  'z 2002': 573,
#  'i na': 572,
#  '101,': 570,
#  'zasady i': 569,
#  'się przecinkiem': 568,
#  'pracy i': 568,
#  'cywilnej,': 568,
#  'jednostki samorządu': 566,
#  'dnia 26': 566,
#  'zmienianej w': 564,
#  'produktu leczniczego': 561,
#  'informacje o': 558,
#  'usług,': 558,
#  'ogłoszenia,': 557,
#  'ustawy zmienianej': 556,
#  '35,': 555,
#  'niniejszej ustawy': 554,
#  'rejestru,': 554,
#  '85,': 554,
#  'lub na': 553,
#  '"4.': 552,
#  'upływie 14': 552,
#  'sposób,': 552,
#  'po wyrazie': 551,
#  'na:': 550,
#  'o:': 547,
#  'dni,': 546,
#  'przez prezesa': 545,
#  'wydanych na': 545,
#  'funduszu,': 544,
#  'przepisy ustawy': 543,
#  '14.': 539,
#  'urzędu.': 538,
#  'zł,': 537,
#  'dnia,': 536,
#  'sprawach o': 536,
#  'z 1993': 535,
#  'sierpnia 1997': 535,
#  'w całości': 534,
#  '50,': 534,
#  '153,': 533,
#  'i z': 533,
#  'o podatku': 533,
#  '1 ustawy': 532,
#  'z wnioskiem': 532,
#  'lat od': 531,
#  'towarów i': 530,
#  'udziału w': 529,
#  'społecznych,': 529,
#  'dnia 20': 528,
#  'od osób': 524,
#  'i gospodarki': 524,
#  'finansowych,': 524,
#  'środków,': 523,
#  '3 miesięcy': 522,
#  'i sposób': 521,
#  'zmiany tekstu': 519,
#  'zdrowotnej,': 518,
#  '14)': 517,
#  'tym że': 517,
#  'tekstu jednolitego': 515,
#  '155,': 515,
#  '39,': 514,
#  'pracowników,': 514,
#  'warunki,': 514,
#  'str.': 514,
#  'państwowej straży': 512,
#  'decyzji o': 512,
#  '64,': 511,
#  'ubezpieczeń społecznych': 511,
#  'nadzór nad': 509,
#  'się za': 509,
#  'z budżetu': 508,
#  'podstawie odrębnych': 506,
#  'w dzienniku': 506,
#  'wolności,': 506,
#  '139,': 506,
#  '1 po': 505,
#  'dnia 6': 504,
#  '14,': 504,
#  'sądu,': 503,
#  '114,': 503,
#  'następuje w': 502,
#  'niż w': 501,
#  '...,': 501,
#  '15.': 500,
#  'informację o': 500,
#  'wynagrodzenia,': 499,
#  'prezes urzędu': 498,
#  'urz.': 497,
#  'jednolitego wymienionej': 497,
#  '17,': 496,
#  'przecinkiem i': 496,
#  'do sądu': 496,
#  'i nie': 496,
#  '5 w': 495,
#  'nie dłużej': 495,
#  'przestępstwa,': 495,
#  'w odrębnych': 494,
#  'informacje,': 492,
#  'na ubezpieczenie': 492,
#  'publicznych.': 492,
#  'pkt 6': 490,
#  '16,': 489,
#  'właściwemu do': 488,
#  'i jego': 486,
#  'przed upływem': 486,
#  'oraz ich': 484,
#  'o udzielenie': 483,
#  'na cele': 482,
#  'udział w': 482,
#  'z 1990': 482,
#  'dłuższy niż': 481,
#  '84,': 481,
#  'dnia 27': 480,
#  'organ,': 480,
#  'wynikające z': 478,
#  '63,': 478,
#  'osobie,': 478,
#  'z powodu': 477,
#  '132,': 477,
#  'ustawie.': 475,
#  'transportu,': 475,
#  '118,': 475,
#  '93,': 474,
#  'dane,': 473,
#  'papierów wartościowych': 472,
#  'warunki i': 471,
#  'do pracy': 471,
#  'karze pozbawienia': 471,
#  'lub innych': 470,
#  '4 pkt': 470,
#  '1 lub': 470,
#  'publicznego,': 470,
#  '99,': 470,
#  'korzystania z': 469,
#  'straży granicznej': 468,
#  'jeżeli:': 468,
#  'miesięcy.': 468,
#  'przepisy o': 468,
#  'wnioskiem o': 467,
#  '(m/m),': 466,
#  'z 1992': 465,
#  'nie dotyczy': 463,
#  'podmiot,': 463,
#  'jednostek organizacyjnych': 462,
#  'grzywny.': 462,
#  '15)': 461,
#  'f)': 461,
#  'się od': 461,
#  '16.': 460,
#  '31,': 460,
#  '– w': 459,
#  '13,': 459,
#  'dnia 21': 458,
#  '5 i': 458,
#  'urzędu ochrony': 458,
#  'na prowadzenie': 458,
#  '7 dni': 457,
#  'jednostki,': 456,
#  '1a w': 455,
#  'tym:': 454,
#  'w przypadkach': 454,
#  'oraz innych': 454,
#  'jednostek samorządu': 454,
#  'postępowania.': 454,
#  'jest to': 453,
#  'karnego.': 452,
#  '62,': 451,
#  'od daty': 450,
#  'celnego,': 450,
#  'dyscyplinarnego,': 449,
#  'minister obrony': 448,
#  'wolności do': 447,
#  '5 otrzymuje': 446,
#  'służby cywilnej': 446,
#  'terminie 14': 445,
#  'na jego': 443,
#  'zezwolenie na': 443,
#  'osobę,': 443,
#  'zawodowych,': 442,
#  '79,': 442,
#  '157,': 442,
#  '40,': 442,
#  'przedsiębiorcy,': 442,
#  'wymienionej w': 440,
#  '105,': 440,
#  'z 2006': 440,
#  'rządowej,': 440,
#  'działania,': 439,
#  '17.': 438,
#  'składek na': 438,
#  'podmiotu,': 438,
#  'i 4': 437,
#  'warunków,': 437,
#  '30,': 437,
#  'przez organ': 436,
#  'wewnętrznych i': 436,
#  '18,': 436,
#  'pozwolenia,': 436,
#  'do prowadzenia': 435,
#  '53,': 434,
#  'minister sprawiedliwości': 434,
#  'lub ich': 434,
#  'jak również': 434,
#  'albo w': 433,
#  'za zgodą': 433,
#  'nie są': 433,
#  'środowisko,': 433,
#  '52,': 432,
#  'należności,': 432,
#  'obowiązany do': 431,
#  '1 nie': 429,
#  '55,': 429,
#  'lub z': 429,
#  '127,': 429,
#  'dnia 24': 428,
#  'w której': 428,
#  'leczniczych,': 428,
#  'w danym': 427,
#  'o tym': 427,
#  'roku.': 427,
#  'brzmieniu nadanym': 427,
#  'świadczeń,': 427,
#  'w toku': 427,
#  'dnia 15': 425,
#  'rozumieniu ustawy': 425,
#  '169,': 425,
#  'ministrowi właściwemu': 424,
#  'polskiego,': 424,
#  'z 2005': 420,
#  'terminu,': 420,
#  'i inne': 418,
#  'oraz sposób': 418,
#  'ustawą.': 418,
#  '(we)': 418,
#  'podatkowego,': 417,
#  '154,': 416,
#  'nie można': 415,
#  'w załączniku': 415,
#  'nadanym niniejszą': 415,
#  'inaczej,': 414,
#  '2 ustawy': 414,
#  '124,': 413,
#  'ma prawo': 410,
#  'zdrowia i': 410,
#  '16)': 409,
#  'na dzień': 409,
#  '18.': 409,
#  'się §': 409,
#  'podmiotów,': 408,
#  'przewidzianych w': 407,
#  'opłat,': 407,
#  'głównego urzędu': 407,
#  'kontroli.': 406,
#  '33,': 405,
#  'opłaty,': 404,
#  '19.': 404,
#  '47,': 404,
#  'decyzji.': 404,
#  'do których': 403,
#  'postanowienia,': 402,
#  '– prawo': 402,
#  'z mocy': 402,
#  'powiatu,': 402,
#  'niezbędne do': 401,
#  'w tej': 400,
#  'grzywnie,': 400,
#  '20.': 398,
#  '149,': 398,
#  'dnia 17': 397,
#  'badań,': 397,
#  'produktów leczniczych': 397,
#  '3 dodaje': 396,
#  'komisji,': 394,
#  '29,': 394,
#  '32,': 394,
#  '156,': 394,
#  'przepisów.': 394,
#  'niż do': 393,
#  'na żądanie': 393,
#  '42,': 393,
#  '1-3,': 392,
#  '38,': 392,
#  '6 w': 391,
#  '115,': 390,
#  'może nastąpić': 389,
#  'po dniu': 388,
#  'pomocy,': 388,
#  'zarządu,': 388,
#  'podstawie umowy': 387,
#  'ue l': 387,
#  '136,': 385,
#  'zatrudnienia,': 385,
#  'sąd może': 384,
#  'na względzie': 383,
#  'pkt 7': 383,
#  'ustawy -': 383,
#  'stają się': 383,
#  'zmiany wymienionej': 383,
#  '2 stosuje': 383,
#  '2a w': 383,
#  '2:': 382,
#  'przepisach,': 382,
#  'województwa.': 382,
#  '"ust.': 382,
#  'na końcu': 381,
#  'podatku od': 381,
#  'na celu': 380,
#  'pracy lub': 380,
#  'o postępowaniu': 380,
#  '17)': 379,
#  'także w': 379,
#  'z 1989': 379,
#  'spraw środowiska': 379,
#  'i usług': 379,
#  '44,': 378,
#  'za pośrednictwem': 377,
#  'użyte w': 377,
#  'dzienniku urzędowym': 377,
#  'leczniczego,': 376,
#  'granicą,': 374,
#  '2;': 374,
#  'z tego': 373,
#  'są obowiązani': 373,
#  '3 wyrazy': 373,
#  'państwowych,': 372,
#  'rozporządzeniu,': 372,
#  'w rzeczypospolitej': 372,
#  'obowiązany jest': 372,
#  '21.': 371,
#  'służby wojskowej': 371,
#  'państwa członkowskiego': 371,
#  'rolnych,': 370,
#  '15,': 370,
#  '(efta)': 370,
#  '1 stosuje': 368,
#  'spółki.': 368,
#  'na ich': 367,
#  'należy przez': 367,
#  'wtedy,': 366,
#  'do tego': 365,
#  'rolnictwa,': 365,
#  'umowy.': 364,
#  'po uzyskaniu': 364,
#  '23,': 364,
#  'finansów,': 364,
#  'wartościowych,': 364,
#  'z tych': 363,
#  'o charakterze': 363,
#  'uwzględniając w': 363,
#  'miesiąca,': 362,
#  'przepisach.': 362,
#  'właściwy organ': 362,
#  'dnia 16': 361,
#  'całości lub': 361,
#  'prawo o': 360,
#  'do ich': 360,
#  'sąd,': 360,
#  'należy:': 359,
#  '25.': 359,
#  'organu,': 359,
#  'trybie określonym': 359,
#  'wykonywania zawodu': 359,
#  'z urzędu': 358,
#  'oraz na': 357,
#  'się również': 357,
#  'oraz inne': 356,
#  'wydane na': 356,
#  'zawierać:': 356,
#  '§4.': 356,
#  'zgodę na': 355,
#  'w zdaniu': 355,
#  'dokonuje się': 355,
#  '119,': 355,
#  'z innych': 354,
#  '2 oraz': 353,
#  'zawiera:': 353,
#  'nie dłuższy': 353,
#  'to rozumieć': 353,
#  'weterynarii,': 353,
#  'terminie 7': 352,
#  'rady,': 351,
#  '130,': 351,
#  'międzynarodowych,': 350,
#  'wyrazy "i': 350,
#  'uchwały,': 350,
#  'które nie': 349,
#  'ograniczenia wolności': 349,
#  'okresu,': 348,
#  'ministrów.': 348,
#  'na miejsce': 347,
#  'terminie 30': 347,
#  'statku,': 346,
#  'w imieniu': 345,
#  'z działalności': 345,
#  'tej samej': 345,
#  '163,': 344,
#  'prawa.': 344,
#  'podmioty,': 344,
#  'innych niż': 344,
#  'z chwilą': 344,
#  '2 po': 344,
#  'administracji publicznej': 344,
#  'do którego': 343,
#  '18)': 342,
#  'dniu wejścia': 342,
#  'zawartych w': 341,
#  '„1.': 341,
#  'zagranicznych,': 341,
#  'roślin,': 341,
#  'jeżeli jest': 341,
#  'i opieki': 340,
#  'kary,': 340,
#  '36,': 339,
#  'ustawy wymienionej': 338,
#  '1 oraz': 338,
#  '116,': 338,
#  'prezydenta rzeczypospolitej': 337,
#  'osób prawnych': 337,
#  '144,': 337,
#  'się jako': 335,
#  'i odwołuje': 335,
#  'zawodowej służby': 335,
#  'jednostki organizacyjne': 335,
#  'szczegółowe warunki': 335,
#  'nie przekracza': 334,
#  '109,': 334,
#  'kosztów,': 334,
#  '"5.': 333,
#  'do zadań': 332,
#  'niezdolności do': 332,
#  'wypadku,': 331,
#  'nie ma': 331,
#  'składek,': 331,
#  '3;': 331,
#  '22.': 330,
#  '§ 4': 330,
#  'dni.': 330,
#  'gmin,': 330,
#  'funduszu.': 330,
#  'europejskiej.': 330,
#  '1;': 329,
#  '78,': 328,
#  'zadania,': 328,
#  '140,': 328,
#  'celny,': 328,
#  'z 2007': 327,
#  'przez osoby': 326,
#  'lub innego': 326,
#  'przyrody,': 326,
#  'wyrobów akcyzowych': 326,
#  'pod warunkiem': 325,
#  'świadczenia,': 325,
#  'przeznaczone do': 323,
#  'na potrzeby': 323,
#  'decyzję o': 323,
#  'fizycznych,': 323,
#  'dnia 13': 323,
#  '134,': 323,
#  'polski obszar': 323,
#  'agencji,': 322,
#  'do wysokości': 322,
#  'w stanie': 322,
#  'do celów': 322,
#  'sposób i': 322,
#  '23.': 321,
#  'z funduszu': 321,
#  '"1a.': 320,
#  'rok,': 320,
#  'środków trwałych': 320,
#  'i ochrony': 320,
#  'główny inspektor': 320,
#  '171,': 319,
#  'towaru,': 319,
#  'są obowiązane': 318,
#  'lata,': 318,
#  'jednostki organizacyjnej': 318,
#  'wchodzą w': 318,
#  'pożarnej,': 318,
#  '66,': 318,
#  'wolności albo': 318,
#  'ubezpieczeń,': 318,
#  'sprawy.': 318,
#  'przepisami,': 317,
#  ':': 317,
#  'prezesa urzędu': 317,
#  'powinny być': 316,
#  'krajowej rady': 315,
#  'wyrazy "w': 315,
#  '240,': 315,
#  'stycznia 1999': 315,
#  'produkcji,': 315,
#  '24.': 314,
#  '77,': 314,
#  'podatku,': 314,
#  'zwany dalej': 314,
#  'medycznych,': 314,
#  'za granicą': 314,
#  'niezależnie od': 313,
#  'niezbędnych do': 313,
#  'wyrazy "lub': 313,
#  'przedsiębiorców,': 313,
#  'spółdzielni,': 313,
#  'postępowania karnego': 312,
#  '26.': 312,
#  'służby.': 312,
#  'podatkowy,': 312,
#  '180,': 312,
#  'stosunku pracy': 312,
#  ...}

# %% [markdown]
# # 3. Discard bigrams containing characters other than letters. Make sure that you discard the invalid entries after computing the bigram counts:

# %%
bigrams_dictionary_copy = bigrams_dictionary.copy()
for k in bigrams_dictionary.keys():
    new_key = k.replace(" ", "")
    if not new_key.isalpha():
       del  bigrams_dictionary_copy[k]

bigrams_dictionary = bigrams_dictionary_copy
bigrams_dictionary
# Out:
# {'mowa w': 28450,
#  'których mowa': 13847,
#  'o których': 13839,
#  'z dnia': 9513,
#  'którym mowa': 9165,
#  'o którym': 9155,
#  'do spraw': 8680,
#  'i nr': 8435,
#  'dodaje się': 8190,
#  'w drodze': 7092,
#  'na podstawie': 6610,
#  'stosuje się': 6030,
#  'o której': 5512,
#  'której mowa': 5502,
#  'w przypadku': 5096,
#  'od dnia': 5084,
#  'w zakresie': 5071,
#  'właściwy do': 4835,
#  'zastępuje się': 4776,
#  'w ustawie': 4605,
#  'minister właściwy': 4282,
#  'oraz z': 4256,
#  'w życie': 4123,
#  'określonych w': 4025,
#  'w tym': 3893,
#  'w terminie': 3838,
#  'w pkt': 3746,
#  'a także': 3674,
#  'ustawie z': 3660,
#  'ustawy z': 3056,
#  'w razie': 3028,
#  'się wyrazami': 2941,
#  'może być': 2636,
#  'w celu': 2614,
#  'zgodnie z': 2542,
#  'skreśla się': 2499,
#  'dni od': 2473,
#  'w szczególności': 2445,
#  'wejścia w': 2372,
#  'na wniosek': 2367,
#  'się w': 2332,
#  'z zastrzeżeniem': 2318,
#  'z tytułu': 2304,
#  'co najmniej': 2280,
#  'się wyrazy': 2173,
#  'do dnia': 2162,
#  'w sprawach': 2148,
#  'a w': 2141,
#  'określone w': 2124,
#  'rzeczypospolitej polskiej': 2067,
#  'się do': 2049,
#  'nie może': 1959,
#  'się odpowiednio': 1891,
#  'się następujące': 1855,
#  'wprowadza się': 1847,
#  'w sprawie': 1821,
#  'mogą być': 1820,
#  'w którym': 1800,
#  'się pkt': 1792,
#  'z dniem': 1781,
#  'w rozumieniu': 1777,
#  'porozumieniu z': 1729,
#  'w porozumieniu': 1679,
#  'w wysokości': 1647,
#  'w przepisach': 1625,
#  'po upływie': 1615,
#  'właściwego do': 1599,
#  'lub w': 1551,
#  'się na': 1530,
#  'na zasadach': 1515,
#  'z ministrem': 1469,
#  'wchodzi w': 1464,
#  'w związku': 1463,
#  'na terytorium': 1462,
#  'ministra właściwego': 1460,
#  'przed dniem': 1451,
#  'jest obowiązany': 1445,
#  'ustawy o': 1440,
#  'z wyjątkiem': 1415,
#  'nie stosuje': 1412,
#  'wraz z': 1411,
#  'względu na': 1402,
#  'oraz w': 1378,
#  'w okresie': 1361,
#  'i w': 1356,
#  'właściwym do': 1351,
#  'w stosunku': 1349,
#  'o zmianie': 1297,
#  'związku z': 1292,
#  'chyba że': 1285,
#  'miesięcy od': 1283,
#  'w trybie': 1263,
#  'prawo do': 1236,
#  'terytorium rzeczypospolitej': 1219,
#  'do obrotu': 1210,
#  'przez to': 1193,
#  'związanych z': 1189,
#  'ustawa z': 1187,
#  'ustawa wchodzi': 1184,
#  'ze względu': 1180,
#  'stosunku do': 1177,
#  'przepisów o': 1173,
#  'ministrem właściwym': 1164,
#  'w sposób': 1163,
#  'z uwzględnieniem': 1147,
#  'określonym w': 1147,
#  'i tryb': 1136,
#  'w formie': 1117,
#  'na rzecz': 1096,
#  'w ramach': 1065,
#  'wymienionych w': 1049,
#  'w ciągu': 1043,
#  'zasadach określonych': 1040,
#  'się z': 1038,
#  'spraw wewnętrznych': 1008,
#  'w postępowaniu': 1005,
#  'spraw finansów': 1004,
#  'rozumie się': 982,
#  'pozbawienia wolności': 979,
#  'podlega karze': 970,
#  'do czasu': 965,
#  'dnia wejścia': 965,
#  'w dniu': 964,
#  'zostały ogłoszone': 952,
#  'ogłoszone w': 950,
#  'się przez': 943,
#  'ustawy zostały': 940,
#  'oraz o': 937,
#  'po wyrazach': 934,
#  'wniosek o': 934,
#  'związane z': 929,
#  'w wyniku': 927,
#  'w których': 922,
#  'i innych': 922,
#  'dniem wejścia': 919,
#  'określonego w': 915,
#  'w odniesieniu': 909,
#  'nie jest': 905,
#  'odniesieniu do': 894,
#  'i dodaje': 893,
#  'wymienionej ustawy': 885,
#  'na czas': 874,
#  'się przepisy': 857,
#  'wniosku o': 851,
#  'zmianie ustawy': 850,
#  'życie z': 836,
#  'podstawie przepisów': 836,
#  'prawa do': 829,
#  'życie niniejszej': 829,
#  'życie po': 818,
#  'w czasie': 815,
#  'samorządu terytorialnego': 806,
#  'nie później': 802,
#  'z zakresu': 797,
#  'przypadku gdy': 787,
#  'wynikających z': 787,
#  'w skład': 787,
#  'się o': 776,
#  'odpowiednio przepisy': 771,
#  'z tym': 769,
#  'zasięgnięciu opinii': 763,
#  'szczegółowe zasady': 761,
#  'po zasięgnięciu': 761,
#  'do wykonywania': 759,
#  'w roku': 748,
#  'ochrony środowiska': 748,
#  'skarbu państwa': 743,
#  'finansów publicznych': 743,
#  'do rejestru': 739,
#  'odpowiednio do': 734,
#  'spraw gospodarki': 730,
#  'umowy o': 725,
#  'i ich': 724,
#  'z wyłączeniem': 719,
#  'się wyrazem': 713,
#  'z przepisami': 705,
#  'ustala się': 704,
#  'przez ministra': 701,
#  'zezwolenia na': 700,
#  'rady ministrów': 698,
#  'przez okres': 692,
#  'na obszarze': 690,
#  'wymienione w': 689,
#  'co do': 688,
#  'później niż': 687,
#  'terminie do': 684,
#  'o ochronie': 682,
#  'działalności gospodarczej': 681,
#  'rada ministrów': 679,
#  'jednak niż': 677,
#  'w brzmieniu': 677,
#  'określony w': 676,
#  'jeżeli w': 675,
#  'na okres': 672,
#  'informacji o': 671,
#  'po pkt': 660,
#  'rozumieniu przepisów': 659,
#  'uchyla się': 655,
#  'kodeksu postępowania': 649,
#  'życie ustawy': 649,
#  'w części': 647,
#  'o wydanie': 647,
#  'unii europejskiej': 646,
#  'kropkę zastępuje': 643,
#  'pracy w': 637,
#  'w wypadku': 636,
#  'do lat': 636,
#  'ustawę z': 635,
#  'budżetu państwa': 631,
#  'ze środków': 631,
#  'jeżeli nie': 626,
#  'przepisów ustawy': 624,
#  'w tych': 622,
#  'przez niego': 620,
#  'opieki zdrowotnej': 617,
#  'administracji rządowej': 608,
#  'mając na': 607,
#  'o ile': 606,
#  'na terenie': 604,
#  'postępowania w': 604,
#  'określonej w': 598,
#  'więcej niż': 598,
#  'lub jego': 595,
#  'obrony narodowej': 591,
#  'spraw zdrowia': 590,
#  'nie mogą': 583,
#  'przepisach o': 582,
#  'uważa się': 575,
#  'prezes rady': 575,
#  'i na': 572,
#  'zasady i': 569,
#  'się przecinkiem': 568,
#  'pracy i': 568,
#  'jednostki samorządu': 566,
#  'zmienianej w': 564,
#  'produktu leczniczego': 561,
#  'informacje o': 558,
#  'ustawy zmienianej': 556,
#  'niniejszej ustawy': 554,
#  'lub na': 553,
#  'po wyrazie': 551,
#  'przez prezesa': 545,
#  'wydanych na': 545,
#  'przepisy ustawy': 543,
#  'sprawach o': 536,
#  'w całości': 534,
#  'i z': 533,
#  'o podatku': 533,
#  'z wnioskiem': 532,
#  'lat od': 531,
#  'towarów i': 530,
#  'udziału w': 529,
#  'od osób': 524,
#  'i gospodarki': 524,
#  'i sposób': 521,
#  'zmiany tekstu': 519,
#  'tym że': 517,
#  'tekstu jednolitego': 515,
#  'państwowej straży': 512,
#  'decyzji o': 512,
#  'ubezpieczeń społecznych': 511,
#  'nadzór nad': 509,
#  'się za': 509,
#  'z budżetu': 508,
#  'podstawie odrębnych': 506,
#  'w dzienniku': 506,
#  'następuje w': 502,
#  'niż w': 501,
#  'informację o': 500,
#  'prezes urzędu': 498,
#  'jednolitego wymienionej': 497,
#  'przecinkiem i': 496,
#  'do sądu': 496,
#  'i nie': 496,
#  'nie dłużej': 495,
#  'w odrębnych': 494,
#  'na ubezpieczenie': 492,
#  'właściwemu do': 488,
#  'i jego': 486,
#  'przed upływem': 486,
#  'oraz ich': 484,
#  'o udzielenie': 483,
#  'na cele': 482,
#  'udział w': 482,
#  'dłuższy niż': 481,
#  'wynikające z': 478,
#  'z powodu': 477,
#  'papierów wartościowych': 472,
#  'warunki i': 471,
#  'do pracy': 471,
#  'karze pozbawienia': 471,
#  'lub innych': 470,
#  'korzystania z': 469,
#  'straży granicznej': 468,
#  'przepisy o': 468,
#  'wnioskiem o': 467,
#  'nie dotyczy': 463,
#  'jednostek organizacyjnych': 462,
#  'się od': 461,
#  'urzędu ochrony': 458,
#  'na prowadzenie': 458,
#  'w przypadkach': 454,
#  'oraz innych': 454,
#  'jednostek samorządu': 454,
#  'jest to': 453,
#  'od daty': 450,
#  'minister obrony': 448,
#  'wolności do': 447,
#  'służby cywilnej': 446,
#  'na jego': 443,
#  'zezwolenie na': 443,
#  'wymienionej w': 440,
#  'składek na': 438,
#  'przez organ': 436,
#  'wewnętrznych i': 436,
#  'do prowadzenia': 435,
#  'minister sprawiedliwości': 434,
#  'lub ich': 434,
#  'jak również': 434,
#  'albo w': 433,
#  'za zgodą': 433,
#  'nie są': 433,
#  'obowiązany do': 431,
#  'lub z': 429,
#  'w której': 428,
#  'w danym': 427,
#  'o tym': 427,
#  'brzmieniu nadanym': 427,
#  'w toku': 427,
#  'rozumieniu ustawy': 425,
#  'ministrowi właściwemu': 424,
#  'i inne': 418,
#  'oraz sposób': 418,
#  'nie można': 415,
#  'w załączniku': 415,
#  'nadanym niniejszą': 415,
#  'ma prawo': 410,
#  'zdrowia i': 410,
#  'na dzień': 409,
#  'przewidzianych w': 407,
#  'głównego urzędu': 407,
#  'do których': 403,
#  'z mocy': 402,
#  'niezbędne do': 401,
#  'w tej': 400,
#  'produktów leczniczych': 397,
#  'niż do': 393,
#  'na żądanie': 393,
#  'może nastąpić': 389,
#  'po dniu': 388,
#  'podstawie umowy': 387,
#  'ue l': 387,
#  'sąd może': 384,
#  'na względzie': 383,
#  'stają się': 383,
#  'zmiany wymienionej': 383,
#  'na końcu': 381,
#  'podatku od': 381,
#  'na celu': 380,
#  'pracy lub': 380,
#  'o postępowaniu': 380,
#  'także w': 379,
#  'spraw środowiska': 379,
#  'i usług': 379,
#  'za pośrednictwem': 377,
#  'użyte w': 377,
#  'dzienniku urzędowym': 377,
#  'z tego': 373,
#  'są obowiązani': 373,
#  'w rzeczypospolitej': 372,
#  'obowiązany jest': 372,
#  'służby wojskowej': 371,
#  'państwa członkowskiego': 371,
#  'na ich': 367,
#  'należy przez': 367,
#  'do tego': 365,
#  'po uzyskaniu': 364,
#  'z tych': 363,
#  'o charakterze': 363,
#  'uwzględniając w': 363,
#  'właściwy organ': 362,
#  'całości lub': 361,
#  'prawo o': 360,
#  'do ich': 360,
#  'trybie określonym': 359,
#  'wykonywania zawodu': 359,
#  'z urzędu': 358,
#  'oraz na': 357,
#  'się również': 357,
#  'oraz inne': 356,
#  'wydane na': 356,
#  'zgodę na': 355,
#  'w zdaniu': 355,
#  'dokonuje się': 355,
#  'z innych': 354,
#  'nie dłuższy': 353,
#  'to rozumieć': 353,
#  'które nie': 349,
#  'ograniczenia wolności': 349,
#  'na miejsce': 347,
#  'w imieniu': 345,
#  'z działalności': 345,
#  'tej samej': 345,
#  'innych niż': 344,
#  'z chwilą': 344,
#  'administracji publicznej': 344,
#  'do którego': 343,
#  'dniu wejścia': 342,
#  'zawartych w': 341,
#  'jeżeli jest': 341,
#  'i opieki': 340,
#  'ustawy wymienionej': 338,
#  'prezydenta rzeczypospolitej': 337,
#  'osób prawnych': 337,
#  'się jako': 335,
#  'i odwołuje': 335,
#  'zawodowej służby': 335,
#  'jednostki organizacyjne': 335,
#  'szczegółowe warunki': 335,
#  'nie przekracza': 334,
#  'do zadań': 332,
#  'niezdolności do': 332,
#  'nie ma': 331,
#  'przez osoby': 326,
#  'lub innego': 326,
#  'wyrobów akcyzowych': 326,
#  'pod warunkiem': 325,
#  'przeznaczone do': 323,
#  'na potrzeby': 323,
#  'decyzję o': 323,
#  'polski obszar': 323,
#  'do wysokości': 322,
#  'w stanie': 322,
#  'do celów': 322,
#  'sposób i': 322,
#  'z funduszu': 321,
#  'środków trwałych': 320,
#  'i ochrony': 320,
#  'główny inspektor': 320,
#  'są obowiązane': 318,
#  'jednostki organizacyjnej': 318,
#  'wchodzą w': 318,
#  'wolności albo': 318,
#  'prezesa urzędu': 317,
#  'powinny być': 316,
#  'krajowej rady': 315,
#  'zwany dalej': 314,
#  'za granicą': 314,
#  'niezależnie od': 313,
#  'niezbędnych do': 313,
#  'postępowania karnego': 312,
#  'stosunku pracy': 312,
#  'państwa w': 312,
#  'powołuje i': 311,
#  'skarb państwa': 311,
#  'dochodowym od': 310,
#  'składki na': 310,
#  'w takim': 309,
#  'pod uwagę': 309,
#  'na piśmie': 309,
#  'dłużej jednak': 308,
#  'w dziedzinie': 308,
#  'osób fizycznych': 308,
#  'imię i': 307,
#  'przepisach wydanych': 307,
#  'nadzoru nad': 306,
#  'organ celny': 306,
#  'w granicach': 305,
#  'wpisu do': 304,
#  'prezes sądu': 304,
#  'o systemie': 304,
#  'miejsce zamieszkania': 304,
#  'spraw rolnictwa': 303,
#  'drodze decyzji': 303,
#  'z zachowaniem': 303,
#  'załączniku nr': 302,
#  'na stanowisko': 300,
#  'postępowanie w': 300,
#  'sposób określony': 299,
#  'w każdym': 298,
#  'inne niż': 298,
#  'dnia doręczenia': 297,
#  'tekst ustawy': 297,
#  'zagospodarowania przestrzennego': 297,
#  'lub więcej': 297,
#  'lub nie': 297,
#  'nie stanowi': 296,
#  'w zależności': 296,
#  'podatku dochodowym': 295,
#  'dnia otrzymania': 294,
#  'przepisy kodeksu': 293,
#  'w kraju': 292,
#  'oraz do': 292,
#  'lub do': 291,
#  'zależności od': 291,
#  'następuje na': 291,
#  'opłat za': 291,
#  'z przyczyn': 290,
#  'organy administracji': 290,
#  'zmianie niektórych': 289,
#  'tworzy się': 289,
#  'bezpieczeństwa i': 289,
#  'państwa lub': 288,
#  'zakres i': 288,
#  'energii elektrycznej': 288,
#  'w postaci': 287,
#  'które mogą': 287,
#  'do wydania': 287,
#  'za okres': 284,
#  'oddziaływania na': 284,
#  'podstawie ustawy': 283,
#  'przy czym': 282,
#  'stosownie do': 282,
#  'pracy oraz': 282,
#  'pochodzących z': 280,
#  'w różnych': 280,
#  'w jednostkach': 279,
#  'przeznaczonych do': 278,
#  'za pomocą': 278,
#  'w trakcie': 277,
#  'licząc od': 277,
#  'działalność gospodarczą': 277,
#  'nie stanowią': 276,
#  'w miejscu': 276,
#  'przysługuje prawo': 276,
#  'składa się': 275,
#  'dla których': 275,
#  'pracy z': 275,
#  'a jeżeli': 275,
#  'i warunki': 275,
#  'w innych': 274,
#  'służby w': 274,
#  'minister finansów': 274,
#  'środowiska i': 273,
#  'spraw administracji': 273,
#  'do końca': 272,
#  'odpowiednio w': 272,
#  'kultury i': 272,
#  'wydaje się': 272,
#  'ochrony państwa': 272,
#  'straży pożarnej': 271,
#  'z przepisów': 271,
#  'oznacza się': 271,
#  'czasu pracy': 271,
#  'przepisów prawa': 270,
#  'od towarów': 270,
#  'o działalności': 269,
#  'nie więcej': 269,
#  'zakładu ubezpieczeń': 269,
#  'określonymi w': 268,
#  'na których': 268,
#  'na polski': 268,
#  'z upływem': 267,
#  'wykonywania zadań': 267,
#  'tryb postępowania': 267,
#  'w obrocie': 267,
#  'wyłącznie w': 266,
#  'mniej niż': 266,
#  'pozwolenia na': 266,
#  'marszałek sejmu': 265,
#  'w pierwszej': 265,
#  'na rachunek': 264,
#  'za przestępstwo': 264,
#  'prawa i': 263,
#  'wynagrodzenia za': 262,
#  'prowadzenia działalności': 261,
#  'na postanowienie': 261,
#  'pomocy społecznej': 261,
#  'prezesa rady': 261,
#  'organów administracji': 260,
#  'zachowują moc': 260,
#  'zdanie drugie': 260,
#  'dłużej niż': 259,
#  'przez radę': 259,
#  'lub inne': 259,
#  'prowadzenie działalności': 259,
#  'działalności w': 259,
#  'postanowienie o': 259,
#  'z wykonywaniem': 259,
#  'lub innej': 258,
#  'oraz tryb': 258,
#  'następującego po': 257,
#  'w umowie': 257,
#  'uprawnionych do': 257,
#  'wniosek ministra': 256,
#  'zakresie określonym': 256,
#  'może w': 255,
#  'do wniosku': 255,
#  'do jego': 254,
#  'podatku dochodowego': 254,
#  'i nazwisko': 253,
#  'w służbie': 253,
#  'przy ustalaniu': 253,
#  'do pełnienia': 252,
#  'określa się': 252,
#  'realizacji zadań': 252,
#  'i adres': 252,
#  'przepisy ogólne': 251,
#  'urzędowym rzeczypospolitej': 251,
#  'i administracji': 250,
#  'i obowiązki': 250,
#  'rolnictwa i': 250,
#  'okres nie': 249,
#  'może przekroczyć': 249,
#  'wykonywania czynności': 248,
#  'państwa oraz': 248,
#  'kierując się': 248,
#  'zakład ubezpieczeń': 248,
#  'państw członkowskich': 246,
#  'opłaty za': 246,
#  'karze ograniczenia': 246,
#  'również w': 245,
#  'karze grzywny': 245,
#  'zwane dalej': 244,
#  'po zakończeniu': 244,
#  'na warunkach': 244,
#  'działalność w': 243,
#  'niematerialnych i': 243,
#  'biorąc pod': 243,
#  'w jakim': 243,
#  'o pracę': 243,
#  'członkowskich unii': 243,
#  'obszar celny': 243,
#  'zakresu administracji': 243,
#  'ustawy nie': 242,
#  'zmiany w': 242,
#  'uwzględnia się': 242,
#  'się wyraz': 242,
#  'może zostać': 241,
#  'nie zostały': 241,
#  'przez organy': 240,
#  'ze sprzedaży': 240,
#  'lub o': 240,
#  'tym samym': 240,
#  'w warunkach': 239,
#  'nie przysługuje': 239,
#  'pobiera się': 239,
#  'do uzyskania': 238,
#  'wartości niematerialnych': 238,
#  'wpływ na': 238,
#  'przez osobę': 238,
#  'niezwłocznie po': 238,
#  'przy wykonywaniu': 237,
#  'pierwszej instancji': 237,
#  'rady nadzorczej': 237,
#  'niż przez': 236,
#  'należności z': 236,
#  'jest w': 236,
#  'zgody na': 236,
#  'komisja wyborcza': 236,
#  'na ubezpieczenia': 235,
#  'wolności od': 235,
#  'na rynku': 235,
#  'przez podmiot': 234,
#  'przepisy dotyczące': 234,
#  'warunków określonych': 234,
#  'oświaty i': 234,
#  'z naruszeniem': 234,
#  'zalicza się': 233,
#  'z udziałem': 233,
#  'sił zbrojnych': 231,
#  'niż określone': 231,
#  'do świadczeń': 231,
#  'różnych przypadkach': 231,
#  'na środowisko': 231,
#  'przewidziane w': 230,
#  'komendant główny': 230,
#  'do tych': 229,
#  'i zagospodarowania': 229,
#  'przypadkach określonych': 228,
#  'z jego': 228,
#  'uznaje się': 228,
#  'w zakładzie': 228,
#  'wojewódzki inspektor': 227,
#  'miesiąca od': 226,
#  'że nie': 226,
#  'z innymi': 226,
#  'do publicznej': 226,
#  'przy pomocy': 226,
#  'tego samego': 225,
#  'w wypadkach': 225,
#  'w jego': 225,
#  'się zdanie': 225,
#  'dotychczasową treść': 225,
#  'dopuszczenie do': 225,
#  'oraz zasady': 225,
#  'że w': 224,
#  'przez sąd': 223,
#  'dla zdrowia': 223,
#  'członkowskiego unii': 223,
#  'przez te': 222,
#  'uprawnień do': 222,
#  'uprawniony do': 222,
#  'w przedmiocie': 222,
#  'w składzie': 221,
#  'mocy prawa': 221,
#  'tryb i': 221,
#  'dla osób': 221,
#  'pracy na': 221,
#  'w inny': 221,
#  'osoby prawne': 220,
#  'które wchodzą': 220,
#  'przez skarb': 220,
#  'albo pozbawienia': 220,
#  'odbywa się': 219,
#  'nie spełnia': 219,
#  'bez względu': 219,
#  'zawarcia umowy': 218,
#  'w systemie': 218,
#  'zasadach i': 217,
#  'który nie': 217,
#  'ilekroć w': 217,
#  'wojewódzkiego inspektora': 217,
#  'spraw zabezpieczenia': 217,
#  'i polityki': 217,
#  'zawarte w': 216,
#  'z rejestru': 216,
#  'do realizacji': 216,
#  'spraw kultury': 216,
#  'ma być': 216,
#  'do właściwego': 215,
#  'do udziału': 215,
#  'przeprowadza się': 215,
#  'kodeks postępowania': 215,
#  'w nim': 214,
#  'w odpowiednich': 214,
#  'postępowaniu egzekucyjnym': 214,
#  'sposób prowadzenia': 213,
#  'treść oznacza': 213,
#  'na uwadze': 213,
#  'poza granicami': 212,
#  'europejskiej lub': 212,
#  'spraw oświaty': 212,
#  'spraw transportu': 212,
#  'kultury fizycznej': 212,
#  'zwanego dalej': 211,
#  'na pokrycie': 211,
#  'i zakres': 211,
#  'za pracę': 211,
#  'warunki określone': 211,
#  'terminie określonym': 210,
#  'sporządza się': 210,
#  'według zasad': 210,
#  'krótszy niż': 209,
#  'dnia złożenia': 209,
#  'organ egzekucyjny': 209,
#  'okresie od': 208,
#  'uprawnione do': 208,
#  'do ewidencji': 208,
#  'we l': 208,
#  'w charakterze': 208,
#  'przepisów wykonawczych': 207,
#  'do której': 207,
#  'niektórych innych': 207,
#  'oraz jego': 207,
#  'wlicza się': 207,
#  'powinna być': 206,
#  'tym również': 206,
#  'się według': 206,
#  'się przecinek': 206,
#  'do służby': 206,
#  'do zasiłku': 206,
#  'za rok': 205,
#  'na poczet': 205,
#  'do osób': 205,
#  'złożenia wniosku': 205,
#  'nie podlega': 205,
#  'użytymi w': 205,
#  'transportu i': 205,
#  'sądu okręgowego': 204,
#  'należących do': 203,
#  'kandydatów na': 203,
#  'w wyznaczonym': 203,
#  'odrębnych przepisów': 203,
#  'i rady': 203,
#  'narodowego banku': 203,
#  'załącznik nr': 203,
#  'na prawach': 203,
#  'mają prawo': 202,
#  'uzgodnieniu z': 202,
#  'przeznaczonych na': 201,
#  'ze służby': 201,
#  'jest mowa': 201,
#  'minister spraw': 201,
#  'fizycznej i': 201,
#  'żołnierza zawodowego': 201,
#  'do sprzedaży': 200,
#  'w spółce': 200,
#  'egzekucyjnym w': 200,
#  'z prawem': 200,
#  'najwyższej izby': 200,
#  'właściwego organu': 199,
#  'na listę': 199,
#  'na skutek': 199,
#  'niż wymienione': 199,
#  'niektórych ustaw': 199,
#  'dostępu do': 199,
#  'polega na': 198,
#  'w innym': 198,
#  'i o': 198,
#  'wykonywania działalności': 198,
#  'w niniejszej': 198,
#  'opieki społecznej': 198,
#  'również do': 197,
#  'są w': 197,
#  'warunkach określonych': 197,
#  'z zagranicą': 197,
#  'komendanta głównego': 197,
#  'w rejestrze': 197,
#  'znajdujących się': 197,
#  'o finansach': 197,
#  'lekarz weterynarii': 197,
#  'w uzasadnionych': 196,
#  'się użytymi': 196,
#  'krajowego rejestru': 196,
#  'urzędu celnego': 196,
#  'krajowego związku': 196,
#  'łącznie z': 195,
#  'od decyzji': 195,
#  'o wolnym': 195,
#  'uprawomocnienia się': 194,
#  'wniosków o': 194,
#  'doręcza się': 194,
#  'decyzji w': 193,
#  'przez nich': 193,
#  'w wymiarze': 193,
#  'dotyczy to': 193,
#  'pozwolenie na': 193,
#  'porozumienia o': 193,
#  'o masie': 193,
#  'głównego inspektora': 193,
#  'pełnienia służby': 192,
#  'narodowy bank': 192,
#  'do emerytury': 192,
#  'może żądać': 192,
#  'wpis do': 191,
#  'za każdy': 191,
#  'określoną w': 191,
#  'niezgodnie z': 191,
#  'z zagranicy': 191,
#  'szczegółowy zakres': 190,
#  'w czynnościach': 190,
#  'rzeczpospolitą polską': 189,
#  'wyłącznie na': 189,
#  'na realizację': 189,
#  'w środowisku': 189,
#  'emerytury lub': 189,
#  'oraz ministrem': 189,
#  'obrotu na': 189,
#  'w okręgu': 189,
#  'spraw rynków': 188,
#  'który wchodzi': 188,
#  'rozporządzenia nr': 188,
#  'zadań określonych': 188,
#  'o odmowie': 188,
#  'do lokalu': 188,
#  'europejskiego porozumienia': 188,
#  'wolnym handlu': 188,
#  'żołnierzy zawodowych': 187,
#  'dla celów': 187,
#  'organ administracji': 187,
#  'o kwotę': 187,
#  'z obowiązku': 187,
#  'zmian w': 187,
#  'podstawy wymiaru': 187,
#  'od którego': 187,
#  'ustawy stosuje': 187,
#  'przepisami o': 187,
#  'albo na': 186,
#  'prowadzących działalność': 186,
#  'znajduje się': 186,
#  'z nich': 186,
#  'czynności w': 186,
#  'w zakładach': 186,
#  'tylko w': 185,
#  'organ podatkowy': 185,
#  'odpowiednich przypadkach': 185,
#  'wchodzących w': 185,
#  'z nimi': 185,
#  'dane dotyczące': 184,
#  'w latach': 184,
#  'korzystanie z': 184,
#  'z ich': 184,
#  'do wykonania': 184,
#  'miesięcy do': 184,
#  'o przyznanie': 183,
#  'ministra obrony': 183,
#  'informacje dotyczące': 183,
#  'w celach': 183,
#  'lub jej': 183,
#  'o europejskim': 183,
#  'państwowa komisja': 183,
#  'oraz niektórych': 182,
#  'i miejsce': 182,
#  'grzywny do': 182,
#  'na rok': 182,
#  'w dziale': 182,
#  'danym roku': 181,
#  'naturalnych i': 181,
#  'państwowej inspekcji': 181,
#  'do przeprowadzenia': 181,
#  'o służbie': 180,
#  'sprawozdania finansowego': 180,
#  'się także': 180,
#  'informacji i': 180,
#  'na wykonywanie': 180,
#  'w chwili': 180,
#  'europejskim obszarze': 180,
#  'środków finansowych': 179,
#  'prowadzi się': 179,
#  'do jej': 179,
#  'zatrudnionych w': 179,
#  'przeznaczone na': 178,
#  'wydania decyzji': 178,
#  'nazwę i': 178,
#  'obowiązane do': 178,
#  'się po': 178,
#  'inny sposób': 178,
#  'o samorządzie': 178,
#  'do właściwości': 178,
#  'i do': 177,
#  'czasu wydania': 177,
#  'oraz warunki': 177,
#  'w nich': 177,
#  'przez bank': 177,
#  'parlamentu europejskiego': 177,
#  'szczególnie uzasadnionych': 176,
#  'w państwie': 176,
#  'wynikającej z': 176,
#  'z których': 176,
#  'o zasadach': 176,
#  'tkanek i': 176,
#  'walnego zgromadzenia': 175,
#  'życia lub': 175,
#  'do produkcji': 174,
#  'roku od': 174,
#  'na koniec': 174,
#  'tym w': 174,
#  'jest obowiązana': 174,
#  'dopuszcza się': 174,
#  'o zaopatrzeniu': 174,
#  'i pkt': 174,
#  'miejsca zamieszkania': 173,
#  'w szczególnie': 173,
#  'uzasadnionych przypadkach': 173,
#  'na mocy': 173,
#  'ustawa określa': 173,
#  'systemie ubezpieczeń': 173,
#  'państwa na': 173,
#  'nie podlegają': 173,
#  'organ właściwy': 173,
#  'o nadanie': 173,
#  'rodzaj i': 173,
#  'w urzędzie': 173,
#  'do wiadomości': 173,
#  'się średnikiem': 173,
#  'prowadzonych przez': 172,
#  'do złożenia': 172,
#  'roku podatkowym': 172,
#  'wcześniej niż': 172,
#  'o emeryturach': 172,
#  'konieczność zapewnienia': 172,
#  'wymagania dotyczące': 172,
#  'niniejszą ustawą': 172,
#  'do informacji': 172,
#  'lokalu mieszkalnego': 172,
#  'masie jednostkowej': 172,
#  'zwanej dalej': 171,
#  'krajowa rada': 171,
#  'do ustawy': 171,
#  'przeliczeniu na': 171,
#  'i urządzeń': 171,
#  'moc do': 171,
#  'lub za': 171,
#  'tym zakresie': 171,
#  'środków na': 171,
#  'informacji niejawnych': 171,
#  'odstąpić od': 171,
#  'do postępowania': 171,
#  'państwowej komisji': 171,
#  'odwołanie do': 170,
#  'prawa z': 170,
#  'na finansowanie': 170,
#  'zasobów naturalnych': 170,
#  'o powszechnym': 170,
#  'staje się': 170,
#  'postępowania o': 170,
#  'papiery wartościowe': 170,
#  'podmiot odpowiedzialny': 170,
#  'postanowienia o': 169,
#  'uprawnienia do': 169,
#  'i końcowe': 169,
#  'na ten': 169,
#  'przepisy wykonawcze': 169,
#  'w procesie': 169,
#  'najpóźniej w': 169,
#  'średnikiem i': 169,
#  'o wpis': 168,
#  'dnia jej': 168,
#  'podstawę do': 168,
#  ...}

# %% [markdown]
# # 4. Use pointwise mutual information to compute the measure for all pairs of words:

# %%
unigrams_dict = dict()
for file in os.listdir(data_dir):
    bills = open(f"./{data_dir}{file}", "r").read()
    bills = bills.split()
    bills = " ".join(bills)
    bills = bills.lower()
    tokens = tokenizer(bills)
    unigrams = ngrams(tokens, 1)
    unigrams_list = []
    for b in unigrams:
        b = str(b).replace(".", "").replace(":", "").replace(";", "").replace("(", "").replace(")", "").replace("[", "").replace("]", "").replace(",", "")
        unigrams_list.append(str(b))
    for i in unigrams_list:
        if i in unigrams_dict.keys():
            unigrams_dict[i] += 1
        else:
            unigrams_dict[i] = 1

unigrams_dictionary = {k: v for k, v in sorted(unigrams_dict.items(), key=lambda item: item[1], reverse=True)}

# %%
unigrams_dictionary_copy = unigrams_dictionary.copy()
for k in unigrams_dictionary.keys():
    if not k.isalpha():
       del  unigrams_dictionary_copy[k]

unigrams_dictionary = unigrams_dictionary_copy

# %%
unigrams_sum = sum(unigrams_dictionary.values())
bigrams_sum = sum(bigrams_dictionary.values())

def calculate_pmi(w_1, w_2):
    p_w_1 = unigrams_dictionary[w_1] / unigrams_sum
    p_w_2 = unigrams_dictionary[w_2] / unigrams_sum
    p_w_1_w_2 = bigrams_dictionary[w_1 + " " + w_2] / bigrams_sum
    return math.log(p_w_1_w_2 / (p_w_1 * p_w_2))

# %%
pmi_dict = dict()
for b in bigrams_dictionary.keys():
    w1 = b.split()[0]
    w2 = b.split()[1]
    pmi_dict[b] = calculate_pmi(w1, w2)

pmi_dict
# Out:
# {'mowa w': 3.2653291075699493,
#  'których mowa': 4.959732737521558,
#  'o których': 4.150482123697541,
#  'z dnia': 3.535204012760526,
#  'którym mowa': 4.966679459526838,
#  'o którym': 4.156915051966411,
#  'do spraw': 4.330654871788954,
#  'i nr': 2.4116446796137874,
#  'dodaje się': 4.7255341107464295,
#  'w drodze': 3.2646692488774782,
#  'na podstawie': 4.619568482484866,
#  'stosuje się': 4.652294888303835,
#  'o której': 4.104952649724248,
#  'której mowa': 4.911809482910507,
#  'w przypadku': 3.0347619696094634,
#  'od dnia': 4.504761094247153,
#  'w zakresie': 3.0960787009772024,
#  'właściwy do': 4.246504439525977,
#  'zastępuje się': 4.744712014518809,
#  'w ustawie': 3.114323166422441,
#  'minister właściwy': 6.297397056527112,
#  'oraz z': 2.114622553842081,
#  'w życie': 3.214658084931618,
#  'określonych w': 3.0524368974979454,
#  'w tym': 2.7868181861719266,
#  'w terminie': 3.050769088259124,
#  'w pkt': 1.6526039250441287,
#  'a także': 5.377036765435371,
#  'ustawie z': 3.7772755856035234,
#  'ustawy z': 2.7259063647099833,
#  'w razie': 3.237540046847247,
#  'się wyrazami': 4.682278286359595,
#  'może być': 5.245284365030827,
#  'w celu': 3.0220982284533537,
#  'zgodnie z': 4.146794322605836,
#  'skreśla się': 4.662861194713699,
#  'dni od': 5.363924041388865,
#  'w szczególności': 2.9321037322019015,
#  'wejścia w': 3.2435521164524466,
#  'na wniosek': 3.998657635429848,
#  'się w': 0.2995142367723771,
#  'z zastrzeżeniem': 4.11888130872449,
#  'z tytułu': 3.940325618912442,
#  'co najmniej': 7.257876240441379,
#  'się wyrazy': 3.769135457924852,
#  'do dnia': 2.3580410103616503,
#  'w sprawach': 3.021690748709894,
#  'a w': 1.228472492965634,
#  'określone w': 3.1037826940433018,
#  'rzeczypospolitej polskiej': 6.683513946840023,
#  'się do': 1.3672343416243995,
#  'nie może': 3.627997821162186,
#  'się odpowiednio': 3.963376979857191,
#  'się następujące': 4.549372186277672,
#  'wprowadza się': 4.674883563611928,
#  'w sprawie': 3.092206910307994,
#  'mogą być': 6.000096223888001,
#  'w którym': 1.3979363751935558,
#  'się pkt': 2.3919925248052256,
#  'z dniem': 3.50439433375325,
#  'w rozumieniu': 3.2711109663861557,
#  'porozumieniu z': 4.1324500379305595,
#  'w porozumieniu': 3.2104732678497316,
#  'w wysokości': 2.568211411006244,
#  'w przepisach': 2.932369465296866,
#  'po upływie': 5.939360539752554,
#  'właściwego do': 3.828054000706935,
#  'lub w': -0.0997353705522092,
#  'się na': 1.2561284790577405,
#  'na zasadach': 4.436813691567359,
#  'z ministrem': 3.933360004332641,
#  'wchodzi w': 3.209370471361441,
#  'w związku': 2.886178056211903,
#  'na terytorium': 4.415638507717215,
#  'ministra właściwego': 6.912873105141085,
#  'przed dniem': 6.162300596102305,
#  'jest obowiązany': 5.628865155678771,
#  'ustawy o': 2.2132758290670407,
#  'z wyjątkiem': 4.007259783562194,
#  'nie stosuje': 3.892959855291382,
#  'wraz z': 4.068326626203392,
#  'względu na': 4.646272649898215,
#  'oraz w': 0.09429403291912644,
#  'w okresie': 3.010578732490283,
#  'i w': -0.9116239123483046,
#  'właściwym do': 4.152474124833049,
#  'w stosunku': 2.812946678236571,
#  'o zmianie': 4.2538262833124065,
#  'związku z': 3.654512281009404,
#  'chyba że': 7.031210307645059,
#  'miesięcy od': 5.0699898865078765,
#  'w trybie': 3.123590476452602,
#  'prawo do': 3.3001534367807506,
#  'terytorium rzeczypospolitej': 6.8920616227267875,
#  'do obrotu': 3.7185879829673882,
#  'przez to': 4.404868295841786,
#  'związanych z': 4.058040432843547,
#  'ustawa z': 3.1714023509372242,
#  'ustawa wchodzi': 7.128394807064874,
#  'ze względu': 6.692837511058099,
#  'stosunku do': 3.8736464333725973,
#  'przepisów o': 2.906532288737701,
#  'ministrem właściwym': 7.486499997692674,
#  'w sposób': 1.9178869797161142,
#  'z uwzględnieniem': 4.083360881699034,
#  'określonym w': 2.9426196428919984,
#  'i tryb': 3.304174539716454,
#  'w formie': 3.128086575547913,
#  'na rzecz': 4.5185305492400145,
#  'w ramach': 3.267376790972695,
#  'wymienionych w': 3.2201999674808497,
#  'w ciągu': 3.2437163569227625,
#  'zasadach określonych': 6.366415097963585,
#  'się z': 0.38271569450290616,
#  'spraw wewnętrznych': 5.823129024792087,
#  'w postępowaniu': 2.813583325669096,
#  'spraw finansów': 5.562791118804298,
#  'rozumie się': 4.740316113817061,
#  'pozbawienia wolności': 7.69340003473898,
#  'podlega karze': 7.107469331914409,
#  'do czasu': 3.808515222226915,
#  'dnia wejścia': 4.7580611656810685,
#  'w dniu': 2.7106075811301853,
#  'zostały ogłoszone': 7.803310354679222,
#  'ogłoszone w': 3.2538288335250796,
#  'się przez': 1.6546466854218325,
#  'ustawy zostały': 5.201670619169907,
#  'oraz o': 0.8410540271324447,
#  'po wyrazach': 5.966579396383907,
#  'wniosek o': 2.8231478523239417,
#  'związane z': 4.0196733684217145,
#  'w wyniku': 3.0707702555096055,
#  'w których': 0.3093162114797051,
#  'i innych': 2.4813891021403993,
#  'dniem wejścia': 6.353893787607289,
#  'określonego w': 2.965548208540876,
#  'w odniesieniu': 3.2734277574940798,
#  'nie jest': 2.7670480728274507,
#  'odniesieniu do': 4.45388294257362,
#  'i dodaje': 1.8405004446251736,
#  'wymienionej ustawy': 5.607247451096908,
#  'na czas': 4.071595927864984,
#  'się przepisy': 2.8494287243556737,
#  'wniosku o': 3.453495605461757,
#  'zmianie ustawy': 5.4389127578085805,
#  'życie z': 2.511582306784498,
#  'podstawie przepisów': 4.812244863818557,
#  'prawa do': 2.814268797105168,
#  'życie niniejszej': 6.41044619378458,
#  'życie po': 4.2945075331769775,
#  'w czasie': 2.882361916017002,
#  'samorządu terytorialnego': 7.275726552311059,
#  'nie później': 5.373725718479599,
#  'z zakresu': 3.6550219534775166,
#  'przypadku gdy': 5.413146565340393,
#  'wynikających z': 4.06107585091123,
#  'w skład': 2.8108571806154696,
#  'się o': 0.3316503730337129,
#  'odpowiednio przepisy': 5.140417511987708,
#  'z tym': 2.057605749542193,
#  'zasięgnięciu opinii': 8.030947371275087,
#  'szczegółowe zasady': 6.903787226087833,
#  'po zasięgnięciu': 5.953239105234482,
#  'do wykonywania': 3.147591742547756,
#  'w roku': 1.6238565199287855,
#  'ochrony środowiska': 5.603366874510879,
#  'skarbu państwa': 6.307347000321378,
#  'finansów publicznych': 6.587973565367243,
#  'do rejestru': 3.5284538353173045,
#  'odpowiednio do': 2.7373745546665,
#  'spraw gospodarki': 5.0422169366563905,
#  'umowy o': 2.8565027210977814,
#  'i ich': 1.6580283736783337,
#  'z wyłączeniem': 4.053892284317109,
#  'się wyrazem': 4.655992170606277,
#  'z przepisami': 3.479048325307669,
#  'ustala się': 4.0392373604982375,
#  'przez ministra': 4.2541990072419384,
#  'zezwolenia na': 3.601479415007264,
#  'rady ministrów': 5.984564157856469,
#  'przez okres': 4.108190622028747,
#  'na obszarze': 4.137901299157826,
#  'wymienione w': 3.206666003456389,
#  'co do': 2.8493760784482887,
#  'później niż': 6.486401118478963,
#  'terminie do': 2.5231148333975346,
#  'o ochronie': 3.9748189626489188,
#  'działalności gospodarczej': 6.404473017698054,
#  'rada ministrów': 6.673335002327037,
#  'jednak niż': 6.089748247482091,
#  'w brzmieniu': 0.8997236633189741,
#  'określony w': 2.8147019868031977,
#  'jeżeli w': 0.40060843143905456,
#  'na okres': 3.196388068817112,
#  'informacji o': 2.6691662202147013,
#  'po pkt': 2.613723321410078,
#  'rozumieniu przepisów': 5.917612149197998,
#  'uchyla się': 4.587823729669017,
#  'kodeksu postępowania': 6.100481929572638,
#  'życie ustawy': 4.105878941805563,
#  'w części': 1.9334584158566426,
#  'o wydanie': 3.761898473422697,
#  'unii europejskiej': 7.599292031780834,
#  'kropkę zastępuje': 6.824797532925198,
#  'pracy w': 0.8568081423486447,
#  'w wypadku': 2.765897029624942,
#  'do lat': 2.9176606116532744,
#  'ustawę z': 3.907596207424021,
#  'budżetu państwa': 5.927043816581258,
#  'ze środków': 4.978449821911926,
#  'jeżeli nie': 2.4943958395524684,
#  'przepisów ustawy': 3.883022117781908,
#  'w tych': 1.1833116169291087,
#  'przez niego': 5.085578541273915,
#  'opieki zdrowotnej': 7.5473545623646805,
#  'administracji rządowej': 7.0534308335609035,
#  'mając na': 4.604985936474906,
#  'o ile': 4.3703479836231685,
#  'na terenie': 4.410681253131683,
#  'postępowania w': 1.1935628673942185,
#  'określonej w': 2.7899293251555592,
#  'więcej niż': 6.1813176537604715,
#  'lub jego': 2.400873260765265,
#  'obrony narodowej': 7.466480228582565,
#  'spraw zdrowia': 4.7962470853675185,
#  'nie mogą': 3.541233563976869,
#  'przepisach o': 3.0380419818129654,
#  'uważa się': 4.652639020078416,
#  'prezes rady': 5.746188631195302,
#  'i na': -0.3967066140995825,
#  'zasady i': 2.491022210433583,
#  'się przecinkiem': 4.703671847949737,
#  'pracy i': 1.5499537245772477,
#  'jednostki samorządu': 6.127328475819489,
#  'zmienianej w': 3.2749511737425503,
#  'produktu leczniczego': 8.036596313278674,
#  'informacje o': 3.1703461869626723,
#  'ustawy zmienianej': 6.000789689371829,
#  'niniejszej ustawy': 4.925481246120345,
#  'lub na': 0.24704024316285175,
#  'po wyrazie': 5.952501278753668,
#  'przez prezesa': 4.316196909338927,
#  'wydanych na': 4.223370516956235,
#  'przepisy ustawy': 3.6564797093383294,
#  'sprawach o': 2.7659976177004406,
#  'w całości': 2.9599727904644757,
#  'i z': -0.9527650152077229,
#  'o podatku': 3.0753724039375316,
#  'z wnioskiem': 3.90930648661635,
#  'lat od': 4.0288795193304034,
#  'towarów i': 2.802011534776442,
#  'udziału w': 2.776921661340252,
#  'od osób': 3.5342687317549553,
#  'i gospodarki': 2.5219621459352974,
#  'i sposób': 1.9226726880304317,
#  'zmiany tekstu': 7.016643849744863,
#  'tym że': 4.5462514818799695,
#  'tekstu jednolitego': 8.863508842835554,
#  'państwowej straży': 6.972599258818654,
#  'decyzji o': 2.531991560432171,
#  'ubezpieczeń społecznych': 7.386567603044246,
#  'nadzór nad': 7.736049312006173,
#  'się za': 1.6720263115669685,
#  'z budżetu': 3.0220771342166195,
#  'podstawie odrębnych': 5.659023198694032,
#  'w dzienniku': 3.1180649236806723,
#  'następuje w': 2.152543583750816,
#  'niż w': 0.721493344685979,
#  'informację o': 3.9761075417982945,
#  'prezes urzędu': 5.489526704211323,
#  'jednolitego wymienionej': 8.057613671995124,
#  'przecinkiem i': 3.899175285802873,
#  'do sądu': 2.6496581601008242,
#  'i nie': 0.25180727376212697,
#  'nie dłużej': 5.292587877337368,
#  'w odrębnych': 2.258153072396359,
#  'na ubezpieczenie': 4.396504489680342,
#  'właściwemu do': 3.923613203721362,
#  'i jego': 1.5209926320002318,
#  'przed upływem': 6.561664987342641,
#  'oraz ich': 2.2451458502034174,
#  'o udzielenie': 3.9480223008514135,
#  'na cele': 4.26888401627867,
#  'udział w': 2.686173555792903,
#  'dłuższy niż': 6.608793528065874,
#  'wynikające z': 4.0832152856040995,
#  'z powodu': 4.086895843494869,
#  'papierów wartościowych': 8.469823623002073,
#  'warunki i': 2.225038829187542,
#  'do pracy': 1.7519910848764046,
#  'karze pozbawienia': 7.128390269863438,
#  'lub innych': 2.4851044204078074,
#  'korzystania z': 3.817167317396666,
#  'straży granicznej': 7.360799264309879,
#  'przepisy o': 1.9001793759937855,
#  'wnioskiem o': 4.018825477017025,
#  'nie dotyczy': 4.444732435417488,
#  'jednostek organizacyjnych': 6.993218189258065,
#  'się od': 1.1671806861574607,
#  'urzędu ochrony': 4.771669670453494,
#  'na prowadzenie': 3.646773761308498,
#  'w przypadkach': 1.9593818316177296,
#  'oraz innych': 2.7627650388193215,
#  'jednostek samorządu': 6.250117860513241,
#  'jest to': 3.897661886910464,
#  'od daty': 5.419521626673993,
#  'minister obrony': 5.583926068716105,
#  'wolności do': 3.0464323814864183,
#  'służby cywilnej': 6.206224343268331,
#  'na jego': 1.9986327344345236,
#  'zezwolenie na': 3.8618335562748225,
#  'wymienionej w': 2.1683100601245306,
#  'składek na': 3.6477711841091294,
#  'przez organ': 3.3745274947100126,
#  'wewnętrznych i': 2.79634587861011,
#  'do prowadzenia': 2.9318953749347756,
#  'minister sprawiedliwości': 5.692788438614109,
#  'lub ich': 1.82380936251292,
#  'jak również': 6.896334922485807,
#  'albo w': 0.2881754843371953,
#  'za zgodą': 5.846744388992424,
#  'nie są': 2.7933788344517594,
#  'obowiązany do': 2.894527548149552,
#  'lub z': -0.49230167332565317,
#  'w której': 0.4169278690640505,
#  'w danym': 3.0663061180781948,
#  'o tym': 1.7091320153385954,
#  'brzmieniu nadanym': 6.558226381507671,
#  'w toku': 3.1555625525689566,
#  'rozumieniu ustawy': 4.580642780032676,
#  'ministrowi właściwemu': 8.145387052311085,
#  'i inne': 2.2373056987062783,
#  'oraz sposób': 2.6922280409959893,
#  'nie można': 4.221388483454288,
#  'w załączniku': 3.2273589302725965,
#  'nadanym niniejszą': 8.923101480953589,
#  'ma prawo': 5.6237504893080965,
#  'zdrowia i': 2.2435797672664086,
#  'na dzień': 3.87616615733219,
#  'przewidzianych w': 2.880307380802686,
#  'głównego urzędu': 6.091098110953548,
#  'do których': 0.6788020539532997,
#  'z mocy': 3.4077121790573006,
#  'niezbędne do': 3.8437133569811137,
#  'w tej': 1.2813422993375316,
#  'produktów leczniczych': 7.358209811358606,
#  'niż do': 1.6757913595538811,
#  'na żądanie': 4.133339484692451,
#  'może nastąpić': 5.687644768728974,
#  'po dniu': 4.497845070492425,
#  'podstawie umowy': 4.473159569922519,
#  'ue l': 8.45100865191658,
#  'sąd może': 4.046820618147395,
#  'na względzie': 4.60389385599416,
#  'stają się': 4.705050443182812,
#  'zmiany wymienionej': 5.942456659486299,
#  'na końcu': 4.646952251299171,
#  'podatku od': 4.095935145208706,
#  'na celu': 2.4717053623588825,
#  'pracy lub': 1.8255314056964254,
#  'o postępowaniu': 2.9734769214448513,
#  'także w': 0.6143803004385137,
#  'spraw środowiska': 4.142978422673782,
#  'i usług': 2.638063219574465,
#  'za pośrednictwem': 6.087356286855041,
#  'użyte w': 3.1428597507351954,
#  'dzienniku urzędowym': 8.862597562668954,
#  'z tego': 1.7961336555172525,
#  'są obowiązani': 6.425837063643795,
#  'w rzeczypospolitej': 1.0234520555521753,
#  'obowiązany jest': 4.271894409405386,
#  'służby wojskowej': 5.908920501948412,
#  'państwa członkowskiego': 6.716914911646728,
#  'na ich': 1.5488777856368376,
#  'należy przez': 3.788188988461771,
#  'do tego': 2.078915152064356,
#  'po uzyskaniu': 5.807414756689576,
#  'z tych': 1.537406299929858,
#  'o charakterze': 3.654606101179507,
#  'uwzględniając w': 1.919071535802969,
#  'właściwy organ': 4.425467477183706,
#  'całości lub': 4.053776576036674,
#  'prawo o': 2.0019924896782646,
#  'do ich': 1.3486416977466635,
#  'trybie określonym': 6.695094468281279,
#  'wykonywania zawodu': 6.8090225841472165,
#  'z urzędu': 1.6409479752907274,
#  'oraz na': 0.12171413849442665,
#  'się również': 2.7783755121190823,
#  'oraz inne': 3.0665789592277206,
#  'wydane na': 3.762383034346836,
#  'zgodę na': 4.332507827130941,
#  'w zdaniu': 3.1499038809196653,
#  'dokonuje się': 3.5771989233747203,
#  'z innych': 1.6089789141130428,
#  'nie dłuższy': 5.031944599249879,
#  'to rozumieć': 7.080557724240609,
#  'które nie': 2.9841551764076875,
#  'ograniczenia wolności': 7.086453617489756,
#  'na miejsce': 3.2721098770422983,
#  'w imieniu': 2.885856344703921,
#  'z działalności': 1.5601376806405218,
#  'tej samej': 7.431060378539575,
#  'innych niż': 4.124291160406964,
#  'z chwilą': 4.121118293906528,
#  'administracji publicznej': 5.932499267980049,
#  'do którego': 2.6500205232818606,
#  'dniu wejścia': 6.078102579845336,
#  'zawartych w': 2.7050309327396342,
#  'jeżeli jest': 2.4394538190199815,
#  'i opieki': 2.488104203053603,
#  'ustawy wymienionej': 4.644705701571997,
#  'prezydenta rzeczypospolitej': 6.826800698002568,
#  'osób prawnych': 5.604685005814175,
#  'się jako': 3.0665159501863823,
#  'i odwołuje': 3.7960884096820453,
#  'zawodowej służby': 6.3532638281588545,
#  'jednostki organizacyjne': 6.8558816084544025,
#  'szczegółowe warunki': 6.006323358915086,
#  'nie przekracza': 4.760238384067615,
#  'do zadań': 2.3527106032199647,
#  'niezdolności do': 4.379054772808435,
#  'nie ma': 3.6637259382647813,
#  'przez osoby': 2.8971181066807494,
#  'lub innego': 3.5189687892507666,
#  'wyrobów akcyzowych': 7.82181612127681,
#  'pod warunkiem': 7.342977815946224,
#  'przeznaczone do': 3.7653086917530056,
#  'na potrzeby': 3.714643056959163,
#  'decyzję o': 3.5443533387948327,
#  'polski obszar': 8.09275021981725,
#  'do wysokości': 2.1331467304565175,
#  'w stanie': 2.6329092629991293,
#  'do celów': 3.6006803294555167,
#  'sposób i': 1.4414741918214733,
#  'z funduszu': 2.069103053672381,
#  'środków trwałych': 6.692276702127975,
#  'i ochrony': 1.421420053869486,
#  'główny inspektor': 7.599331071646157,
#  'są obowiązane': 6.143855077763029,
#  'jednostki organizacyjnej': 6.755266070143105,
#  'wchodzą w': 2.8587573825185366,
#  'wolności albo': 4.657980621832487,
#  'prezesa urzędu': 5.313260422409794,
#  'powinny być': 5.926292147093162,
#  'krajowej rady': 6.257070775103131,
#  'zwany dalej': 8.142582407215624,
#  'za granicą': 5.557633141473173,
#  'niezależnie od': 5.7464846950050585,
#  'niezbędnych do': 3.890299442491895,
#  'postępowania karnego': 5.614535901689271,
#  'stosunku pracy': 4.680581696543039,
#  'państwa w': 0.3920651967582064,
#  'powołuje i': 3.309596693777252,
#  'skarb państwa': 6.468239564386606,
#  'dochodowym od': 5.459412071046561,
#  'składki na': 3.99610612812394,
#  'w takim': 3.0086490523275278,
#  'pod uwagę': 7.819986586765435,
#  'na piśmie': 4.248252153431688,
#  'dłużej jednak': 7.7161699008251095,
#  'w dziedzinie': 3.098739498195576,
#  'osób fizycznych': 6.399996489940579,
#  'imię i': 3.5142549001238095,
#  'przepisach wydanych': 6.742178264972212,
#  'nadzoru nad': 6.445850874611199,
#  'organ celny': 6.076731596093918,
#  'w granicach': 3.1799232700351396,
#  'wpisu do': 3.536692338697441,
#  'prezes sądu': 5.374159010470334,
#  'o systemie': 3.666311063968119,
#  'miejsce zamieszkania': 7.194808785515198,
#  'spraw rolnictwa': 5.077197937234804,
#  'drodze decyzji': 4.204593358965173,
#  'z zachowaniem': 4.10234388458305,
#  'załączniku nr': 4.404925492899132,
#  'na stanowisko': 3.610991376587083,
#  'postępowanie w': 1.5860120208280957,
#  'sposób określony': 5.789793511276631,
#  'w każdym': 3.0310167647696358,
#  'inne niż': 4.527723377136686,
#  'dnia doręczenia': 5.054603594678188,
#  'tekst ustawy': 5.914521514305015,
#  'zagospodarowania przestrzennego': 8.69546939465493,
#  'lub więcej': 3.5301812612826766,
#  'lub nie': 0.4164913329597966,
#  'nie stanowi': 3.9173221279817776,
#  'w zależności': 3.1987611119212205,
#  'podatku dochodowym': 7.517163192199819,
#  'dnia otrzymania': 4.815974325924597,
#  'przepisy kodeksu': 5.13447906895385,
#  'w kraju': 1.7567898848248642,
#  'oraz do': -0.2602461123026903,
#  'lub do': -0.5759727624737501,
#  'zależności od': 5.670474878627471,
#  'następuje na': 2.985339506599844,
#  'opłat za': 4.801431610288536,
#  'z przyczyn': 3.4274172501366333,
#  'organy administracji': 5.769878113409729,
#  'zmianie niektórych': 6.948029394693083,
#  'tworzy się': 4.295210839839415,
#  'bezpieczeństwa i': 2.3491015818391503,
#  'państwa lub': 1.7973441552841827,
#  'zakres i': 2.3179561098200314,
#  'energii elektrycznej': 8.426482953749627,
#  'w postaci': 3.030843021095983,
#  'które mogą': 4.555024591747829,
#  'do wydania': 2.6693627687651342,
#  'za okres': 3.8515767968003547,
#  'oddziaływania na': 4.332507827130941,
#  'podstawie ustawy': 2.830728144789862,
#  'przy czym': 6.972063485566086,
#  'stosownie do': 4.473817157474438,
#  'pracy oraz': 1.839563338988378,
#  'pochodzących z': 3.9605997810039004,
#  'w różnych': 2.838467722459777,
#  'w jednostkach': 2.569340357009115,
#  'przeznaczonych do': 3.73841016762461,
#  'za pomocą': 6.021237049573364,
#  'w trakcie': 3.262385490244525,
#  'licząc od': 5.726529633301143,
#  'działalność gospodarczą': 7.305077334789932,
#  'nie stanowią': 4.303543740062048,
#  'w miejscu': 2.590848232160067,
#  'przysługuje prawo': 5.0633676764604205,
#  'składa się': 3.8205878980539483,
#  'dla których': 2.3313356321864194,
#  'pracy z': 0.9094415259181305,
#  'a jeżeli': 1.9938232425373081,
#  'i warunki': 1.6869518328376953,
#  'w innych': 0.4601781658922604,
#  'służby w': 0.6494656442626675,
#  'minister finansów': 4.637124224783787,
#  'środowiska i': 1.626212071876617,
#  'spraw administracji': 3.943531390598409,
#  'do końca': 4.1742573757158645,
#  'odpowiednio w': 0.5475730882644763,
#  'kultury i': 3.0413339887417687,
#  'wydaje się': 3.148451155444964,
#  'ochrony państwa': 4.031881514169081,
#  'straży pożarnej': 7.54100299889805,
#  'z przepisów': 1.2014980388905043,
#  'oznacza się': 3.925866885461751,
#  'czasu pracy': 4.673162124388867,
#  'przepisów prawa': 4.133835573348728,
#  'od towarów': 3.8085126220078522,
#  'o działalności': 1.551137865284423,
#  'nie więcej': 4.114988563768149,
#  'zakładu ubezpieczeń': 6.386073559734309,
#  'określonymi w': 3.0838844515720516,
#  'na których': 0.45183074380323307,
#  'na polski': 3.564927730480839,
#  'z upływem': 3.0998767290878684,
#  'wykonywania zadań': 5.187937449617102,
#  'tryb postępowania': 4.770061649143655,
#  'w obrocie': 2.4923594645593257,
#  'wyłącznie w': 1.590602212564462,
#  'mniej niż': 6.447493625755148,
#  'pozwolenia na': 3.1692683109636373,
#  'marszałek sejmu': 8.494661276796649,
#  'w pierwszej': 2.3096670686166307,
#  'na rachunek': 3.8833553222505035,
#  'za przestępstwo': 5.107341528425164,
#  'prawa i': 1.2769019891437468,
#  'wynagrodzenia za': 4.295364113369775,
#  'prowadzenia działalności': 4.979648769147624,
#  'na postanowienie': 3.4705562885912116,
#  'pomocy społecznej': 6.474226386899592,
#  'prezesa rady': 5.231771019066489,
#  'organów administracji': 5.717116366091221,
#  'zachowują moc': 8.620630962278808,
#  'zdanie drugie': 8.53568463437612,
#  'dłużej niż': 5.912307892111746,
#  'przez radę': 4.828797215839141,
#  'lub inne': 2.4361801750009575,
#  'prowadzenie działalności': 5.4543333855869305,
#  'działalności w': 0.38078938383362165,
#  'postanowienie o': 3.217256331147291,
#  'z wykonywaniem': 3.871110734363121,
#  'lub innej': 3.3414608849919225,
#  'oraz tryb': 2.811689487551143,
#  'następującego po': 5.935873524235414,
#  'w umowie': 2.7690147250575277,
#  'uprawnionych do': 4.011626067965496,
#  'wniosek ministra': 4.769239301675389,
#  'zakresie określonym': 4.939389555352634,
#  'może w': -0.5800777795097736,
#  'do wniosku': 2.3129763625818143,
#  'do jego': 1.261418960122165,
#  'podatku dochodowego': 7.5782724592774,
#  'i nazwisko': 3.1486556444022953,
#  'w służbie': 2.455742101321102,
#  'przy ustalaniu': 7.170611842628322,
#  'do pełnienia': 3.5449079616410715,
#  'określa się': 2.5606618854230034,
#  'realizacji zadań': 5.792609998301305,
#  'i adres': 2.963666511394549,
#  'przepisy ogólne': 6.291676790050599,
#  'urzędowym rzeczypospolitej': 6.6688352612385495,
#  'i administracji': 1.6668185723759972,
#  'i obowiązki': 2.93521106948692,
#  'rolnictwa i': 2.696224108687984,
#  'okres nie': 2.99465957727525,
#  'może przekroczyć': 5.842495042335524,
#  'wykonywania czynności': 4.7448105443270325,
#  'państwa oraz': 1.9601085363874895,
#  'kierując się': 4.68339998000447,
#  'zakład ubezpieczeń': 6.74983395420674,
#  'państw członkowskich': 8.489681752614374,
#  'opłaty za': 4.430231714935286,
#  'karze ograniczenia': 6.903377014858242,
#  'również w': 0.9251530516539153,
#  'karze grzywny': 7.042496993006865,
#  'zwane dalej': 8.10497070803105,
#  'po zakończeniu': 5.678200714649503,
#  'na warunkach': 3.324334419550547,
#  'działalność w': 1.116289187070228,
#  'niematerialnych i': 4.060125019346389,
#  'biorąc pod': 7.8777127090016545,
#  'w jakim': 2.696739562631076,
#  'o pracę': 2.946656651883684,
#  'członkowskich unii': 7.819213180507864,
#  'obszar celny': 7.597388121673103,
#  'zakresu administracji': 5.843872811915168,
#  'ustawy nie': 1.4664997269910258,
#  'zmiany w': 0.47011186332185523,
#  'uwzględnia się': 4.245953180158852,
#  'się wyraz': 3.4223889041037436,
#  'może zostać': 5.331614616970879,
#  'nie zostały': 3.269612932405603,
#  'przez organy': 3.5719077918951845,
#  'ze sprzedaży': 5.141352903562028,
#  'lub o': -0.8332864468382567,
#  'tym samym': 6.603154548926658,
#  'w warunkach': 1.9255569708195908,
#  'nie przysługuje': 3.1734445959527564,
#  'pobiera się': 4.218663920148536,
#  'do uzyskania': 2.742682310062818,
#  'wartości niematerialnych': 7.700180825508191,
#  'wpływ na': 4.4133332969223025,
#  'przez osobę': 3.8510270432194673,
#  'niezwłocznie po': 4.269298005502019,
#  'przy wykonywaniu': 6.629954984537448,
#  'pierwszej instancji': 8.028006053433145,
#  'rady nadzorczej': 6.799236850597096,
#  'niż przez': 2.229266762113105,
#  'należności z': 2.122755843513614,
#  'jest w': -0.7462047937327104,
#  'zgody na': 3.1979557295371244,
#  'komisja wyborcza': 8.191701781535004,
#  'na ubezpieczenia': 2.7872576506450635,
#  'wolności od': 3.695114750792321,
#  'na rynku': 3.4148806027426786,
#  'przez podmiot': 3.5666378251574735,
#  'przepisy dotyczące': 4.82193637085025,
#  'warunków określonych': 4.926500592813457,
#  'oświaty i': 3.3849794938118314,
#  'z naruszeniem': 4.000658204036373,
#  'zalicza się': 4.602387175307187,
#  'z udziałem': 3.9856034452624614,
#  'sił zbrojnych': 8.80239272168644,
#  'niż określone': 4.321743465732641,
#  'do świadczeń': 2.375082412859923,
#  'różnych przypadkach': 7.419092663316964,
#  'na środowisko': 3.805643999723671,
#  'przewidziane w': 2.8398712314620975,
#  'komendant główny': 7.849324459913738,
#  'do tych': 1.3811880318276746,
#  'i zagospodarowania': 3.0869073940913085,
#  'przypadkach określonych': 4.9544991701043655,
#  'z jego': 0.8489677594496416,
#  'uznaje się': 4.506059369307346,
#  'w zakładzie': 2.7925652767071028,
#  'wojewódzki inspektor': 7.72186090519159,
#  'miesiąca od': 4.362721484166349,
#  'że nie': 2.436298296039939,
#  'z innymi': 3.3360607825628232,
#  'do publicznej': 2.4402110786000453,
#  'przy pomocy': 5.053108386946116,
#  'tego samego': 7.081005610790188,
#  'w wypadkach': 2.6128898604997626,
#  'w jego': -0.05690940877545701,
#  'się zdanie': 3.653374868782643,
#  'dotychczasową treść': 9.185620197502628,
#  'dopuszczenie do': 4.302668901278609,
#  'oraz zasady': 2.5530661407058406,
#  'że w': 0.2582596207368482,
#  'przez sąd': 2.9535266752461067,
#  'dla zdrowia': 4.0585941065452955,
#  'członkowskiego unii': 7.737996414326827,
#  'przez te': 3.460648110966759,
#  'uprawnień do': 3.1623240094372456,
#  'uprawniony do': 3.7518111484525125,
#  'w przedmiocie': 3.1148796279405184,
#  'w składzie': 2.919143141321773,
#  'mocy prawa': 5.745457188295583,
#  'tryb i': 1.6670686419531098,
#  'dla osób': 3.413983341689585,
#  'pracy na': 1.1762739636634991,
#  'w inny': 2.0155914352250477,
#  'osoby prawne': 6.231145241399476,
#  'które wchodzą': 6.3819792723383975,
#  'przez skarb': 4.80184770316913,
#  'albo pozbawienia': 4.671154412106192,
#  'odbywa się': 4.562809446451466,
#  'nie spełnia': 4.4893077502646825,
#  'bez względu': 5.844775543583245,
#  'zawarcia umowy': 6.53231710231058,
#  'w systemie': 2.201313261802486,
#  'zasadach i': 1.9232613708746988,
#  'który nie': 2.793084858849617,
#  'ilekroć w': 3.1801564549998815,
#  'wojewódzkiego inspektora': 7.248320903788613,
#  'spraw zabezpieczenia': 4.75541082378207,
#  'i polityki': 3.067484170794861,
#  'zawarte w': 2.811359403701699,
#  'z rejestru': 1.9939717594448398,
#  'do realizacji': 2.553360492409321,
#  'spraw kultury': 4.9995122710296345,
#  'ma być': 4.557344036762666,
#  'do właściwego': 1.8215583160006434,
#  'do udziału': 3.073665761693121,
#  'przeprowadza się': 4.019312338333865,
#  'kodeks postępowania': 5.848440423347563,
#  'w nim': 2.219451704879264,
#  'w odpowiednich': 2.4421894943700937,
#  'postępowaniu egzekucyjnym': 7.829804475873727,
#  'sposób prowadzenia': 4.811588032597721,
#  'treść oznacza': 8.230521570479919,
#  'na uwadze': 4.613410212597343,
#  'poza granicami': 8.368606397479827,
#  'europejskiej lub': 2.859514466165357,
#  'spraw oświaty': 5.47494659402584,
#  'spraw transportu': 4.433867461566689,
#  'kultury fizycznej': 7.944716356848932,
#  'zwanego dalej': 8.145850649785789,
#  'na pokrycie': 4.177707944626057,
#  'i zakres': 2.006853763160152,
#  'za pracę': 4.567533784185153,
#  'warunki określone': 4.988683561177308,
#  'terminie określonym': 4.974596668099836,
#  'sporządza się': 3.8164409122678538,
#  'według zasad': 6.7144123920727905,
#  'krótszy niż': 6.399664538065266,
#  'dnia złożenia': 3.9897666973746553,
#  'organ egzekucyjny': 7.011157540012285,
#  'okresie od': 3.620891763398953,
#  'uprawnione do': 3.988309341692737,
#  'do ewidencji': 2.7406311299154793,
#  'we l': 6.8868452640090965,
#  'w charakterze': 1.965276183067474,
#  'przepisów wykonawczych': 6.527589146512876,
#  'do której': 0.8876179708311286,
#  'niektórych innych': 5.507819623902748,
#  'oraz jego': 1.6573267635592752,
#  'wlicza się': 4.739078805169088,
#  'powinna być': 5.677474333744816,
#  'tym również': 4.203366048388501,
#  'się według': 2.7250638348600202,
#  'się przecinek': 4.475541645114771,
#  'do służby': 1.5613082107476843,
#  'do zasiłku': 3.276663668420557,
#  'za rok': 4.241515820190605,
#  'na poczet': 4.597908054358146,
#  'do osób': 1.304131576797009,
#  'złożenia wniosku': 6.062903229809144,
#  'nie podlega': 2.877177701085079,
#  'użytymi w': 3.2718564637397596,
#  'transportu i': 2.2115892251333866,
#  'sądu okręgowego': 6.565966649730873,
#  'należących do': 4.430436861844213,
#  'kandydatów na': 3.497201904019383,
#  'w wyznaczonym': 2.8861461577765186,
#  'odrębnych przepisów': 5.00728301071421,
#  'i rady': 1.101674808747634,
#  'narodowego banku': 7.104968585711495,
#  'załącznik nr': 4.286254043454558,
#  'na prawach': 4.193449862257577,
#  'mają prawo': 5.53882979948984,
#  'uzgodnieniu z': 4.093127229478126,
#  'przeznaczonych na': 3.5950722332788083,
#  'ze służby': 3.936665432597647,
#  'jest mowa': 1.0344061772444884,
#  'minister spraw': 2.7375365279325354,
#  'fizycznej i': 3.139778506021194,
#  'żołnierza zawodowego': 7.66502761154656,
#  'do sprzedaży': 2.5591028641876057,
#  'w spółce': 2.5089319298352213,
#  'egzekucyjnym w': 2.9295931222957314,
#  'z prawem': 3.4938623495447856,
#  'najwyższej izby': 8.082260962978049,
#  'właściwego organu': 5.303163010609523,
#  'na listę': 3.747591079442,
#  'na skutek': 4.434671507319708,
#  'niż wymienione': 5.401329000696598,
#  'niektórych ustaw': 7.161111291246757,
#  'dostępu do': 4.198777478437833,
#  'polega na': 4.4541247332980465,
#  'w innym': 1.938271934836443,
#  'i o': -1.7031861866056104,
#  'wykonywania działalności': 4.3624360138255005,
#  'w niniejszej': 1.1564591171908414,
#  'opieki społecznej': 6.415618758805001,
#  'również do': 1.904193073930682,
#  'są w': -0.16330489269858722,
#  'warunkach określonych': 5.416166055199612,
#  'z zagranicą': 3.7031653376957454,
#  'komendanta głównego': 7.3708540622901095,
#  'w rejestrze': 2.466356612083785,
#  'znajdujących się': 4.7039524780938065,
#  'o finansach': 4.409187816939432,
#  'lekarz weterynarii': 7.880172023507102,
#  'w uzasadnionych': 2.219783061123391,
#  'się użytymi': 4.703706033062123,
#  'krajowego rejestru': 5.974114081940942,
#  'urzędu celnego': 5.510582610958435,
#  'krajowego związku': 5.845986326847124,
#  'łącznie z': 2.9731038366339844,
#  'od decyzji': 2.922951284266728,
#  'o wolnym': 4.07271558031822,
#  'uprawomocnienia się': 4.664739427012503,
#  'wniosków o': 3.3349245572816093,
#  'doręcza się': 4.441595875698293,
#  'decyzji w': 0.4238919607490487,
#  'przez nich': 3.939296884333912,
#  'w wymiarze': 2.5554765616086277,
#  'dotyczy to': 5.392352202536045,
#  'pozwolenie na': 3.792802226770878,
#  'porozumienia o': 3.418049194268845,
#  'o masie': 4.099723973666554,
#  'głównego inspektora': 6.885940311421529,
#  'pełnienia służby': 6.043929479876782,
#  'narodowy bank': 8.521740883011093,
#  'do emerytury': 3.3927184512990367,
#  'może żądać': 5.425695046405629,
#  'wpis do': 3.707497371024833,
#  'za każdy': 5.1891309614336425,
#  'określoną w': 2.8352639426348625,
#  'niezgodnie z': 4.108422043870853,
#  'z zagranicy': 3.8343793645123907,
#  'szczegółowy zakres': 7.064336111044642,
#  'w czynnościach': 2.914274930366459,
#  'rzeczpospolitą polską': 9.299580519095265,
#  'wyłącznie na': 2.6269256942116703,
#  'na realizację': 3.988459505650909,
#  'w środowisku': 2.6158363350492086,
#  'emerytury lub': 3.6651972564469046,
#  'oraz ministrem': 2.7877556830171115,
#  'obrotu na': 2.0429376307220033,
#  'w okręgu': 2.468736213218617,
#  'spraw rynków': 5.93750634402243,
#  'który wchodzi': 5.3326347170217065,
#  'rozporządzenia nr': 1.439936208698093,
#  'zadań określonych': 4.270792000623462,
#  'o odmowie': 4.152568336428833,
#  'do lokalu': 2.785646724255827,
#  'europejskiego porozumienia': 8.111662997268711,
#  'wolnym handlu': 8.98525849024093,
#  'żołnierzy zawodowych': 7.310971440752928,
#  'dla celów': 5.091936443278926,
#  'organ administracji': 4.536722190091581,
#  'o kwotę': 2.7754486558231584,
#  'z obowiązku': 2.205275891541888,
#  'zmian w': 2.00654159970513,
#  'podstawy wymiaru': 7.83466306550276,
#  'od którego': 3.3350541427458196,
#  'ustawy stosuje': 2.4422807990836914,
#  'przepisami o': 2.3917923614234087,
#  'albo na': 0.8212572054171718,
#  'prowadzących działalność': 6.977476075666484,
#  'znajduje się': 4.603935808650223,
#  'z nich': 2.534437597130925,
#  'czynności w': 0.2069208108783701,
#  'w zakładach': 2.3101068376292617,
#  'tylko w': 1.5705014452465325,
#  'organ podatkowy': 5.972888381251645,
#  'odpowiednich przypadkach': 7.06956613793121,
#  'wchodzących w': 3.2240789199055104,
#  'z nimi': 3.5204135068105606,
#  'dane dotyczące': 5.70426509292729,
#  'w latach': 2.358260368003269,
#  'korzystanie z': 3.7495007493057466,
#  'z ich': 0.373010861297066,
#  'do wykonania': 2.4289333047202373,
#  'miesięcy do': 1.8363138297259136,
#  'o przyznanie': 4.077410424622427,
#  'ministra obrony': 5.692026535969362,
#  'informacje dotyczące': 5.670377552839192,
#  'w celach': 3.218350647169025,
#  'lub jej': 1.7567946390495637,
#  'o europejskim': 4.271566439063385,
#  'państwowa komisja': 8.274363268365097,
#  'oraz niektórych': 3.3979630395555063,
#  'i miejsce': 2.056512827882585,
#  'grzywny do': 3.097184707266284,
#  'na rok': 2.6060396977838054,
#  'w dziale': 3.016897535442118,
#  'danym roku': 6.146184877997965,
#  'naturalnych i': 3.6096902365648806,
#  'państwowej inspekcji': 6.232444784625177,
#  'do przeprowadzenia': 3.0549112107657863,
#  'o służbie': 3.2477746270322925,
#  'sprawozdania finansowego': 7.5347569060918,
#  'się także': 1.3465458354765525,
#  'informacji i': 1.0286825896643452,
#  'na wykonywanie': 2.8845622937801703,
#  'w chwili': 2.5481010846373273,
#  'europejskim obszarze': 8.27742109968919,
#  'środków finansowych': 5.4423890602020695,
#  'prowadzi się': 3.049227451409689,
#  'do jej': 1.4464671299328908,
#  'zatrudnionych w': 2.583575472830987,
#  'przeznaczone na': 3.350418190108194,
#  'wydania decyzji': 5.0874835709865165,
#  'nazwę i': 2.621209053256989,
#  'obowiązane do': 3.275478170866758,
#  'się po': 0.4241396839435913,
#  'inny sposób': 5.59005331112509,
#  'o samorządzie': 4.307767638493529,
#  'do właściwości': 3.0625561736240865,
#  'i do': -1.750674144191311,
#  'czasu wydania': 5.659940598228521,
#  'oraz warunki': 2.236154429939121,
#  'w nich': 1.5922087145164752,
#  'przez bank': 4.072237929710551,
#  'parlamentu europejskiego': 9.052926150541433,
#  'szczególnie uzasadnionych': 8.344236340952284,
#  'w państwie': 2.504407273302383,
#  'wynikającej z': 4.092814517743676,
#  'z których': -0.4541130755636589,
#  'o zasadach': 2.0385193568412756,
#  'tkanek i': 3.5314153655563185,
#  'walnego zgromadzenia': 8.708774320665906,
#  'życia lub': 3.3872443378962895,
#  'do produkcji': 2.565552608035491,
#  'roku od': 2.6542587950276553,
#  'na koniec': 4.545992568911398,
#  'tym w': -0.3210618622240001,
#  'jest obowiązana': 5.515546482837288,
#  'dopuszcza się': 4.344178338074619,
#  'o zaopatrzeniu': 4.279976085459426,
#  'i pkt': -0.6089908396657612,
#  'miejsca zamieszkania': 6.936505977048788,
#  'w szczególnie': 2.453663338590778,
#  'uzasadnionych przypadkach': 6.867956829895295,
#  'na mocy': 3.0499925188302455,
#  'ustawa określa': 4.839077717959843,
#  'systemie ubezpieczeń': 6.768197549009345,
#  'państwa na': 1.180426378815768,
#  'nie podlegają': 3.5700764116248944,
#  'organ właściwy': 3.6871148598557144,
#  'o nadanie': 4.146379009232791,
#  'rodzaj i': 2.714245760818814,
#  'w urzędzie': 2.466434904270265,
#  'do wiadomości': 3.324489776227312,
#  'się średnikiem': 4.7419731631954525,
#  'prowadzonych przez': 4.760509046276234,
#  'do złożenia': 2.578151718299551,
#  'roku podatkowym': 6.346225712388601,
#  'wcześniej niż': 5.854463414132027,
#  'o emeryturach': 4.386198298714733,
#  'konieczność zapewnienia': 7.82467063786773,
#  'wymagania dotyczące': 6.210290423259129,
#  'niniejszą ustawą': 7.1719638008492135,
#  'do informacji': 1.3725209005914782,
#  'lokalu mieszkalnego': 7.808142233892527,
#  'masie jednostkowej': 9.772230920651278,
#  'zwanej dalej': 8.147238801725516,
#  'krajowa rada': 7.49806615522711,
#  'do ustawy': 0.14717033353465972,
#  'przeliczeniu na': 4.435166819553432,
#  'i urządzeń': 2.182147131698523,
#  'moc do': 3.2185510587609514,
#  'lub za': 0.5898186284883634,
#  'tym zakresie': 3.158043980174575,
#  'środków na': 1.4538573045786642,
#  'informacji niejawnych': 6.787043349005516,
#  'odstąpić od': 5.703129476675615,
#  'do postępowania': 1.128746730045569,
#  'państwowej komisji': 5.318614970143554,
#  'odwołanie do': 3.135724898172425,
#  'prawa z': 0.9253845164117068,
#  'na finansowanie': 4.019152742680443,
#  'zasobów naturalnych': 8.931475516890542,
#  'o powszechnym': 4.23671855658849,
#  'staje się': 4.73597438517367,
#  'postępowania o': 1.0582522700581651,
#  'papiery wartościowe': 9.802178159683688,
#  'podmiot odpowiedzialny': 7.6040153061719895,
#  'postanowienia o': 2.6046893219339475,
#  'uprawnienia do': 2.831780316557909,
#  'i końcowe': 3.7894651699122184,
#  'na ten': 2.4309718132836395,
#  'przepisy wykonawcze': 6.573084421980816,
#  'w procesie': 3.1439311794091203,
#  'najpóźniej w': 2.69951110356513,
#  'średnikiem i': 4.049629213470107,
#  'o wpis': 3.514558581846457,
#  'dnia jej': 2.599820507419141,
#  'podstawę do': 3.0495620341153247,
#  ...}

# %% [markdown]
# # 5. Sort the word pairs according to that measure in the descending order and determine top 10 entries:

# %%
pmi_dict = {k: v for k, v in sorted(pmi_dict.items(), key=lambda item: item[1], reverse=True)[:10]}
pmi_dict
# Out:
# {'doktorów habilitowanych': 15.485157506710125,
#  'pionową ścianę': 15.485157506710125,
#  'techno logii': 15.485157506710125,
#  'usprawnianie zaburzonych': 15.485157506710125,
#  'przepro wadza': 15.485157506710125,
#  'stępkę położono': 15.485157506710125,
#  'wybuchła wojna': 15.485157506710125,
#  'dało pożytecznego': 15.485157506710125,
#  'poświęcenie objęło': 15.485157506710125,
#  'błędem nautycznym': 15.485157506710125}

# %% [markdown]
# # 6. Filter bigrams with number of occurrences lower than 5. Determine top 10 entries for the remaining dataset (>=5 occurrences):

# %%
bigrams_dictionary_copy = bigrams_dictionary.copy()
for k in bigrams_dictionary.keys():
    if bigrams_dictionary[k] < 5:
       del  bigrams_dictionary_copy[k]

bigrams_dictionary = bigrams_dictionary_copy
bigrams_dictionary_asc = {k: v for k, v in sorted(bigrams_dictionary.items(), key=lambda item: item[1], reverse=False)}
bigrams_dictionary_asc
# Out:
# {'zakres ustawowych': 5,
#  'finansowe uzyskane': 5,
#  'czasie korzystania': 5,
#  'korzystaniem przez': 5,
#  'lub szkodę': 5,
#  'mleczne przeznaczone': 5,
#  'indywidualna reprezentatywna': 5,
#  'reprezentatywna zawartość': 5,
#  'współczynnik przydziału': 5,
#  'i wprowadzona': 5,
#  'bezpośrednich w': 5,
#  'rezerwę krajowej': 5,
#  'i wprowadzonego': 5,
#  'referencyjnym oraz': 5,
#  'ramach przyznanej': 5,
#  'przyznanej indywidualnej': 5,
#  'skupującym w': 5,
#  'mleka od': 5,
#  'mleka sprzedanego': 5,
#  'obliczonej w': 5,
#  'kwoty mleczne': 5,
#  'wydają dyrektorzy': 5,
#  'terenowych agencji': 5,
#  'tożsamość albo': 5,
#  'wykonujące badania': 5,
#  'do sprawdzania': 5,
#  'badań zawartości': 5,
#  'tego dostawcy': 5,
#  'którą wiąże': 5,
#  'mlecznej na': 5,
#  'dzierżawcę lub': 5,
#  'wejdzie w': 5,
#  'przenoszącej własność': 5,
#  'się jeżeli': 5,
#  'do właściciela': 5,
#  'posiadaczem gospodarstwa': 5,
#  'umowa dzierżawy': 5,
#  'posiadającymi gospodarstwa': 5,
#  'samego oddziału': 5,
#  'do przyznanej': 5,
#  'lub dostawcą': 5,
#  'kopię dokumentu': 5,
#  'było spowodowane': 5,
#  'dodatkowej kwoty': 5,
#  'mleku objętym': 5,
#  'obrotu ponad': 5,
#  'każdy kilogram': 5,
#  'zapłacie należności': 5,
#  'przekazują kwoty': 5,
#  'pobranych zaliczek': 5,
#  'prowadzona produkcja': 5,
#  'przysługujące im': 5,
#  'o pobranych': 5,
#  'dostawcy bezpośredni': 5,
#  'współczynnik realokacji': 5,
#  'sumy niewykorzystanych': 5,
#  'rejestr dostawców': 5,
#  'badań tych': 5,
#  'sporządzany przez': 5,
#  'agencję i': 5,
#  'mlecznych objętych': 5,
#  'proszku przeznaczonych': 5,
#  'oraz cen': 5,
#  'finansowego tego': 5,
#  'ten wniosek': 5,
#  'wniosek na': 5,
#  'wyodrębnionych środków': 5,
#  'sprawuje sąd': 5,
#  'sędziów wojskowych': 5,
#  'czynności poza': 5,
#  'karnych na': 5,
#  'garnizonowy obejmujący': 5,
#  'wybór członków': 5,
#  'zakresie doskonalenia': 5,
#  'obecność przynajmniej': 5,
#  'przynajmniej dwóch': 5,
#  'piątej liczby': 5,
#  'odbywania posiedzeń': 5,
#  'są przełożonymi': 5,
#  'prezesa wojskowego': 5,
#  'z czterech': 5,
#  'i odrębnych': 5,
#  'prezesi tych': 5,
#  'mogą zlecać': 5,
#  'oraz usunięcia': 5,
#  'zwrócić na': 5,
#  'zasady wyznaczania': 5,
#  'obowiązany postępować': 5,
#  'stanowisku asesora': 5,
#  'mogą wyrazić': 5,
#  'stroju urzędowego': 5,
#  'innym sądzie': 5,
#  'okręgowego na': 5,
#  'ponadto o': 5,
#  'nabytym przez': 5,
#  'osobę albo': 5,
#  'wyjątkiem funkcji': 5,
#  'analizy zawartych': 5,
#  'przypadkach podmiot': 5,
#  'je ujawnić': 5,
#  'nie cierpiące': 5,
#  'uczynku popełnienia': 5,
#  'się prezesa': 5,
#  'nakazać natychmiastowe': 5,
#  'dyscyplinarnemu przysługuje': 5,
#  'lub nabył': 5,
#  'i istnieje': 5,
#  'wybrany do': 5,
#  'dyscyplinarnym karą': 5,
#  'przed odwołaniem': 5,
#  'za swoje': 5,
#  'któremu wymierzono': 5,
#  'mianowany na': 5,
#  'dyscyplinarny składa': 5,
#  'dyscyplinarnego na': 5,
#  'wyjaśnienie okoliczności': 5,
#  'wyroku orzekającego': 5,
#  'odpisu wyroku': 5,
#  'wojskowy w': 5,
#  'zasady odbywania': 5,
#  'podjęciem obowiązków': 5,
#  'określony dla': 5,
#  'dla aplikantów': 5,
#  'aplikant może': 5,
#  'zezwolenia udziela': 5,
#  'udziela prezes': 5,
#  'nieskazitelnego charakteru': 5,
#  'prokuratury lub': 5,
#  'mandat ławnika': 5,
#  'zarządza prezes': 5,
#  'dniem wygaśnięcia': 5,
#  'pełniący czynną': 5,
#  'że zażalenie': 5,
#  'ukończeniu przez': 5,
#  'wewnętrznego urzędowania': 5,
#  'delegować prokuratora': 5,
#  'zgodą prokuratora': 5,
#  'przekraczający dwóch': 5,
#  'przez zgromadzenia': 5,
#  'przedstawiane przez': 5,
#  'aplikantów i': 5,
#  'izbie wojskowej': 5,
#  'aplikację sądową': 5,
#  'przepisy dotychczas': 5,
#  'utworzoną w': 5,
#  'wydziału teologii': 5,
#  'teologicznych i': 5,
#  'wartość przychodu': 5,
#  'kwotą należnego': 5,
#  'przekroczyła w': 5,
#  'pojazd ten': 5,
#  'jeżeli przychody': 5,
#  'którzy wybrali': 5,
#  'pozycji w': 5,
#  'pisemnej właściwego': 5,
#  'kursowe od': 5,
#  'podziale przez': 5,
#  'dzień podziału': 5,
#  'jeżeli podział': 5,
#  'dzielonej do': 5,
#  'zakładowym spółki': 5,
#  'nadwyżka wartości': 5,
#  'przejmujących majątek': 5,
#  'mającym miejsce': 5,
#  'tego podmiot': 5,
#  'drodze oszacowania': 5,
#  'spółki przejmujące': 5,
#  'się ostatni': 5,
#  'dostawy energii': 5,
#  'braku wartości': 5,
#  'dzień poniesienia': 5,
#  'poprzedzających rok': 5,
#  'podatkowego do': 5,
#  'jest sprawozdanie': 5,
#  'koszty bezpośrednio': 5,
#  'wyjątkiem sytuacji': 5,
#  'dniu ich': 5,
#  'jego udzielenia': 5,
#  'wezwać strony': 5,
#  'wskazania przyczyn': 5,
#  'niedokonania zmiany': 5,
#  'lub niewskazania': 5,
#  'na kursach': 5,
#  'przychodu lub': 5,
#  'i prawnymi': 5,
#  'uprzednio zostały': 5,
#  'postaci przedsiębiorstwa': 5,
#  'amortyzacyjnych można': 5,
#  'można dokonywać': 5,
#  'urządzeń zaliczonych': 5,
#  'roku ich': 5,
#  'latach podatkowych': 5,
#  'którym rozpoczęli': 5,
#  'podatkowym oraz': 5,
#  'niezaliczonych do': 5,
#  'przychodów zgodnie': 5,
#  'prowadzącego kasę': 5,
#  'celów wymienionych': 5,
#  'zasobami mieszkaniowymi': 5,
#  'prowadzenia szkoły': 5,
#  'od agencji': 5,
#  'zwiększenia podstawy': 5,
#  'poniesienia straty': 5,
#  'jej zmniejszenia': 5,
#  'zmniejszenia o': 5,
#  'utracił to': 5,
#  'ostatnim okresie': 5,
#  'prawnych opiekunów': 5,
#  'sferze zadań': 5,
#  'była ona': 5,
#  'gospodarczego albo': 5,
#  'określając wielkość': 5,
#  'lub dzień': 5,
#  'warunku posiadania': 5,
#  'statutu spółdzielni': 5,
#  'udział procentowy': 5,
#  'procentowy w': 5,
#  'dochód osiągnięty': 5,
#  'prawnej mającej': 5,
#  'którym po': 5,
#  'sumą zaliczek': 5,
#  'do przedostatniego': 5,
#  'wysokości zaliczki': 5,
#  'kwartalne w': 5,
#  'ostatni kwartał': 5,
#  'zawiadomi w': 5,
#  'poprzedzającym dany': 5,
#  'z zeznania': 5,
#  'do wpłaty': 5,
#  'należnych zaliczek': 5,
#  'podatku wynikającej': 5,
#  'warunkiem udokumentowania': 5,
#  'handlowej są': 5,
#  'handlowej jest': 5,
#  'jednak przed': 5,
#  'wyłącznie pod': 5,
#  'od dokonywanych': 5,
#  'dokonywanych wypłat': 5,
#  'podatek na': 5,
#  'nowo zawiązana': 5,
#  'obowiązany przed': 5,
#  'sporządzoną według': 5,
#  'zachowują to': 5,
#  'życie aktów': 5,
#  'przybycia na': 5,
#  'oferty z': 5,
#  'warunki współdziałania': 5,
#  'powiatowi i': 5,
#  'ich zobowiązań': 5,
#  'rozłożeniu spłaty': 5,
#  'podlegają restrukturyzacji': 5,
#  'do zamiany': 5,
#  'zamiany wierzytelności': 5,
#  'zobowiązań oraz': 5,
#  'tych zobowiązań': 5,
#  'przez huty': 5,
#  'z rachunkiem': 5,
#  'roku za': 5,
#  'przez hutę': 5,
#  'hutę albo': 5,
#  'podaniem wysokości': 5,
#  'ich płatności': 5,
#  'finansowej z': 5,
#  'postępowania oddłużeniowego': 5,
#  'przekazywanych na': 5,
#  'polskich kolei': 5,
#  'kolei państwowych': 5,
#  'zawarła z': 5,
#  'kamiennego i': 5,
#  'zdrowotne wraz': 5,
#  'gwarancji spłaty': 5,
#  'udzielone do': 5,
#  'ustanowienie na': 5,
#  'na rozwiązanie': 5,
#  'zakresie doradztwa': 5,
#  'wpłat składek': 5,
#  'kwocie równej': 5,
#  'przypadkach dopuszcza': 5,
#  'zachowują uprawnienia': 5,
#  'opłat od': 5,
#  'uprawnień pracowników': 5,
#  'państwowego oraz': 5,
#  'się dokumentami': 5,
#  'wniesienia pierwszej': 5,
#  'dowody w': 5,
#  'z budownictwem': 5,
#  'wyłoniony w': 5,
#  'zasobów przyrody': 5,
#  'ochrona przyrody': 5,
#  'ekologicznych i': 5,
#  'zachowanie różnorodności': 5,
#  'utrzymywanie lub': 5,
#  'poza ich': 5,
#  'cech charakterystycznych': 5,
#  'dziko żyjących': 5,
#  'indywidualnie dla': 5,
#  'siedliska przyrodnicze': 5,
#  'właściwym stanie': 5,
#  'mieszczące się': 5,
#  'działalności człowieka': 5,
#  'programach ochrony': 5,
#  'przyjmowanych przez': 5,
#  'strategiach rozwoju': 5,
#  'studiach uwarunkowań': 5,
#  'rada parku': 5,
#  'których minister': 5,
#  'osoby spoza': 5,
#  'wojewoda spośród': 5,
#  'zadań wojewódzkiej': 5,
#  'miejscowego w': 5,
#  'na system': 5,
#  'przez tworzenie': 5,
#  'i realizuje': 5,
#  'niezłożenie opinii': 5,
#  'terminie uznaje': 5,
#  'sporządzenia lub': 5,
#  'planu miejscowego': 5,
#  'rezerwatów przyrody': 5,
#  'program działań': 5,
#  'ochroną przyrody': 5,
#  'zakres prowadzenia': 5,
#  'właściwi wojewodowie': 5,
#  'graniczących z': 5,
#  'strefa ochronna': 5,
#  'właściwej liczebności': 5,
#  'struktury populacji': 5,
#  'populacji poszczególnych': 5,
#  'utworzenie parku': 5,
#  'bezpowrotnej utraty': 5,
#  'wartości przyrodniczych': 5,
#  'przestrzennego w': 5,
#  'dyrektorem parku': 5,
#  'dla lasów': 5,
#  'przy dyrektorze': 5,
#  'organizacji gospodarczych': 5,
#  'specjalisty do': 5,
#  'strażnika straży': 5,
#  'który stanowi': 5,
#  'za niewykorzystywanie': 5,
#  'niewykorzystywanie bezpłatnego': 5,
#  'normatywnej powierzchni': 5,
#  'użytkowej w': 5,
#  'normy powierzchni': 5,
#  'ręcznego miotacza': 5,
#  'obowiązki funkcjonariusza': 5,
#  'dyrektorowi parku': 5,
#  'umundurowania dla': 5,
#  'oraz oznak': 5,
#  'i polowego': 5,
#  'na odpowiednie': 5,
#  'przedmiotów uzupełniających': 5,
#  'umundurowania pracowników': 5,
#  'dyrektora krajowego': 5,
#  'sporządzanie sprawozdań': 5,
#  'określając jego': 5,
#  'opinii wojewódzkiej': 5,
#  'miejscami wyznaczonymi': 5,
#  'innych znaków': 5,
#  'znaków drogowych': 5,
#  'wykonywania lotów': 5,
#  'organu uznającego': 5,
#  'uznającego obszar': 5,
#  'zwierząt poza': 5,
#  'ratowniczej oraz': 5,
#  'obronności kraju': 5,
#  'wykorzystywania przez': 5,
#  'dotyczy prowadzenia': 5,
#  'prawnymi i': 5,
#  'wykonuje samodzielnie': 5,
#  'ochrony parku': 5,
#  'się największa': 5,
#  'szczególności zapewnienie': 5,
#  'zabijania dziko': 5,
#  'prowadzeniem racjonalnej': 5,
#  'materiały lub': 5,
#  'września do': 5,
#  'do ośrodka': 5,
#  'dla danych': 5,
#  'państwa roślin': 5,
#  'podlegających ograniczeniom': 5,
#  'ograniczeniom na': 5,
#  'pomimo spełnienia': 5,
#  'roślinami lub': 5,
#  'warunkami w': 5,
#  'upraw i': 5,
#  'zajętych pod': 5,
#  'przez urzędowego': 5,
#  'posiadanie lub': 5,
#  'wyzbycia się': 5,
#  'rejestru powinien': 5,
#  'tych roślin': 5,
#  'negatywny wpływ': 5,
#  'strategii ochrony': 5,
#  'zachowania różnorodności': 5,
#  'lub rezerwatu': 5,
#  'prowadzeniem gospodarstwa': 5,
#  'właściwym wojewodą': 5,
#  'danego obszaru': 5,
#  'która zapewni': 5,
#  'i administracyjne': 5,
#  'ogłoszenia aktu': 5,
#  'lub ochronę': 5,
#  'botanicznych lub': 5,
#  'ogrody botaniczne': 5,
#  'prezydentem miasta': 5,
#  'lub planowanych': 5,
#  'z ogrodu': 5,
#  'terenach objętych': 5,
#  'na obrzeżach': 5,
#  'należy umieszczać': 5,
#  'o poddaniu': 5,
#  'określi wzory': 5,
#  'się wypłaty': 5,
#  'ochronnej zwierząt': 5,
#  'przepadek albo': 5,
#  'podmiotowi uprawnionemu': 5,
#  'parki narodowe': 5,
#  'się parkami': 5,
#  'utworzonych przed': 5,
#  'mogą używać': 5,
#  'obowiązek zgłosić': 5,
#  'okresie następującym': 5,
#  'inwalidzkiej albo': 5,
#  'inwalidzkiej dla': 5,
#  'kwoty najniższych': 5,
#  'rodzinnej i': 5,
#  'przypadku renty': 5,
#  'inwalidzkiej z': 5,
#  'była wstrzymana': 5,
#  'wysokości zapewniającej': 5,
#  'jednorazowej wypłaty': 5,
#  'dodatek dla': 5,
#  'doliczenie nie': 5,
#  'uwzględnionych dotychczas': 5,
#  'składkowych lub': 5,
#  'kwoty emerytury': 5,
#  'grupy oraz': 5,
#  'inwalidzkiej w': 5,
#  'kwota dodatku': 5,
#  'każdy pełny': 5,
#  'kwota zasiłku': 5,
#  'kształtowanie postaw': 5,
#  'i uzdolnień': 5,
#  'bezpieczeństwie oraz': 5,
#  'form wypoczynku': 5,
#  'stosowania specjalnej': 5,
#  'upośledzonym umysłowo': 5,
#  'ze sprzężonymi': 5,
#  'prawne prowadzące': 5,
#  'się odrębną': 5,
#  'i uzupełniania': 5,
#  'uzyskiwanie i': 5,
#  'wojskowych rzeczypospolitej': 5,
#  'celu kształcenia': 5,
#  'może zakładać': 5,
#  'oraz placówek': 5,
#  'znaczeniu regionalnym': 5,
#  'zawarciu porozumienia': 5,
#  'typu szkoły': 5,
#  'placówkach doskonalenia': 5,
#  'ustaloną dla': 5,
#  'liceum profilowanego': 5,
#  'i niepubliczne': 5,
#  'dające możliwość': 5,
#  'dyplomu potwierdzającego': 5,
#  'uczniów z': 5,
#  'upośledzeniem umysłowym': 5,
#  'i kształcenie': 5,
#  'testów oraz': 5,
#  'szczególności opis': 5,
#  'i testy': 5,
#  'kryteria ich': 5,
#  'centralną komisją': 5,
#  'objętym właściwością': 5,
#  'nieuczestniczenia w': 5,
#  'dotyczących przeprowadzania': 5,
#  'do nieujawniania': 5,
#  'zł waloryzowanej': 5,
#  'szkolne i': 5,
#  'dziecko kończy': 5,
#  'które ukończyło': 5,
#  'do spełniania': 5,
#  'zadaniem własnym': 5,
#  'gminy ustala': 5,
#  'zamieszkałe na': 5,
#  'z domu': 5,
#  'przedszkola lub': 5,
#  'obowiązkiem gminy': 5,
#  'bezpłatnego transportu': 5,
#  'dyrektorzy publicznych': 5,
#  'niepublicznych przedszkoli': 5,
#  'powiadomić dyrektora': 5,
#  'podejmuje dyrektor': 5,
#  'uczęszczanie do': 5,
#  'fizyczne na': 5,
#  'również udział': 5,
#  'wniosek rodziców': 5,
#  'spełniania obowiązku': 5,
#  'kształcenie i': 5,
#  'realizację obowiązku': 5,
#  'szkolnego przez': 5,
#  'kultury polskiej': 5,
#  'w środowiskach': 5,
#  'wychowania może': 5,
#  'warunków funkcjonowania': 5,
#  'jawnej i': 5,
#  'indywidualnych potrzeb': 5,
#  'i edukacyjnych': 5,
#  'lub egzaminu': 5,
#  'można przyjąć': 5,
#  'przez nauczycieli': 5,
#  'tryb dopuszczania': 5,
#  'treści nauczania': 5,
#  'przez rzeczoznawców': 5,
#  'doświadczenia w': 5,
#  'opinia jest': 5,
#  'opłat wnoszonych': 5,
#  'że opłata': 5,
#  'i programu': 5,
#  'danego zawodu': 5,
#  'narodowej do': 5,
#  'wyodrębnionych w': 5,
#  'placówki nie': 5,
#  'usunie w': 5,
#  'programu poprawy': 5,
#  'odwołanie dyrektora': 5,
#  'ogłaszać w': 5,
#  'który sprawuje': 5,
#  'sprawuje kurator': 5,
#  'przedstawiciel związku': 5,
#  'szkół prowadzonych': 5,
#  'i przebieg': 5,
#  'wykonania uchwały': 5,
#  'prawa po': 5,
#  'opiniuje projekt': 5,
#  'gimnazjów i': 5,
#  'partii i': 5,
#  'przez stowarzyszenia': 5,
#  'akt założycielski': 5,
#  'jest realizowany': 5,
#  'szczególności nazwy': 5,
#  'szkole publicznej': 5,
#  'dla mniejszości': 5,
#  'wykonawczy jednostki': 5,
#  'szkoła lub': 5,
#  'w profilu': 5,
#  'zgodą kuratora': 5,
#  'łączone w': 5,
#  'oraz wyznaczyć': 5,
#  'z niezbędnym': 5,
#  'przez placówki': 5,
#  'i udostępniają': 5,
#  'przez placówkę': 5,
#  'umożliwiających uzyskanie': 5,
#  'kształcenia na': 5,
#  'ogólnodostępnych i': 5,
#  'publicznych poradni': 5,
#  'powiatu prowadzącego': 5,
#  'formy współpracy': 5,
#  'standardy kształcenia': 5,
#  'wymiar i': 5,
#  'form doskonalenia': 5,
#  'specjalistów w': 5,
#  'placówki publiczne': 5,
#  'dotacji jest': 5,
#  'wychowanka w': 5,
#  'z nazwami': 5,
#  'spełnianiu wymagań': 5,
#  'publicznej do': 5,
#  'i dokonanie': 5,
#  'wprowadzenia tego': 5,
#  'cofnięte przez': 5,
#  'równej średnim': 5,
#  'funduszy strukturalnych': 5,
#  'uzyskanych za': 5,
#  'przyznania świadczeń': 5,
#  'granicą do': 5,
#  'publicznych placówkach': 5,
#  'z zadań': 5,
#  'orzec umieszczenie': 5,
#  'wychowawczym lub': 5,
#  'iv w': 5,
#  'różnej liczbie': 5,
#  'przez sędziów': 5,
#  'dokumentowania jej': 5,
#  'nieletnich w': 5,
#  'bezpieczeństwa tych': 5,
#  'młodzieżowych ośrodkach': 5,
#  'wychowawczych oraz': 5,
#  'jakich mogą': 5,
#  'stanem zdrowia': 5,
#  'działalnością komisji': 5,
#  'oraz wglądu': 5,
#  'związku rzemiosła': 5,
#  'realizacji zaleceń': 5,
#  'stwierdzenia istotnych': 5,
#  'istotnych uchybień': 5,
#  'lub cały': 5,
#  'komisji albo': 5,
#  'obrotu prawnego': 5,
#  'przyjmowania na': 5,
#  'młodzieży pozbawionym': 5,
#  'całkowicie opieki': 5,
#  'lub okresową': 5,
#  'programów pomocy': 5,
#  'rozpoczęcia odbywania': 5,
#  'przypadku nabywania': 5,
#  'studiów oraz': 5,
#  'oraz standardy': 5,
#  'możliwości zorganizowania': 5,
#  'tytuł honorowy': 5,
#  'województwa przysługuje': 5,
#  'zawarte między': 5,
#  'między zarządem': 5,
#  'przez centralną': 5,
#  'ich miejsca': 5,
#  'sprawach wpisu': 5,
#  'tej ewidencji': 5,
#  'ewidencji stosuje': 5,
#  'kliniczne wyrobów': 5,
#  'oceną zgodności': 5,
#  'lub pogorszenie': 5,
#  'według danych': 5,
#  'celu używania': 5,
#  'z przewidzianym': 5,
#  'wyrobu w': 5,
#  'i zastosowanie': 5,
#  'obrotu pod': 5,
#  'używania mogą': 5,
#  'być prawidłowo': 5,
#  'staranności w': 5,
#  'znaku zgodności': 5,
#  'że wszystkie': 5,
#  'ich zastosowanie': 5,
#  'dla ratowania': 5,
#  'dany wyrób': 5,
#  'szpitala lub': 5,
#  'jeżeli stwierdzono': 5,
#  'z polskimi': 5,
#  'odnoszącymi się': 5,
#  'zastosowanych przy': 5,
#  'na organizm': 5,
#  'podejmuje organ': 5,
#  'medycznym oraz': 5,
#  'dotyczące wyrobów': 5,
#  'na zakres': 5,
#  'zawieszonych i': 5,
#  'daty ważności': 5,
#  'podmioty uczestniczące': 5,
#  'wymagania organizacyjne': 5,
#  'prowadzące badania': 5,
#  'przedstawiciel jest': 5,
#  'rejestr wytwórców': 5,
#  'zmian we': 5,
#  'z rejestrów': 5,
#  'handlową i': 5,
#  'informacje wskazujące': 5,
#  'badań bezpieczeństwa': 5,
#  'i klinicznych': 5,
#  'ramach prowadzonego': 5,
#  'przedstawiciel podmiotu': 5,
#  'zalecenia pokontrolne': 5,
#  'obsługi lub': 5,
#  'przypadku ustalenia': 5,
#  'norm lub': 5,
#  'oznaczonego znakiem': 5,
#  'ustanawiającego wspólne': 5,
#  'nienależących do': 5,
#  'odpadów za': 5,
#  'doradztwa w': 5,
#  'listu przewozowego': 5,
#  'przewóz odpadów': 5,
#  'także organowi': 5,
#  'przywóz i': 5,
#  'jeżeli główny': 5,
#  'się zabezpieczenie': 5,
#  'polisy ubezpieczeniowej': 5,
#  'ubezpieczeniowej jest': 5,
#  'bankowa lub': 5,
#  'lub określa': 5,
#  'zostały wywiezione': 5,
#  'i zagospodarowanie': 5,
#  'egzekucja okazała': 5,
#  'środowiska dokonuje': 5,
#  'odbiorcy w': 5,
#  'przejścia graniczne': 5,
#  'załączniku w': 5,
#  'jest statek': 5,
#  'pod nim': 5,
#  'lub pasażerów': 5,
#  'przedawnienia roszczeń': 5,
#  'po zaistnieniu': 5,
#  'może uprawiać': 5,
#  'pasażerów lub': 5,
#  'za stanowiący': 5,
#  'statek niestanowiący': 5,
#  'niestanowiący polskiej': 5,
#  'działu dotyczące': 5,
#  'przynależności jest': 5,
#  'zwolnić niektóre': 5,
#  'względzie ich': 5,
#  'urzędowo poświadczony': 5,
#  'wyciąg ze': 5,
#  'do podnoszenia': 5,
#  'izby morskiej': 5,
#  'działalność za': 5,
#  'uprawianiem żeglugi': 5,
#  'być zmieniona': 5,
#  'właściciela i': 5,
#  'wniesie o': 5,
#  'utrata przez': 5,
#  'ustaje po': 5,
#  'stałym rejestrze': 5,
#  'rejestrze okrętowym': 5,
#  'mówi się': 5,
#  'właściwego związku': 5,
#  'odpowiednio przepisów': 5,
#  'numer rejestrowy': 5,
#  'identyfikacyjny nadany': 5,
#  'stwierdzenie przez': 5,
#  'rejestrze statków': 5,
#  'podlegających wpisowi': 5,
#  'lub uległ': 5,
#  'została wpisana': 5,
#  'razie niezgłoszenia': 5,
#  'statku zawiadamia': 5,
#  'odpowiedniego dokumentu': 5,
#  'zawiadamia właściwe': 5,
#  'bądź innej': 5,
#  'być poddany': 5,
#  'jest bez': 5,
#  'bez określenia': 5,
#  'któremu zostało': 5,
#  'i wymiarów': 5,
#  'pod banderą': 5,
#  'są dyrektorzy': 5,
#  'specyfikę i': 5,
#  'uprawiającego żeglugę': 5,
#  'wszystkie dokumenty': 5,
#  'osoby znajdujące': 5,
#  'zainteresowanych ładunkiem': 5,
#  'skutek prawny': 5,
#  'przy wszystkich': 5,
#  'wszystkich czynnościach': 5,
#  'statek był': 5,
#  'przez kapitana': 5,
#  'środki dla': 5,
#  'zdarzeniach dotyczących': 5,
#  'zabezpieczenia dowodów': 5,
#  'poświadczony przez': 5,
#  'za przyjęcie': 5,
#  'rozporządzenia sposób': 5,
#  'po wypadku': 5,
#  'i właściwe': 5,
#  'lub kontynuowania': 5,
#  'na ładunku': 5,
#  'jest kierować': 5,
#  'przypadku urodzenia': 5,
#  'mienie pozostałe': 5,
#  'osoby zmarłej': 5,
#  'i akt': 5,
#  'jest sporządzić': 5,
#  'lub polskiej': 5,
#  'głównego lub': 5,
#  'za najem': 5,
#  'statku obciążonego': 5,
#  'hipoteką morską': 5,
#  'osobę zagraniczną': 5,
#  'przedmiotu hipoteki': 5,
#  'do budowy': 5,
#  'alimentacyjnych oraz': 5,
#  'za wywołanie': 5,
#  'zaspokojenie wierzyciela': 5,
#  'z upoważnieniem': 5,
#  'wymaga złożenia': 5,
#  'zawiadomienia właściciela': 5,
#  'innych wierzycieli': 5,
#  'wynikłą stąd': 5,
#  'powinien on': 5,
#  'tym statku': 5,
#  'powoduje zawieszenie': 5,
#  'jest bank': 5,
#  'załogi i': 5,
#  'wynagrodzenia szkody': 5,
#  'i drogach': 5,
#  'wierzyciela z': 5,
#  'jest skuteczny': 5,
#  'ich bagażu': 5,
#  'termin wygaśnięcia': 5,
#  'którym powinny': 5,
#  'należności powstałych': 5,
#  'kwotę na': 5,
#  'lub właściciela': 5,
#  'zgłoszenia roszczenia': 5,
#  'powoływania się': 5,
#  'to przewiduje': 5,
#  'od ustanowienia': 5,
#  'żeglugi statkiem': 5,
#  'jego odpowiedzialności': 5,
#  'jednostek obliczeniowych': 5,
#  'jeżeli dłużnikiem': 5,
#  'odpowiada on': 5,
#  'umowa przewozu': 5,
#  'każda strona': 5,
#  'jeżeli ładunek': 5,
#  'przewozie na': 5,
#  'roszczenia do': 5,
#  'być wytoczone': 5,
#  'i dostępnym': 5,
#  'czarterujący może': 5,
#  'przewoźnika na': 5,
#  'gdy chodzi': 5,
#  'w rozkładzie': 5,
#  'ładunku nie': 5,
#  'i odpowiednie': 5,
#  'jest umieścić': 5,
#  'w szczególny': 5,
#  'umieścić na': 5,
#  'właściwym czasie': 5,
#  'ponosi także': 5,
#  'jeżeli złożenie': 5,
#  'konieczny do': 5,
#  'i odpowiedniego': 5,
#  'danymi określającymi': 5,
#  'zastrzeżenia dotyczące': 5,
#  'powinna nastąpić': 5,
#  'odmówić wpisania': 5,
#  'dokonany na': 5,
#  'innego przewoźnika': 5,
#  'na całej': 5,
#  'objętej tym': 5,
#  'zwalnia go': 5,
#  'z konosamentu': 5,
#  'wykonanie jest': 5,
#  'jest według': 5,
#  'swoje prawo': 5,
#  'określenia sposobu': 5,
#  'tytułu przewozu': 5,
#  'postanowienia umowne': 5,
#  'zabezpieczenia przez': 5,
#  'jeżeli odbiorca': 5,
#  'do przechowania': 5,
#  'wszystkich należności': 5,
#  'przed oddaniem': 5,
#  'przekracza wartość': 5,
#  'podróży lub': 5,
#  'szkodę spowodowaną': 5,
#  'nie udzieli': 5,
#  'żądać zapłaty': 5,
#  'niebezpieczeństwem dla': 5,
#  'wzajemne zobowiązania': 5,
#  'wskutek którego': 5,
#  'się niezdatny': 5,
#  'niezdatny do': 5,
#  'do naprawy': 5,
#  'szkodę wynikłą': 5,
#  'wartość ładunku': 5,
#  'z wartością': 5,
#  'wartością towarów': 5,
#  'kwoty obliczonej': 5,
#  'w międzynarodowej': 5,
#  'zasad dotyczących': 5,
#  'uważana za': 5,
#  'z ograniczenia': 5,
#  'wynikła z': 5,
#  'za przyjęte': 5,
#  'osoba niebędąca': 5,
#  'na siedem': 5,
#  'zwrot uiszczonej': 5,
#  'powodu przeszkód': 5,
#  'jego wyboru': 5,
#  'pasażera do': 5,
#  'odstąpiono od': 5,
#  'umowy przed': 5,
#  'konwencji ateńskiej': 5,
#  'bezzwłocznie zawiadomić': 5,
#  'roszczenie wobec': 5,
#  'mu informacji': 5,
#  'kilku następujących': 5,
#  'umowy czarteru': 5,
#  'wstępuje z': 5,
#  'braków lub': 5,
#  'okresie tym': 5,
#  'stosowania się': 5,
#  'razie zwłoki': 5,
#  'tych okoliczności': 5,
#  'rozsądnym czasie': 5,
#  'czasie nie': 5,
#  'ustalona według': 5,
#  'przeładunku i': 5,
#  'portu i': 5,
#  'mimo to': 5,
#  'czynności należących': 5,
#  'jest rozliczyć': 5,
#  'zasadami dobrej': 5,
#  'usługi pilotowe': 5,
#  'swojej winy': 5,
#  'kwoty równej': 5,
#  'zainteresowanego na': 5,
#  'razie zajścia': 5,
#  'orzeczenia izby': 5,
#  'lub zawiesić': 5,
#  'zawiesić uprawnienia': 5,
#  'w niebezpieczeństwie': 5,
#  'statku albo': 5,
#  'wynika co': 5,
#  'wynagrodzenie jest': 5,
#  'inne mienie': 5,
#  'wyłączeniem odsetek': 5,
#  'wartości mienia': 5,
#  'ono wyższe': 5,
#  'za działania': 5,
#  'wkład w': 5,
#  'podjąć wszelkie': 5,
#  'zapewnienia przez': 5,
#  'poszukiwania lub': 5,
#  'doprowadził do': 5,
#  'wszelkie szkody': 5,
#  'zaniedbań w': 5,
#  'każdego ze': 5,
#  'morzu odpadów': 5,
#  'powstała wskutek': 5,
#  'być wyłączona': 5,
#  'wyrządzoną działaniem': 5,
#  'stanu sprzed': 5,
#  'ich zwrotu': 5,
#  'zwolnić się': 5,
#  'lub usunięcie': 5,
#  'lub poświadczenie': 5,
#  'polską w': 5,
#  'dochodzenia roszczeń': 5,
#  'do wypełnienia': 5,
#  'przewieziony drogą': 5,
#  'morską stosownie': 5,
#  'jest podać': 5,
#  'lub znalezione': 5,
#  'mienia przez': 5,
#  'morskie wody': 5,
#  'lub zniszczeniu': 5,
#  'i złożeniu': 5,
#  'przekazać właściwemu': 5,
#  'i poniesionych': 5,
#  'tytuł viii': 5,
#  'ubezpieczony może': 5,
#  'umowie ubezpieczenia': 5,
#  'wiedział o': 5,
#  'stronom w': 5,
#  'wartością ubezpieczenia': 5,
#  'odrębnie od': 5,
#  'nich określa': 5,
#  'pozbawia go': 5,
#  'może od': 5,
#  'którym dowiedział': 5,
#  'które by': 5,
#  'jeżeli wystawiono': 5,
#  'może wykonać': 5,
#  'spowodowana przez': 5,
#  'mienia bądź': 5,
#  'prawa odstąpienia': 5,
#  'przed zmianą': 5,
#  'lub rażącego': 5,
#  'wieku lub': 5,
#  'powstałe wskutek': 5,
#  'objętą ubezpieczeniem': 5,
#  'od wszelkich': 5,
#  'zawiadomienia od': 5,
#  'zgłoszony przed': 5,
#  'termin dla': 5,
#  'dochodzenia praw': 5,
#  'tytuł ix': 5,
#  'ix postępowanie': 5,
#  'z ograniczeniem': 5,
#  'i podział': 5,
#  'za wystarczający': 5,
#  'prowadzonej dla': 5,
#  'dla zaspokojenia': 5,
#  'ustanowieniu funduszu': 5,
#  'i podjęcia': 5,
#  'i otwarciu': 5,
#  'do biegłego': 5,
#  'i oświadczeń': 5,
#  'wiadomości informacji': 5,
#  'wezwaniu należy': 5,
#  'ogłoszenie powinno': 5,
#  'koszty tego': 5,
#  'razie skierowania': 5,
#  'i wzywa': 5,
#  'potrzeby sąd': 5,
#  'wprowadzenie zmian': 5,
#  'spór o': 5,
#  'jeżeli zgłosi': 5,
#  'dokonania wypłat': 5,
#  'nadaje mu': 5,
#  'o podział': 5,
#  'dochodzone na': 5,
#  'sąd wezwie': 5,
#  'cywilnej są': 5,
#  'klauzuli wykonalności': 5,
#  'lub urzędowo': 5,
#  'jeżeli wszystkie': 5,
#  ...}

# %%
bigrams_dictionary = {k: v for k, v in sorted(bigrams_dictionary.items(), key=lambda item: item[1], reverse=True)[:10]}
bigrams_dictionary
# Out:
# {'mowa w': 28450,
#  'których mowa': 13847,
#  'o których': 13839,
#  'z dnia': 9513,
#  'którym mowa': 9165,
#  'o którym': 9155,
#  'do spraw': 8680,
#  'i nr': 8435,
#  'dodaje się': 8190,
#  'w drodze': 7092}

# %% [markdown]
# # 7. Use log likelihood ratio (LLR) to compute the measure for all pairs of words:

# %%
def llr_2x2(k11, k12, k21, k22):
    '''Special case of llr with a 2x2 table'''
    return 2 * (denormEntropy([k11 + k12, k21 + k22]) +
                denormEntropy([k11 + k21, k12 + k22]) -
                denormEntropy([k11, k12, k21, k22]))

def denormEntropy(counts):
    '''Computes the entropy of a list of counts scaled by the sum of the counts. If the inputs sum to one, this is just the normal definition of entropy'''
    counts = list(counts)
    total = float(sum(counts))
    # Note tricky way to avoid 0*log(0)
    return -sum([k * math.log(k / total + (k == 0)) for k in counts])

w1_dict, w2_dict, llr_dict = dict(), dict(), dict()

for k in bigrams_dictionary.keys():
    w1, w2 = k.split()
    if w1 not in w1_dict.keys():
        bigrams = set()
    else:
        bigrams = w1_dict[w1]
    bigrams.add(k)
    w1_dict[w1] = bigrams
    if w2 not in w2_dict.keys():
        bigrams = set()
    else:
        bigrams = w2_dict[w2]
    bigrams.add(k)
    w2_dict[w2] = bigrams

for k, v in bigrams_dictionary.items():
    w1, w2 = k.split()
    b1, b2 = w1_dict[w1], w2_dict[w2]
    k11 = v
    k12 = sum(bigrams_dictionary[i] for i in b1) - v
    k21 = sum(bigrams_dictionary[i] for i in b2) - v
    k22 = bigrams_sum - k11 - k12 - k21
    llr_dict[k] = llr_2x2(k11, k12, k21, k22)

llr_dict
# Out:
# {'mowa w': 176478.90209806873,
#  'których mowa': 116487.1890897266,
#  'o których': 91317.24360996136,
#  'z dnia': 51193.825702226255,
#  'którym mowa': 74945.41002563864,
#  'o którym': 57819.1330856944,
#  'do spraw': 62759.87027216959,
#  'i nr': 58749.40208535467,
#  'dodaje się': 65564.32445676788,
#  'w drodze': 42222.39421694481,
#  'na podstawie': 52539.76119496202,
#  'stosuje się': 48574.833414177,
#  'o której': 34790.62867726898,
#  'której mowa': 43844.47067235649,
#  'w przypadku': 27817.41625480645,
#  'od dnia': 34151.996132001455,
#  'w zakresie': 27830.244787672185,
#  'właściwy do': 32733.16766981181,
#  'zastępuje się': 38678.93476830411,
#  'w ustawie': 26562.06496036728,
#  'minister właściwy': 49954.972916778206,
#  'oraz z': 11964.915378040401,
#  'w życie': 24036.44329452887,
#  'określonych w': 20973.966119877878,
#  'w tym': 16468.997376594343,
#  'w terminie': 20210.352217419655,
#  'w pkt': 13506.926638255478,
#  'a także': 39099.12428182573,
#  'ustawie z': 24629.77898132155,
#  'ustawy z': 13184.566960427444,
#  'w razie': 17990.63931988878,
#  'się wyrazami': 24186.474898119166,
#  'może być': 21469.471771525627,
#  'w celu': 12666.030074149487,
#  'zgodnie z': 19314.788538327673,
#  'skreśla się': 20095.800434068893,
#  'dni od': 23391.762321112386,
#  'w szczególności': 14584.76759924821,
#  'wejścia w': 13743.932456955663,
#  'na wniosek': 15256.565398412524,
#  'się w': 374.251795980148,
#  'z zastrzeżeniem': 17835.852065580722,
#  'z tytułu': 16180.730502170394,
#  'co najmniej': 32587.038310097152,
#  'się wyrazy': 15651.011122175434,
#  'do dnia': 4348.652340532048,
#  'w sprawach': 11875.655444132397,
#  'a w': 3997.3620794446906,
#  'określone w': 11333.088669408928,
#  'rzeczypospolitej polskiej': 30528.550197765973,
#  'się do': 2100.811334108701,
#  'nie może': 10759.103457932011,
#  'się odpowiednio': 14302.868676090264,
#  'się następujące': 14547.66358748416,
#  'wprowadza się': 14042.952393358224,
#  'w sprawie': 9959.867715293076,
#  'mogą być': 17900.21817140022,
#  'w którym': 1806.0468775343616,
#  'się pkt': 7911.7941928028595,
#  'z dniem': 9138.948494677432,
#  'w rozumieniu': 10590.488293568487,
#  'porozumieniu z': 13266.696394921513,
#  'w porozumieniu': 9393.307423939463,
#  'w wysokości': 6171.422563989647,
#  'w przepisach': 8212.568046950037,
#  'po upływie': 17814.147962454794,
#  'właściwego do': 8952.176818805048,
#  'lub w': 33.17758660740219,
#  'się na': 1571.5003670325968,
#  'na zasadach': 10635.913658790174,
#  'z ministrem': 9730.501497781777,
#  'wchodzi w': 8454.752571847057,
#  'w związku': 6655.519132211106,
#  'na terytorium': 10219.817739565391,
#  'ministra właściwego': 18107.723546251553,
#  'przed dniem': 14590.957745962369,
#  'jest obowiązany': 15140.175475121956,
#  'ustawy o': 5865.227686389349,
#  'z wyjątkiem': 10687.587160712981,
#  'nie stosuje': 10362.703981022176,
#  'wraz z': 10054.771308884141,
#  'względu na': 11832.338130892836,
#  'oraz w': 47.21854310948402,
#  'w okresie': 6936.354564909823,
#  'i w': 804.882359366864,
#  'właściwym do': 8846.58842429344,
#  'w stosunku': 5699.928746098769,
#  'o zmianie': 8753.67009904061,
#  'związku z': 7893.8446029603365,
#  'chyba że': 19199.367955135072,
#  'miesięcy od': 11261.87900784894,
#  'w trybie': 6797.087460233597,
#  'prawo do': 5524.810879669676,
#  'terytorium rzeczypospolitej': 14725.183008401036,
#  'do obrotu': 7084.69561453833,
#  'przez to': 8003.444511594484,
#  'związanych z': 8608.432689689798,
#  'ustawa z': 5277.9997658345965,
#  'ustawa wchodzi': 15078.563214849695,
#  'ze względu': 13935.74029509013,
#  'stosunku do': 6970.609150352073,
#  'przepisów o': 6596.274020652869,
#  'ministrem właściwym': 16147.752059361592,
#  'w sposób': 3228.194321458228,
#  'z uwzględnieniem': 8306.843707249907,
#  'określonym w': 5660.1145130147925,
#  'i tryb': 6523.463125304435,
#  'w formie': 6195.083523019566,
#  'na rzecz': 8222.263452377752,
#  'w ramach': 6341.055713316891,
#  'wymienionych w': 6242.660400616704,
#  'w ciągu': 6037.411907724803,
#  'zasadach określonych': 11452.241706990942,
#  'się z': 203.96220977348275,
#  'spraw wewnętrznych': 11490.318651577545,
#  'w postępowaniu': 4320.21041890874,
#  'spraw finansów': 9574.883951130454,
#  'rozumie się': 7903.38301120192,
#  'pozbawienia wolności': 14815.546796455623,
#  'podlega karze': 13231.324736800838,
#  'do czasu': 5382.951941379462,
#  'dnia wejścia': 9083.86450479539,
#  'w dniu': 3925.4940415795427,
#  'zostały ogłoszone': 14586.109838812277,
#  'ogłoszone w': 5719.195426638238,
#  'się przez': 1508.5991198412376,
#  'ustawy zostały': 8396.643711201832,
#  'oraz o': 1264.6519120747107,
#  'po wyrazach': 10435.56711215929,
#  'wniosek o': 4947.967464153597,
#  'związane z': 6567.644368635083,
#  'w wyniku': 4837.149484960479,
#  'w których': 9.630326387705281,
#  'i innych': 3025.723841204657,
#  'dniem wejścia': 10711.674227262913,
#  'określonego w': 4665.157945502899,
#  'w odniesieniu': 5411.089898161357,
#  'nie jest': 3327.1966098197154,
#  'odniesieniu do': 6990.795017107623,
#  'i dodaje': 5494.5497495949385,
#  'wymienionej ustawy': 8913.374934822787,
#  'na czas': 5635.714291280368,
#  'się przepisy': 3896.3457040709327,
#  'wniosku o': 6256.483284207294,
#  'zmianie ustawy': 8463.0524637762,
#  'życie z': 2774.9756661957363,
#  'podstawie przepisów': 6800.38418040461,
#  'prawa do': 3240.968021008768,
#  'życie niniejszej': 8965.386819378778,
#  'życie po': 6747.232456773039,
#  'w czasie': 3785.1684648215305,
#  'samorządu terytorialnego': 13160.861877316336,
#  'nie później': 7681.434879113745,
#  'z zakresu': 4705.765333818272,
#  'przypadku gdy': 8623.723105915851,
#  'wynikających z': 5604.4277333136415,
#  'w skład': 3670.501434270991,
#  'się o': 510.341857843101,
#  'odpowiednio przepisy': 7650.406805852283,
#  'z tym': 1613.611070298124,
#  'zasięgnięciu opinii': 12053.012903298488,
#  'szczegółowe zasady': 9768.050093699203,
#  'po zasięgnięciu': 8487.44968152087,
#  'do wykonywania': 2993.7165515317465,
#  'w roku': 1425.1655555048492,
#  'ochrony środowiska': 8002.45063248802,
#  'skarbu państwa': 9927.666875308278,
#  'finansów publicznych': 10043.78547700894,
#  'do rejestru': 3876.659196230874,
#  'odpowiednio do': 3000.0265714799752,
#  'spraw gospodarki': 6088.089378789489,
#  'umowy o': 4111.901374108216,
#  'i ich': 1284.1519034247613,
#  'z wyłączeniem': 5509.7756319913315,
#  'się wyrazem': 5751.7652896536165,
#  'z przepisami': 4040.5813975148485,
#  'ustala się': 4387.1848816944985,
#  'przez ministra': 4338.067608897632,
#  'zezwolenia na': 4332.858470644453,
#  'rady ministrów': 7807.456588548805,
#  'przez okres': 4204.689594618947,
#  'na obszarze': 4117.844322323857,
#  'wymienione w': 4146.431938664522,
#  'co do': 2216.4911523117335,
#  'później niż': 7556.066559902843,
#  'terminie do': 2885.521693368035,
#  'o ochronie': 3969.626751259435,
#  'działalności gospodarczej': 9017.626731779768,
#  'rada ministrów': 8331.156341570655,
#  'jednak niż': 6988.895905189798,
#  'w brzmieniu': 4028.7858196177986,
#  'określony w': 3438.9437301495345,
#  'jeżeli w': 129.33756642160006,
#  'na okres': 2779.9436709252186,
#  'informacji o': 3395.1669941011933,
#  'po pkt': 3087.827520296152,
#  'rozumieniu przepisów': 6739.413086177054,
#  'uchyla się': 5015.077636417758,
#  'kodeksu postępowania': 7128.217687120297,
#  'życie ustawy': 4421.846553079493,
#  'w części': 1942.8592496532947,
#  'o wydanie': 3524.131265060394,
#  'unii europejskiej': 11054.828933486502,
#  'kropkę zastępuje': 10332.928720722186,
#  'pracy w': 765.758864794625,
#  'w wypadku': 3053.455907166237,
#  'do lat': 3399.7961548308376,
#  'ustawę z': 4250.469168544107,
#  'budżetu państwa': 7548.064094477202,
#  'ze środków': 5051.955626438386,
#  'jeżeli nie': 2244.923018975649,
#  'przepisów ustawy': 4240.358087703498,
#  'w tych': 857.4368296874454,
#  'przez niego': 4938.642127730796,
#  'opieki zdrowotnej': 9549.403677681526,
#  'administracji rządowej': 8921.128577905536,
#  'mając na': 4983.1523905450595,
#  'o ile': 4455.107878706534,
#  'na terenie': 4381.554758640414,
#  'postępowania w': 945.2186809269479,
#  'określonej w': 2683.334099699743,
#  'więcej niż': 6240.607953394036,
#  'lub jego': 1847.6767069261987,
#  'obrony narodowej': 9369.66044417553,
#  'spraw zdrowia': 4657.982792074254,
#  'nie mogą': 3525.9894895711914,
#  'przepisach o': 3385.33283737459,
#  'uważa się': 4622.2232676467975,
#  'prezes rady': 5177.873142639874,
#  'i na': 74.23352931858972,
#  'zasady i': 1970.8929528699955,
#  'się przecinkiem': 4910.210902021092,
#  'pracy i': 1339.1950397276087,
#  'jednostki samorządu': 6009.706160233851,
#  'zmienianej w': 3393.5931355467765,
#  'produktu leczniczego': 9499.998996096774,
#  'informacje o': 3367.6297287816415,
#  'ustawy zmienianej': 6247.7652424902335,
#  'niniejszej ustawy': 6100.720891863442,
#  'lub na': 48.67929747106973,
#  'po wyrazie': 6057.003480782194,
#  'przez prezesa': 3533.0891236718744,
#  'wydanych na': 3712.4547116575413,
#  'przepisy ustawy': 3498.74408098351,
#  'sprawach o': 2887.4933954849257,
#  'w całości': 2855.6429437391926,
#  'i z': 385.33042748481967,
#  'o podatku': 1957.464443222736,
#  'z wnioskiem': 3847.8165769826155,
#  'lat od': 4056.1500981387217,
#  'towarów i': 2438.4616614792612,
#  'udziału w': 2667.4333149008453,
#  'od osób': 2747.916841838829,
#  'i gospodarki': 1809.7593754724367,
#  'i sposób': 1330.4858208748046,
#  'zmiany tekstu': 7634.609805249122,
#  'tym że': 4573.9868850452185,
#  'tekstu jednolitego': 9173.611215902476,
#  'państwowej straży': 6168.441408962179,
#  'decyzji o': 2850.207169182191,
#  'ubezpieczeń społecznych': 8146.146174802361,
#  'nadzór nad': 7296.902521572523,
#  'się za': 1008.3637974871672,
#  'z budżetu': 2145.9106195159256,
#  'podstawie odrębnych': 4892.550173159296,
#  'w dzienniku': 2559.500394545612,
#  'następuje w': 1374.6659158818657,
#  'niż w': 457.07786227040924,
#  'informację o': 4047.0415158388787,
#  'prezes urzędu': 4249.063006664408,
#  'jednolitego wymienionej': 7493.261803617446,
#  'przecinkiem i': 3375.4079164547147,
#  'do sądu': 1477.3329002491664,
#  'i nie': 160.64490163023584,
#  'nie dłużej': 4459.946874934307,
#  'w odrębnych': 1364.384114688728,
#  'na ubezpieczenie': 3591.792306569463,
#  'właściwemu do': 2813.568897680845,
#  'i jego': 752.6291674928507,
#  'przed upływem': 5277.29278975584,
#  'oraz ich': 1204.5020548069733,
#  'o udzielenie': 3070.9784318216844,
#  'na cele': 3577.683118982881,
#  'udział w': 2295.1694438201375,
#  'dłuższy niż': 5594.552157534577,
#  'wynikające z': 3473.3140767429722,
#  'z powodu': 3548.362944316119,
#  'papierów wartościowych': 8706.972148079347,
#  'warunki i': 1553.8049528941046,
#  'do pracy': 811.9493952716002,
#  'karze pozbawienia': 5760.39135101252,
#  'lub innych': 1485.2735703313956,
#  'korzystania z': 2948.1244064000202,
#  'straży granicznej': 7358.428349404727,
#  'przepisy o': 1661.5673398879007,
#  'wnioskiem o': 3995.1921584274387,
#  'nie dotyczy': 3437.075220939354,
#  'jednostek organizacyjnych': 5945.518175406913,
#  'się od': 321.9948490645038,
#  'urzędu ochrony': 3475.851202931124,
#  'na prowadzenie': 2653.529560960247,
#  'w przypadkach': 1170.4927295023808,
#  'oraz innych': 1537.7063140441896,
#  'jednostek samorządu': 4791.187387806996,
#  'jest to': 2609.8433266170323,
#  'od daty': 4230.721462139685,
#  'minister obrony': 3839.68186430457,
#  'wolności do': 1831.1430625662906,
#  'służby cywilnej': 5298.361974568965,
#  'na jego': 766.6362774533336,
#  'zezwolenie na': 2968.272837301425,
#  'wymienionej w': 1052.0950184235116,
#  'składek na': 2726.9481861495296,
#  'przez organ': 2455.553398198448,
#  'wewnętrznych i': 2361.446937088447,
#  'do prowadzenia': 1546.2110579978325,
#  'minister sprawiedliwości': 4246.766546462459,
#  'lub ich': 874.369269929768,
#  'jak również': 5479.828276664804,
#  'albo w': 173.3969502467662,
#  'za zgodą': 4636.279206436142,
#  'nie są': 1761.9724146053195,
#  'obowiązany do': 1562.0575117908302,
#  'lub z': 36.74967712396756,
#  'w której': 20.941115264431573,
#  'w danym': 2088.79537503724,
#  'o tym': 380.45916913670953,
#  'brzmieniu nadanym': 7497.442188341847,
#  'w toku': 2332.7557340932544,
#  'rozumieniu ustawy': 3438.694708473253,
#  'ministrowi właściwemu': 6568.144190104169,
#  'i inne': 1372.559509554063,
#  'oraz sposób': 1528.4556292580673,
#  'nie można': 3353.0438200689096,
#  'w załączniku': 2415.046632858459,
#  'nadanym niniejszą': 7424.534520664463,
#  'ma prawo': 4143.446013161461,
#  'zdrowia i': 1641.0825584958657,
#  'na dzień': 2321.708524878719,
#  'przewidzianych w': 1799.6295528894989,
#  'głównego urzędu': 4081.6269906004527,
#  'do których': 9.035987893701531,
#  'z mocy': 2028.2727828212082,
#  'niezbędne do': 2331.071283126308,
#  'w tej': 758.5531440476188,
#  'produktów leczniczych': 6015.771721417124,
#  'niż do': 749.3809170139721,
#  'na żądanie': 2675.718584423361,
#  'może nastąpić': 3806.058290778863,
#  'po dniu': 2630.3367983702337,
#  'podstawie umowy': 2940.9485134130227,
#  'ue l': 6248.671277033085,
#  'sąd może': 2533.8526507553324,
#  'na względzie': 2979.21899496048,
#  'stają się': 3077.0761454032618,
#  'zmiany wymienionej': 4097.256227653947,
#  'na końcu': 3041.0044803425553,
#  'podatku od': 2312.5140531983634,
#  'na celu': 809.1932791868458,
#  'pracy lub': 955.1437702695257,
#  'o postępowaniu': 1198.158460528939,
#  'także w': 309.8008518744027,
#  'spraw środowiska': 2624.6461224156083,
#  'i usług': 1623.6771582205547,
#  'za pośrednictwem': 4173.9305278069805,
#  'użyte w': 2083.068063105573,
#  'dzienniku urzędowym': 6507.347185287215,
#  'z tego': 930.2588138126303,
#  'są obowiązani': 4732.864244617325,
#  'w rzeczypospolitej': 202.76551215490326,
#  'obowiązany jest': 2601.7558491852105,
#  'służby wojskowej': 4162.360399236408,
#  'państwa członkowskiego': 5088.605571256987,
#  'na ich': 369.0084461164661,
#  'należy przez': 2105.960183551477,
#  'do tego': 912.1116606210708,
#  'po uzyskaniu': 3742.920711066603,
#  'z tych': 663.493811280583,
#  'o charakterze': 1799.2966258411761,
#  'uwzględniając w': 949.9246942462632,
#  'właściwy organ': 2648.2758596991625,
#  'całości lub': 2606.0713051990024,
#  'prawo o': 1141.6454311620328,
#  'do ich': 285.4898280779598,
#  'trybie określonym': 4138.080033594597,
#  'wykonywania zawodu': 4511.936073230012,
#  'z urzędu': 587.4773764255224,
#  'oraz na': 0.27792950125876814,
#  'się również': 1337.0803556432365,
#  'oraz inne': 1612.4560144086136,
#  'wydane na': 2040.910883913166,
#  'zgodę na': 2916.511855078803,
#  'w zdaniu': 1899.1219052178785,
#  'dokonuje się': 1788.7292099877377,
#  'z innych': 543.7543255041819,
#  'nie dłuższy': 2757.6096377648646,
#  'to rozumieć': 4818.843306486182,
#  'które nie': 1581.0946062900475,
#  'ograniczenia wolności': 4583.671048602613,
#  'na miejsce': 1514.0203900914057,
#  'w imieniu': 1597.1410604154225,
#  'z działalności': 528.1271925668698,
#  'tej samej': 5106.096159611519,
#  'innych niż': 2005.0314386707323,
#  'z chwilą': 2633.6110476975446,
#  'administracji publicznej': 3809.2475762275208,
#  'do którego': 1214.9650615240098,
#  'dniu wejścia': 3615.7845122565923,
#  'zawartych w': 1341.8528909825254,
#  'jeżeli jest': 1132.7502268916287,
#  'i opieki': 1045.3632072698092,
#  'ustawy wymienionej': 2370.0676753258012,
#  'prezydenta rzeczypospolitej': 4124.366122134299,
#  'osób prawnych': 3504.00531951875,
#  'się jako': 1899.3805765114375,
#  'i odwołuje': 2392.1056087329052,
#  'zawodowej służby': 3836.3740966549376,
#  'jednostki organizacyjne': 4427.697530511097,
#  'szczegółowe warunki': 3521.8046593384934,
#  'nie przekracza': 2741.9645321128482,
#  'do zadań': 849.0388426126447,
#  'niezdolności do': 2524.3306195712066,
#  'nie ma': 1969.2510531832813,
#  'przez osoby': 1413.0975059531047,
#  'lub innego': 1906.4537887134939,
#  'wyrobów akcyzowych': 5269.757171957266,
#  'pod warunkiem': 4859.97339146044,
#  'przeznaczone do': 1688.5645533059724,
#  'na potrzeby': 1705.0058395342203,
#  'decyzję o': 2298.4632422436844,
#  'polski obszar': 5134.199068474201,
#  'do wysokości': 593.4023484362406,
#  'w stanie': 1199.5253809266724,
#  'do celów': 1623.4843459134572,
#  'sposób i': 518.32920910127,
#  'z funduszu': 864.2151892809779,
#  'środków trwałych': 4068.7520267403743,
#  'i ochrony': 386.66923820623197,
#  'główny inspektor': 4363.122028667367,
#  'są obowiązane': 3638.7168323714286,
#  'jednostki organizacyjnej': 3953.4452022952246,
#  'wchodzą w': 1762.9016680511413,
#  'wolności albo': 2678.074066731948,
#  'prezesa urzędu': 2644.695416532777,
#  'powinny być': 2968.0509851270035,
#  'krajowej rady': 3271.72177159234,
#  'zwany dalej': 4691.705518455019,
#  'za granicą': 3563.0918632061657,
#  'niezależnie od': 3243.5528838772734,
#  'niezbędnych do': 1898.5298763161409,
#  'postępowania karnego': 3292.83361113118,
#  'stosunku pracy': 2297.598439342648,
#  'państwa w': 194.72823006438557,
#  'powołuje i': 1681.177061532624,
#  'skarb państwa': 4109.874105700568,
#  'dochodowym od': 3084.912444904243,
#  'składki na': 2159.64945305977,
#  'w takim': 1565.0248542831978,
#  'pod uwagę': 4665.747485937649,
#  'na piśmie': 2327.1132016083575,
#  'dłużej jednak': 4176.229588788785,
#  'w dziedzinie': 1592.13604528422,
#  'osób fizycznych': 4121.813546416488,
#  'imię i': 2242.742348954489,
#  'przepisach wydanych': 3648.0901432123355,
#  'nadzoru nad': 3473.1773375836638,
#  'organ celny': 3157.9207845035344,
#  'w granicach': 1814.130874618073,
#  'wpisu do': 1601.0448712336365,
#  'prezes sądu': 2477.58062615963,
#  'o systemie': 1429.30495887727,
#  'miejsce zamieszkania': 3998.0282277627157,
#  'spraw rolnictwa': 2660.984513664327,
#  'drodze decyzji': 3325.241747673819,
#  'z zachowaniem': 2231.3707746661385,
#  'załączniku nr': 2915.2301948030217,
#  'na stanowisko': 1582.8540810650447,
#  'postępowanie w': 621.1724987014895,
#  'sposób określony': 3019.3371029708433,
#  'w każdym': 1412.1801873068325,
#  'inne niż': 1975.6496093600726,
#  'dnia doręczenia': 3227.162481573818,
#  'tekst ustawy': 3438.2554361035,
#  'zagospodarowania przestrzennego': 5427.709915960949,
#  'lub więcej': 1672.217531920236,
#  'lub nie': 144.51105469302274,
#  'nie stanowi': 1999.4938942552544,
#  'w zależności': 1641.932707725442,
#  'podatku dochodowym': 4131.328587080658,
#  'dnia otrzymania': 2948.101850791587,
#  'przepisy kodeksu': 2923.720593611368,
#  'w kraju': 853.4689659583382,
#  'oraz do': 78.87581511295866,
#  'lub do': 150.1353580331197,
#  'zależności od': 2920.7363965282857,
#  'następuje na': 1098.7195342603372,
#  'opłat za': 2580.7690041964815,
#  'z przyczyn': 1774.925760233542,
#  'organy administracji': 2728.236941432886,
#  'zmianie niektórych': 3354.497924912117,
#  'tworzy się': 1969.5269632678246,
#  'bezpieczeństwa i': 1083.560461124871,
#  'państwa lub': 744.8765459457063,
#  'zakres i': 977.7228856294532,
#  'energii elektrycznej': 5072.351139213988,
#  'w postaci': 1601.350450742757,
#  'które mogą': 2365.8054496678815,
#  'do wydania': 850.2161282109446,
#  'za okres': 1566.6534273082507,
#  'oddziaływania na': 2155.1554023017525,
#  'podstawie ustawy': 1354.9278835674631,
#  'przy czym': 3443.1752749304505,
#  'stosownie do': 2201.532955628005,
#  'pracy oraz': 883.1937031240377,
#  'pochodzących z': 1876.2301418356365,
#  'w różnych': 1304.1431676184293,
#  'w jednostkach': 1106.0523141857702,
#  'przeznaczonych do': 1414.8545723017887,
#  'za pomocą': 3153.332163986648,
#  'w trakcie': 1647.5258813421242,
#  'licząc od': 2869.7329786884948,
#  'działalność gospodarczą': 4031.1786723197147,
#  'nie stanowią': 1974.8611848077853,
#  'w miejscu': 1133.2088132187491,
#  'przysługuje prawo': 2535.8158577443537,
#  'składa się': 1536.5806252047769,
#  'dla których': 633.7541031644214,
#  'pracy z': 324.5005493935896,
#  'a jeżeli': 2316.8117014150193,
#  'i warunki': 692.4550094363512,
#  'w innych': 42.21845334104728,
#  'służby w': 213.78490761085413,
#  'minister finansów': 1749.0915019929234,
#  'środowiska i': 896.5664242970524,
#  'spraw administracji': 1521.0434669240203,
#  'do końca': 1691.4081161523354,
#  'odpowiednio w': 186.34756446420215,
#  'kultury i': 1359.6669480272103,
#  'wydaje się': 1117.5983958391007,
#  'ochrony państwa': 1839.937251808602,
#  'straży pożarnej': 4391.088892378288,
#  'z przepisów': 253.85858190373983,
#  'oznacza się': 1592.8234856413328,
#  'czasu pracy': 2117.88596349975,
#  'przepisów prawa': 1781.33568299326,
#  'od towarów': 1609.1565594282292,
#  'o działalności': 246.21960570127703,
#  'nie więcej': 1615.9854148129234,
#  'zakładu ubezpieczeń': 3065.0763495818246,
#  'określonymi w': 1443.566118989489,
#  'na których': 4.195061078178696,
#  'na polski': 1421.781521965866,
#  'z upływem': 1079.190838172508,
#  'wykonywania zadań': 2202.0185808937604,
#  'tryb postępowania': 1907.653423362819,
#  'w obrocie': 900.7794603662333,
#  'wyłącznie w': 523.0431278678589,
#  'mniej niż': 2925.4763434233464,
#  'pozwolenia na': 1445.6270963802817,
#  'marszałek sejmu': 4354.115022706053,
#  'w pierwszej': 894.2213614060311,
#  'na rachunek': 1643.1736908196472,
#  'za przestępstwo': 2226.683723945971,
#  'prawa i': 399.60566853522323,
#  'wynagrodzenia za': 2053.5523363899265,
#  'prowadzenia działalności': 2091.317132106371,
#  'na postanowienie': 1478.9731315399404,
#  'pomocy społecznej': 3326.1632083470286,
#  'prezesa rady': 2090.004370509705,
#  'organów administracji': 2458.8744683381665,
#  'zachowują moc': 4133.436591944654,
#  'zdanie drugie': 4325.1291081795625,
#  'dłużej niż': 2329.145237706136,
#  'przez radę': 2033.8611829901638,
#  'lub inne': 920.4106448921375,
#  'prowadzenie działalności': 2361.670356951916,
#  'działalności w': 117.29870248178486,
#  'postanowienie o': 1577.6089356464217,
#  'z wykonywaniem': 1703.9377549325582,
#  'lub innej': 1369.1171512678266,
#  'oraz tryb': 970.5764629398473,
#  'następującego po': 3266.8792731752546,
#  'w umowie': 1297.9810849326896,
#  'uprawnionych do': 1750.0358936750563,
#  'wniosek ministra': 1886.417446289037,
#  'zakresie określonym': 1996.5510015851032,
#  'może w': 142.73275793192443,
#  'do wniosku': 769.9281437047175,
#  'do jego': 174.62897427601274,
#  'podatku dochodowego': 3706.8306329768675,
#  'i nazwisko': 1863.8580376472091,
#  'w służbie': 828.5070313302567,
#  'przy ustalaniu': 3412.708840575913,
#  'do pełnienia': 1252.824106679007,
#  'określa się': 809.3579447107622,
#  'realizacji zadań': 2525.6863257392106,
#  'i adres': 1371.6563600535155,
#  'przepisy ogólne': 2917.96635986655,
#  'urzędowym rzeczypospolitej': 2889.8240603153463,
#  'i administracji': 399.83247879566625,
#  'i obowiązki': 1302.182015828148,
#  'rolnictwa i': 1421.2378156141494,
#  'okres nie': 1215.4650870787154,
#  'może przekroczyć': 2540.625469435545,
#  'wykonywania czynności': 1924.0359243323328,
#  'państwa oraz': 866.8389208528388,
#  'kierując się': 1991.6830977866775,
#  'zakład ubezpieczeń': 3006.366701734485,
#  'państw członkowskich': 4014.8014199687677,
#  'opłaty za': 2012.83813266964,
#  'karze ograniczenia': 3077.399059203879,
#  'również w': 372.006586558884,
#  'karze grzywny': 3333.258262583189,
#  'zwane dalej': 3632.628355651068,
#  'po zakończeniu': 2432.4187616142444,
#  'na warunkach': 986.1861949913437,
#  'działalność w': 345.7105065610958,
#  'niematerialnych i': 1860.5292836426524,
#  'biorąc pod': 3876.226150577073,
#  'w jakim': 1305.8372665860225,
#  'o pracę': 869.2062351193745,
#  'członkowskich unii': 3398.0369729231825,
#  'obszar celny': 3506.6199230829516,
#  'zakresu administracji': 2318.7599600247922,
#  'ustawy nie': 461.29071836560615,
#  'zmiany w': 218.98457493213937,
#  'uwzględnia się': 1747.0834965865943,
#  'się wyraz': 1624.1750034833094,
#  'może zostać': 2002.258435552154,
#  'nie zostały': 939.6819385369599,
#  'przez organy': 1411.7288590088137,
#  'ze sprzedaży': 2021.343089265647,
#  'lub o': 3.3109341952949762,
#  'tym samym': 2987.6698923713193,
#  'w warunkach': 507.00080941652413,
#  'nie przysługuje': 1296.3564064765233,
#  'pobiera się': 1562.9398345423397,
#  'do uzyskania': 710.6166670009843,
#  'wartości niematerialnych': 3549.6585464583804,
#  'wpływ na': 2000.694506031694,
#  'przez osobę': 1474.685136285465,
#  'niezwłocznie po': 2137.5410748203867,
#  'przy wykonywaniu': 2653.3165108255344,
#  'pierwszej instancji': 3773.1249090864403,
#  'rady nadzorczej': 3147.4814316764678,
#  'niż przez': 712.329233711207,
#  'należności z': 740.6778953804169,
#  'jest w': 110.0938276007073,
#  'zgody na': 1212.408798481396,
#  'komisja wyborcza': 3621.5265145437224,
#  'na ubezpieczenia': 772.1931483465014,
#  'wolności od': 1206.8037144954724,
#  'na rynku': 1110.755608252657,
#  'przez podmiot': 1452.8227711025393,
#  'przepisy dotyczące': 1904.37768276532,
#  'warunków określonych': 1931.9507387354242,
#  'oświaty i': 1573.2380187296658,
#  'z naruszeniem': 1672.7567065345938,
#  'zalicza się': 1871.1366552749532,
#  'z udziałem': 1629.6092074982007,
#  'sił zbrojnych': 4495.744032708545,
#  'niż określone': 1703.2032454443251,
#  'do świadczeń': 616.8052378346329,
#  'różnych przypadkach': 3244.215647967467,
#  'na środowisko': 1842.9687796382932,
#  'przewidziane w': 1042.60011997947,
#  'komendant główny': 3652.9465283654736,
#  'do tych': 255.36219923745375,
#  'i zagospodarowania': 1013.8760799624142,
#  'przypadkach określonych': 1863.8525342472421,
#  'z jego': 119.6940200101817,
#  'uznaje się': 1754.7547676543472,
#  'w zakładzie': 1055.6013516528765,
#  'wojewódzki inspektor': 3165.2828167223706,
#  'miesiąca od': 1634.100672305649,
#  'że nie': 862.39435448515,
#  'z innymi': 1132.2734824315994,
#  'do publicznej': 651.392262396228,
#  'przy pomocy': 1806.021011701756,
#  'tego samego': 3166.5332247927035,
#  'w wypadkach': 904.9284762251191,
#  'w jego': 0.775274615152739,
#  'się zdanie': 1758.6799962464138,
#  'dotychczasową treść': 4124.983044119485,
#  'dopuszczenie do': 1667.7925704361405,
#  'oraz zasady': 793.6823508960078,
#  'że w': 51.761528512462974,
#  'przez sąd': 1225.9816695491318,
#  'dla zdrowia': 1377.7347768686013,
#  'członkowskiego unii': 3063.849426651843,
#  'przez te': 1117.5743317500455,
#  'uprawnień do': 1085.456056157709,
#  'uprawniony do': 1290.4164209690643,
#  'w przedmiocie': 1179.5350316480035,
#  'w składzie': 1113.7543943851488,
#  'mocy prawa': 2267.332378379673,
#  'tryb i': 385.62943926197477,
#  'dla osób': 1146.124314347282,
#  'pracy na': 295.5687717376859,
#  'w inny': 572.6550307014259,
#  'osoby prawne': 2621.5940149314265,
#  'które wchodzą': 2643.645701806141,
#  'przez skarb': 1748.3437435127562,
#  'albo pozbawienia': 1632.4572816363652,
#  'odbywa się': 1658.9242233619443,
#  'nie spełnia': 1527.7943488806486,
#  'bez względu': 1989.0345504709767,
#  'zawarcia umowy': 2746.2502033946657,
#  'w systemie': 557.4478923673742,
#  'zasadach i': 444.5212855327409,
#  'który nie': 906.1269783859607,
#  'ilekroć w': 1236.7805810170248,
#  'wojewódzkiego inspektora': 2783.1253610445856,
#  'spraw zabezpieczenia': 1766.264993201621,
#  'i polityki': 1033.207448940142,
#  'zawarte w': 932.7612817879999,
#  'z rejestru': 517.4015007501584,
#  'do realizacji': 625.8850897365483,
#  'spraw kultury': 1799.202726723146,
#  'ma być': 1345.8317509363696,
#  'do właściwego': 284.3499476860743,
#  'do udziału': 928.4611568984692,
#  'przeprowadza się': 1431.2349803883699,
#  'kodeks postępowania': 2019.4315664905807,
#  'w nim': 562.3633585839998,
#  'w odpowiednich': 1024.9311590375146,
#  'postępowaniu egzekucyjnym': 3164.472788479634,
#  'sposób prowadzenia': 1590.100107373888,
#  'treść oznacza': 4013.4774354890287,
#  'na uwadze': 1699.2735430198954,
#  'poza granicami': 3459.169326682624,
#  'europejskiej lub': 1078.3870129581774,
#  'spraw oświaty': 2058.183946041696,
#  'spraw transportu': 1548.6985148375388,
#  'kultury fizycznej': 3113.571453604609,
#  'zwanego dalej': 3136.110426873489,
#  'na pokrycie': 1436.7811142941355,
#  'i zakres': 642.8377917336184,
#  'za pracę': 1506.5917377746227,
#  'warunki określone': 1777.7590976543142,
#  'terminie określonym': 1831.5721710259604,
#  'sporządza się': 1195.951831091661,
#  'według zasad': 2432.095379208462,
#  'krótszy niż': 2270.2961056481,
#  'dnia złożenia': 1652.793726417076,
#  'organ egzekucyjny': 2835.306869428692,
#  'okresie od': 1128.0027213236608,
#  'uprawnione do': 1368.6055959293735,
#  'do ewidencji': 718.6049681645818,
#  'we l': 2480.0590444683403,
#  'w charakterze': 472.4618718040874,
#  'przepisów wykonawczych': 2501.9704762416804,
#  'do której': 26.422339622629806,
#  'niektórych innych': 1829.2836237830925,
#  'oraz jego': 305.84210341016296,
#  'wlicza się': 1662.2144609707757,
#  'powinna być': 1844.7078362122702,
#  'tym również': 1444.4460708956758,
#  'się według': 994.212369227258,
#  'się przecinek': 1710.3704813953373,
#  'do służby': 230.35105097608175,
#  'do zasiłku': 950.9871290475712,
#  'za rok': 1278.9332678963256,
#  'na poczet': 1548.8915826094453,
#  'do osób': 216.39092101785354,
#  'złożenia wniosku': 2340.9848838121543,
#  'nie podlega': 1214.368077652296,
#  'użytymi w': 1232.878781135776,
#  'transportu i': 858.1493701940635,
#  'sądu okręgowego': 2684.368187975375,
#  'należących do': 1584.4570235308493,
#  'kandydatów na': 1142.8183391774073,
#  'w wyznaczonym': 960.9847415906843,
#  'odrębnych przepisów': 2059.9059643502696,
#  'i rady': 159.52227060834412,
#  'narodowego banku': 2748.9149955832363,
#  'załącznik nr': 1861.7896007873642,
#  'na prawach': 1278.0074188561994,
#  'mają prawo': 1980.0163152712703,
#  'uzgodnieniu z': 1564.8343270960613,
#  'przeznaczonych na': 975.1699581027497,
#  'ze służby': 1098.2546234414913,
#  'jest mowa': 66.31231232749997,
#  'minister spraw': 474.3640191901068,
#  'fizycznej i': 1143.5993541855714,
#  'żołnierza zawodowego': 2947.288996379819,
#  'do sprzedaży': 646.9226226325845,
#  'w spółce': 917.6529762748396,
#  'egzekucyjnym w': 1080.3645924207522,
#  'z prawem': 1341.976750065107,
#  'najwyższej izby': 3010.8632582354985,
#  'właściwego organu': 1646.8123617897509,
#  'na listę': 1336.4745952527155,
#  'na skutek': 1533.5469858521246,
#  'niż wymienione': 1928.3496506536976,
#  'niektórych ustaw': 2509.1310818275306,
#  'dostępu do': 1357.1638023329433,
#  'polega na': 1545.838775167882,
#  'w innym': 520.2805287862429,
#  'i o': 279.1713744159788,
#  'wykonywania działalności': 1263.9349871922605,
#  'w niniejszej': 144.30162259971257,
#  'opieki społecznej': 2354.266701223056,
#  'również do': 521.4533631830709,
#  'są w': 0.05659275327343494,
#  'warunkach określonych': 1773.168376079062,
#  'z zagranicą': 1507.6427459763363,
#  'komendanta głównego': 2530.1938209457803,
#  'w rejestrze': 735.443966735038,
#  'znajdujących się': 1508.242544910754,
#  'o finansach': 1446.9477828481467,
#  'lekarz weterynarii': 3121.5378815507975,
#  'w uzasadnionych': 550.0211661900394,
#  'się użytymi': 1692.043728867371,
#  'krajowego rejestru': 1968.8973339155054,
#  'urzędu celnego': 1953.1505594201953,
#  'krajowego związku': 1820.4303186947072,
#  'łącznie z': 949.7020883508376,
#  'od decyzji': 832.9914533320407,
#  'o wolnym': 1165.7269078091485,
#  'uprawomocnienia się': 1557.7652358967462,
#  'wniosków o': 1310.38048921054,
#  'doręcza się': 1472.4135184444021,
#  'decyzji w': 146.22519942652434,
#  'przez nich': 1004.033409178257,
#  'w wymiarze': 734.706905290368,
#  'dotyczy to': 2006.2721199540174,
#  'pozwolenie na': 1261.986836561875,
#  'porozumienia o': 1387.457748095505,
#  'o masie': 1202.484039205825,
#  'głównego inspektora': 2231.2799241701578,
#  'pełnienia służby': 1914.8908237137948,
#  'narodowy bank': 3172.596517107362,
#  'do emerytury': 1008.9975875241216,
#  'może żądać': 1692.1239005147945,
#  'wpis do': 1148.7681649239967,
#  'za każdy': 1903.3582829799998,
#  'określoną w': 926.4905923147453,
#  'niezgodnie z': 1400.4890416024718,
#  'z zagranicy': 1461.7025969154784,
#  'szczegółowy zakres': 2381.7036508231904,
#  'w czynnościach': 925.0124156314414,
#  'rzeczpospolitą polską': 3460.394683524645,
#  'wyłącznie na': 648.8613501518848,
#  'na realizację': 1311.1948330884916,
#  'w środowisku': 821.6222397978418,
#  'emerytury lub': 1129.522448124364,
#  'oraz ministrem': 576.5453633581055,
#  'obrotu na': 503.77429511764785,
#  'w okręgu': 645.146695551346,
#  'spraw rynków': 1982.8967291607696,
#  'który wchodzi': 1532.6826263799667,
#  'rozporządzenia nr': 1492.2073437829094,
#  'zadań określonych': 1241.6987310385448,
#  'o odmowie': 1196.1959552118788,
#  'do lokalu': 735.4028530388605,
#  'europejskiego porozumienia': 2865.0601752357616,
#  'wolnym handlu': 3149.0632015827177,
#  'żołnierzy zawodowych': 2605.45780780908,
#  'dla celów': 1513.699414114686,
#  'organ administracji': 1239.8170476845262,
#  'o kwotę': 771.9880250326823,
#  'z obowiązku': 574.6223601885722,
#  'zmian w': 578.6493077188497,
#  'podstawy wymiaru': 2641.8872385780414,
#  'od którego': 898.2497232162277,
#  'ustawy stosuje': 819.5113809602917,
#  'przepisami o': 877.2434939615196,
#  'albo na': 147.53836304572178,
#  'prowadzących działalność': 2395.745713259297,
#  'znajduje się': 1440.3114413779695,
#  'z nich': 558.521825124044,
#  'czynności w': 75.74298017518595,
#  'w zakładach': 611.2358979645651,
#  'tylko w': 397.86273701733444,
#  'organ podatkowy': 1894.8695376140677,
#  'odpowiednich przypadkach': 2472.816594954864,
#  'wchodzących w': 1059.8397152277175,
#  'z nimi': 1224.5130024715909,
#  'dane dotyczące': 1839.8766555509064,
#  'w latach': 839.3512016488239,
#  'korzystanie z': 1102.4645090211416,
#  'z ich': 18.03064992034342,
#  'do wykonania': 493.94474376994185,
#  'miesięcy do': 315.71438086027047,
#  'o przyznanie': 1254.533638781868,
#  'ministra obrony': 1575.2057582029447,
#  'informacje dotyczące': 1745.7634092311491,
#  'w celach': 1088.3005906132748,
#  'lub jej': 388.3588406459894,
#  'o europejskim': 1278.0626714372775,
#  'państwowa komisja': 2979.1967755063797,
#  'oraz niektórych': 839.3465398499975,
#  'i miejsce': 469.802649619407,
#  'grzywny do': 941.2426867817994,
#  'na rok': 505.0690188446315,
#  'w dziale': 894.2802094253711,
#  'danym roku': 2012.4020985383395,
#  'naturalnych i': 1206.7677731309086,
#  'państwowej inspekcji': 1844.5888172969571,
#  'do przeprowadzenia': 735.4522156665917,
#  'o służbie': 679.2360602427507,
#  'sprawozdania finansowego': 2555.008112608346,
#  'się także': 160.6040501135867,
#  'informacji i': 196.0840302426368,
#  'na wykonywanie': 830.5403273855918,
#  'w chwili': 618.479508254095,
#  'europejskim obszarze': 2750.224185974719,
#  'środków finansowych': 1738.5186111180083,
#  'prowadzi się': 704.849576618697,
#  'do jej': 200.11650415771874,
#  'zatrudnionych w': 650.1397393743973,
#  'przeznaczone na': 771.7633962544496,
#  'wydania decyzji': 1632.8405937054558,
#  'nazwę i': 906.4388251879718,
#  'obowiązane do': 925.2451174638118,
#  'się po': 172.2139675259241,
#  'inny sposób': 1755.7279500938457,
#  'o samorządzie': 1254.7669611572055,
#  'do właściwości': 786.9317514089635,
#  'i do': 1195.651387480204,
#  'czasu wydania': 1637.6589257640808,
#  'oraz warunki': 562.2361145760515,
#  'w nich': 252.74716924596578,
#  'przez bank': 1179.7682573444908,
#  'parlamentu europejskiego': 3070.7769361516584,
#  'szczególnie uzasadnionych': 2651.8500181283944,
#  'w państwie': 664.7112247234909,
#  'wynikającej z': 1274.576822668605,
#  'z których': 114.3498782311799,
#  'o zasadach': 226.3530301535502,
#  'tkanek i': 994.2910070779035,
#  'walnego zgromadzenia': 3266.334121635742,
#  'życia lub': 1053.3131120111793,
#  'do produkcji': 625.0147687024437,
#  'roku od': 712.9679044468212,
#  'na koniec': 1342.5326906316332,
#  'tym w': 0.7465381465153769,
#  'jest obowiązana': 1767.6279058858345,
#  'dopuszcza się': 1185.8116931112017,
#  'o zaopatrzeniu': 1168.9765664787265,
#  'i pkt': 2.848225024295971,
#  'miejsca zamieszkania': 2162.8974297829773,
#  'w szczególnie': 665.7685514804907,
#  'uzasadnionych przypadkach': 2142.733450057378,
#  'na mocy': 581.8392309331102,
#  'ustawa określa': 1585.8274923413046,
#  'systemie ubezpieczeń': 2060.114961483814,
#  'państwa na': 251.18211521726334,
#  'nie podlegają': 1166.5775790997432,
#  'organ właściwy': 848.5178904378845,
#  'o nadanie': 1205.4669231525622,
#  'rodzaj i': 934.8144947731053,
#  'w urzędzie': 601.2887839393225,
#  'do wiadomości': 808.8656372115947,
#  'się średnikiem': 1493.3612516087596,
#  'prowadzonych przez': 1339.4714387355198,
#  'do złożenia': 476.0901084386278,
#  'roku podatkowym': 2234.6968220187155,
#  'wcześniej niż': 1771.5864232755994,
#  'o emeryturach': 1263.2541742076864,
#  'konieczność zapewnienia': 2421.4079376938025,
#  'wymagania dotyczące': 1862.2573732033707,
#  'niniejszą ustawą': 3171.9357834868797,
#  'do informacji': 210.5874583569821,
#  'lokalu mieszkalnego': 2773.7354512586135,
#  'masie jednostkowej': 3402.3573104845264,
#  'zwanej dalej': 2536.5537954094143,
#  'krajowa rada': 2743.23851279315,
#  'do ustawy': 9.63079473352991,
#  'przeliczeniu na': 1437.1496331974631,
#  'i urządzeń': 614.0427468564594,
#  'moc do': 747.3696390229743,
#  'lub za': 94.45998130639782,
#  'tym zakresie': 748.6495322155679,
#  'środków na': 235.23330203822115,
#  'informacji niejawnych': 2363.8214770899503,
#  'odstąpić od': 1770.192487624212,
#  'do postępowania': 84.93404831096996,
#  'państwowej komisji': 1393.9799964216509,
#  'odwołanie do': 751.6618138938211,
#  'prawa z': 155.66231257648906,
#  'na finansowanie': 1188.0977362809354,
#  'zasobów naturalnych': 3161.3051271383,
#  'o powszechnym': 1203.407450652332,
#  'staje się': 1364.9566804023343,
#  'postępowania o': 342.25740441470407,
#  'papiery wartościowe': 3430.535967527016,
#  'podmiot odpowiedzialny': 2472.539768415747,
#  'postanowienia o': 920.1798396210652,
#  'uprawnienia do': 681.9603788156528,
#  'i końcowe': 1095.6741243278957,
#  'na ten': 468.5263407807215,
#  'przepisy wykonawcze': 2139.0845416768498,
#  'w procesie': 1005.0237728895154,
#  'najpóźniej w': 642.8995815656381,
#  'średnikiem i': 1293.7068628163543,
#  'o wpis': 1059.6427789148875,
#  'dnia jej': 901.4713299017312,
#  'podstawę do': 674.8796484987251,
#  ...}

# %% [markdown]
# # 8. Sort the word pairs according to that measure in the descending order and display top 10 entries:

# %%
llr_dict = {k: v for k, v in sorted(llr_dict.items(), key=lambda item: item[1], reverse=True)[:10]}
llr_dict
# Out:
# {'mowa w': 176478.90209806873,
#  'których mowa': 116487.1890897266,
#  'o których': 91317.24360996136,
#  'którym mowa': 74945.41002563864,
#  'dodaje się': 65564.32445676788,
#  'do spraw': 62759.87027216959,
#  'i nr': 58749.40208535467,
#  'o którym': 57819.1330856944,
#  'na podstawie': 52539.76119496202,
#  'z dnia': 51193.825702226255}

# %% [markdown]
# # 12. Answer the following questions:
# * Why do we have to filter the bigrams, rather than the token sequence?
#
#
#
# * Which measure (PMI, PMI with filtering, LLR) works better for the bigrams and which for the trigrams?
#
# W bigramach warto odfiltrować wyrażenia występujące stosunkowo rzadko lub gdy są to pojedyncze przypadki (PMI lub PMI with filtering), ponieważ w tekstach zdarzają się literówki.
#
# * What types of expressions are discovered by the methods.
#
# PMI - wykrywa wyrażenia występująco rzadko. Im mniej ich jest,tym ma wyższą wartość.
#
# LLR - wykrywa wyrażenia charakterystyczne dla danego języka.
#
# * Can you devise a different type of filtering that would yield better results?
#
# Usuwanie wyrazów występujących bardzo często jak na przykład spójniki.
